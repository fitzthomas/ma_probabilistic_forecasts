# %% [markdown]
# # Capacity Factors Forecast with Regression

# %%
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
from enum import Enum

from ngboost.scores import LogScore
from shapely.geometry import Point
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

from ngboost import NGBRegressor
from sklearn.model_selection import train_test_split
from ngboost.distns import Exponential, Normal, LogNormal
from ngboost.scores import LogScore, CRPScore
from sklearn.metrics import mean_pinball_loss
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

from scipy.stats import norm
import ephem
from datetime import datetime
import pickle
from pathlib import Path

paths = {"era5_eu_2013": "resources/europe-2013-era5.nc",
         "era5_tutorial": "resources/europe-2013-era5-tutorial.nc",
         "offshore_shape": "resources/regions_offshore_elec_s_37.geojson",
         "onshore_shape": "resources/regions_onshore_elec_s_37.geojson",
         "capfacs": "resources/capfacs_37.csv",
         "era5_regions": "resources/europe-2013-era5-regions.nc"}

# %%
ds = xr.open_dataset(filename_or_obj=paths["era5_regions"], engine="netcdf4")
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (region: 65, time: 8760)
# Coordinates:
#   * region            (region) object 'AL0 0 on' 'AT0 0 on' ... 'SI0 0 off'
#   * time              (time) datetime64[ns] 2013-01-01 ... 2013-12-31T23:00:00
# Data variables:
#     height            (region, time) float64 ...
#     wnd100m           (region, time) float64 ...
#     roughness         (region, time) float64 ...
#     influx_toa        (region, time) float64 ...
#     influx_direct     (region, time) float64 ...
#     influx_diffuse    (region, time) float64 ...
#     albedo            (region, time) float64 ...
#     temperature       (region, time) float64 ...
#     soil_temperature  (region, time) float64 ...
#     runoff            (region, time) float64 ...
# Attributes:
#     description:  Era5 data with mean value of the coordinates within a region

# %%
capfacts = pd.read_csv(paths["capfacs"])
capfacts
# Out:
#                  snapshot  AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  \
# 0     2013-01-01 00:00:00          0.003291      0.001469          0.0
# 1     2013-01-01 01:00:00          0.002103      0.000000          0.0
# 2     2013-01-01 02:00:00          0.000000      0.000000          0.0
# 3     2013-01-01 03:00:00          0.000000      0.000000          0.0
# 4     2013-01-01 04:00:00          0.000000      0.000000          0.0
# ...                   ...               ...           ...          ...
# 8755  2013-12-31 19:00:00          0.029235      0.024321          0.0
# 8756  2013-12-31 20:00:00          0.034024      0.031357          0.0
# 8757  2013-12-31 21:00:00          0.037104      0.034522          0.0
# 8758  2013-12-31 22:00:00          0.029730      0.027419          0.0
# 8759  2013-12-31 23:00:00          0.017742      0.020761          0.0
#
#       AT0 0 onwind  AT0 0 ror  AT0 0 solar  BA0 0 onwind  BA0 0 solar  \
# 0         0.163262   0.224456          0.0      0.007340          0.0
# 1         0.171340   0.224369          0.0      0.007939          0.0
# 2         0.171035   0.224300          0.0      0.007829          0.0
# 3         0.169685   0.224249          0.0      0.005766          0.0
# 4         0.159757   0.224213          0.0      0.004262          0.0
# ...            ...        ...          ...           ...          ...
# 8755      0.109127   0.275353          0.0      0.001076          0.0
# 8756      0.120485   0.275159          0.0      0.001090          0.0
# 8757      0.128186   0.274975          0.0      0.001062          0.0
# 8758      0.124740   0.274784          0.0      0.001351          0.0
# 8759      0.126570   0.274592          0.0      0.001109          0.0
#
#       BE0 0 offwind-ac  ...  SE4 0 onwind  SE4 0 ror  SE4 0 solar  \
# 0             1.000000  ...      0.459609   0.626955          0.0
# 1             0.999998  ...      0.463265   0.625502          0.0
# 2             0.993941  ...      0.463777   0.624810          0.0
# 3             0.916094  ...      0.463041   0.623794          0.0
# 4             0.704786  ...      0.457253   0.623085          0.0
# ...                ...  ...           ...        ...          ...
# 8755          0.998922  ...      0.358191   0.469586          0.0
# 8756          0.965757  ...      0.324709   0.469395          0.0
# 8757          0.852484  ...      0.288415   0.469208          0.0
# 8758          0.776442  ...      0.268695   0.469028          0.0
# 8759          0.880753  ...      0.245296   0.468856          0.0
#
#       SI0 0 offwind-ac  SI0 0 onwind  SI0 0 ror  SI0 0 solar  SK0 0 onwind  \
# 0             0.000000      0.055146   0.344668          0.0      0.361009
# 1             0.000000      0.052605   0.344657          0.0      0.368912
# 2             0.000000      0.052222   0.344593          0.0      0.382949
# 3             0.000000      0.050762   0.344626          0.0      0.388344
# 4             0.000000      0.047285   0.344607          0.0      0.409303
# ...                ...           ...        ...          ...           ...
# 8755          0.027877      0.001708   0.696975          0.0      0.125735
# 8756          0.023567      0.000000   0.696262          0.0      0.142431
# 8757          0.000000      0.004891   0.695524          0.0      0.153930
# 8758          0.000000      0.009091   0.694665          0.0      0.163442
# 8759          0.000000      0.013554   0.693632          0.0      0.183295
#
#       SK0 0 ror  SK0 0 solar
# 0      0.106197          0.0
# 1      0.106012          0.0
# 2      0.105968          0.0
# 3      0.106215          0.0
# 4      0.106364          0.0
# ...         ...          ...
# 8755   0.157729          0.0
# 8756   0.157817          0.0
# 8757   0.157899          0.0
# 8758   0.157945          0.0
# 8759   0.157963          0.0
#
# [8760 rows x 151 columns]

# %%
class EnergyType(Enum):
    """
    Represents the different type of renewable energy sources in pypsa-eur
    """
    OFFWIND_AC = "offwind-ac"
    OFFWIND_DC = "offwind-dc"
    ONWIND = "onwind-dc"
    SOLAR = "solar"
    ROR = "ror"
    NOT_DEFINED = "not_defined"

class Feature(Enum):
    """
    Represents the features, that can be extracted from the era-5 weather data set
    """
    HEIGHT = "height"
    WND100M = "wnd100m"
    ROUGHNESS = "roughness"
    INFLUX_TOA = "influx_toa"
    INFLUX_DIRECT = "influx_direct"
    INFLUX_DIFFUSE = "influx_diffuse"
    ALBEDO = "albedo"
    TEMPERATURE = "temperature"
    SOIL_TEMPERATURE = "soil_temperature"
    RUNOFF = "runoff"

"""
Determines which features are selected to calculate the capacity factor of a certain energy type.
"""
feature_set = {
    EnergyType.OFFWIND_AC: [Feature.HEIGHT, Feature.WND100M, Feature.ROUGHNESS],
    EnergyType.OFFWIND_DC: [Feature.HEIGHT, Feature.WND100M, Feature.ROUGHNESS],
    EnergyType.ONWIND: [Feature.HEIGHT, Feature.WND100M, Feature.ROUGHNESS],
    EnergyType.SOLAR: [Feature.INFLUX_TOA, Feature.INFLUX_DIRECT, Feature.INFLUX_DIFFUSE, Feature.TEMPERATURE],
    EnergyType.ROR: []
}

def find_countries_in_capfacts(country_name="") -> list:
    """
    Returns the full region names and energy types of the given name abbreviation that can be found in the .csv file with capacity factors.
    :param country_name: Two character abbreviation of the searched country
    :return: list of all regions and energy types to the given country name
    """
    countries = []
    for column in capfacts:
        if column.find(country_name) >= 0:
            countries.append(column)
    return countries


def get_energy_type(name: str) -> EnergyType:
    """
    Returns the energy type for a given string
    :param name: energy type as string
    :return: energy type for the given string
    """
    match name:
        case "offwind-ac":
            return EnergyType.OFFWIND_AC
        case "offwind-dc":
            return EnergyType.OFFWIND_DC
        case "onwind":
            return EnergyType.ONWIND
        case "solar":
            return EnergyType.SOLAR
        case "ror":
            return EnergyType.ROR
        case _:
            return EnergyType.NOT_DEFINED

def get_ds_region_name(region_name: str, energy_type: EnergyType) -> str:
    """
    Returns the name or string that addresses the given region and energy type which can be used to address the data in the feature data set
    :param region_name: name of the region
    :param energy_type: the uses energy type in that region
    :return: string that can be used to fetch data from the feature data set
    """
    ds_region_name = region_name + " 0"
    if energy_type == EnergyType.ONWIND or energy_type == EnergyType.SOLAR or energy_type == EnergyType.ROR:
        ds_region_name += " on"
    elif energy_type == EnergyType.OFFWIND_AC or energy_type == EnergyType.OFFWIND_DC:
        ds_region_name += " off"
    else:
        ds_region_name += ""
    return ds_region_name

def parse_capfac_col(column_name: str) -> (str, EnergyType):
    """
    Returns a tuple of the region name and energy type for a given column name of the capfacts .csv file
    :param column_name: column name of the capfacts .csv file
    :return: Tuple of a region name and energy type, None if no region is found
    """
    col_args = column_name.split(" ")
    if len(col_args) == 3:
        region_name = col_args[0]
        energy_type = get_energy_type(col_args[2])
        return region_name, energy_type
    return None, None

def create_training_data_for_col(column_name: str) -> (np.ndarray, dict):
    """
    Creates and returns the the training data set with the relevant data for a given column name from the capfacts .csv file.
    The training data set is a tuple of a numpy array of capacity factors (target values) and a dictionary of the era5 data (feature data),
    :param column_name: column name of the capfacts .csv file
    :return: Tuple of capacity factor (Y) and trainings data (X)
            X                       : DataFrame object or List or numpy array of predictors (n x p) in Numeric format
            Y                       : DataFrame object or List or numpy array of outcomes (n) in Numeric format.
    """
    region_name, energy_type = parse_capfac_col(column_name)
    # print(region_name)
    # print(energy_type)
    ds_region_name = get_ds_region_name(region_name, energy_type)
    # print(ds_region_name)
    features = feature_set.get(energy_type)
    # print(features)

    Y_capfac = capfacts[column_name].values
    X = {}
    for feature in features:
        X[feature] = ds.sel(region=ds_region_name)[feature.value].values

    return Y_capfac, X


def shape_multi_feature_data(training_data: dict):
    """
    Reshapes the trainingsdata in an array of shape (n_samples, n_features)
    (8760, 2) ---> [[x_f1_1, x_f2_1], [x_f1_2, x_f2_2], ... , [x_f1_8760, x_f2_8760]]
    :param training_data as a dictinary of multiple 1-d arrays:
    :return: trainingsdata in array of shape (n_samples,  n_features)
    """
    # tup = tuple(list(training_data.values()))
    # multi_feature_train_data = np.column_stack(tup)
    arrays = list(training_data.values())
    return np.stack(arrays, axis=-1)

# %%
def get_date_time_obj(date_time_str: str):
    # 2013-01-01 21:00:00
    return datetime.strptime(date_time_str, "%Y-%m-%d %H:%M:%S")

# %%
capfacts_columns = capfacts.columns.values


# capfacts_pred_q40 = pd.DataFrame(columns=capfacts_columns)
capfacts_pred_q40 = pd.DataFrame()
capfacts_pred_q40["snapshot"] = capfacts["snapshot"]

# capfacts_pred_q60 = pd.DataFrame(columns=capfacts_columns)
capfacts_pred_q60 = pd.DataFrame()
capfacts_pred_q60["snapshot"] = capfacts["snapshot"]

# capfacts_pred_q40

df_scores = pd.DataFrame()
df_scores["metric"] = ["RMSE", "RMSE_clipped", "MAE", "MAE_clipped", "NLL", "PL 0.4", "PL 0.4_clipped", "PL 0.6", "PL 0.6_clipped"]
df_scores.set_index("metric", inplace=True)
df_scores
# Out:
# Empty DataFrame
# Columns: []
# Index: [RMSE, RMSE_clipped, MAE, MAE_clipped, NLL, PL 0.4, PL 0.4_clipped, PL 0.6, PL 0.6_clipped]

# %%
col_names = capfacts_columns[1:]

new_columns_q40 = {}
new_columns_q60 = {}
new_columns_scores = {}

i = 1
for col in col_names:
    print("Processing \"", col, "\" (", i, "/", len(col_names), ")")
    i += 1
    region_name, energy_type = parse_capfac_col(col)

    if(energy_type == EnergyType.NOT_DEFINED):
        print("Skipped column: ", col)
        print("-------------------------------------------------------------------")
    elif(energy_type == EnergyType.ROR):
        print("Skipped column: ", col)
        print("-------------------------------------------------------------------")
    else:
        print("Create Trainings data for region: ", region_name, " with energy type: ", energy_type)

        Y, X = create_training_data_for_col(col)
        X_pred = shape_multi_feature_data(X)
        X_train, X_test, Y_train, Y_test = train_test_split(shape_multi_feature_data(X), Y, test_size=0.25, random_state=42)

        print("Fit Regression Model for region ", region_name)
        # ngb = NGBRegressor(random_state=42, verbose=False).fit(X_train, Y_train)
        ngb = NGBRegressor(Dist=Normal, Score=LogScore, n_estimators=1000, random_state=42, verbose=True)
        ngb.fit(X=X_train, Y=Y_train, X_val=X_test, Y_val=Y_test, early_stopping_rounds=2)
        print("Iteration with best validation score: ", ngb.best_val_loss_itr)


        print("Predict capacity factors for region ", region_name)
        # Y_preds = ngb.predict(X_pred, max_iter=ngb.best_val_loss_itr)
        Y_dists = ngb.pred_dist(X_pred, max_iter=ngb.best_val_loss_itr)

        Y_preds_q40 = Y_dists.ppf(0.4)
        new_columns_q40[col] = pd.Series(Y_preds_q40)
        # capfacts_pred_q40[col] = Y_preds_q40

        Y_preds_q60 = Y_dists.ppf(0.6)
        new_columns_q60[col] = pd.Series(Y_preds_q60)
        # capfacts_pred_q60[col] = Y_preds_q60

        Y_preds_q50 = Y_dists.ppf(0.5)
        Y_preds_q50_clipped = Y_preds_q50.clip(min=0, max=1.02)
        Y_preds_q40_clipped = Y_preds_q40.clip(min=0, max=1.02)
        Y_preds_q60_clipped = Y_preds_q60.clip(min=0, max=1.02)

        # Scores and Errors
        # ["RMSE", "MAE", "NLL", "PL 0.4", "PL 0.6"]
        rmse = mean_squared_error(Y, Y_preds_q50, squared=False)
        rmse_clipped = mean_squared_error(Y, Y_preds_q50_clipped, squared=False)
        mae = mean_absolute_error(Y, Y_preds_q50)
        mae_clipped = mean_absolute_error(Y, Y_preds_q50_clipped)
        nll = -Y_dists.logpdf(Y).mean()
        pl40 = mean_pinball_loss(Y, Y_preds_q40, alpha=0.4)
        pl40_clipped = mean_pinball_loss(Y, Y_preds_q40_clipped, alpha=0.4)
        pl60 = mean_pinball_loss(Y, Y_preds_q60, alpha=0.6)
        pl60_clipped = mean_pinball_loss(Y, Y_preds_q60_clipped, alpha=0.6)
        new_columns_scores[col] = pd.Series([rmse, rmse_clipped, mae, mae_clipped, nll, pl40, pl40_clipped, pl60, pl60_clipped])
        print(new_columns_scores[col])


        # print(capfacts_pred.head())
        # print(col, " with q = 0.4")
        # print("Smallest value: ", capfacts_pred_q40[col].min())
        # print("Biggest value: ", capfacts_pred_q40[col].max())
        # print("#Negative Values: ", (capfacts_pred_q40[col] < 0).sum())
        # print("#Values > 1: ", (capfacts_pred_q40[col] > 1).sum())
        # print("Smallest value: ", new_columns_q40[col].min())
        # print("Biggest value: ", new_columns_q40[col].max())
        # print("#Negative Values: ", (new_columns_q40[col] < 0).sum())
        # print("#Values > 1: ", (new_columns_q40[col] > 1).sum())

        # print("")
        # print(col, " with q = 0.6")
        # print("Smallest value: ", capfacts_pred_q40[col].min())
        # print("Biggest value: ", capfacts_pred_q40[col].max())
        # print("#Negative Values: ", (capfacts_pred_q40[col] < 0).sum())
        # print("#Values > 1: ", (capfacts_pred_q40[col] > 1).sum())
        # print("Smallest value: ", new_columns_q60[col].min())
        # print("Biggest value: ", new_columns_q60[col].max())
        # print("#Negative Values: ", (new_columns_q60[col] < 0).sum())
        # print("#Values > 1: ", (new_columns_q60[col] > 1).sum())

        print("-------------------------------------------------------------------")

        print("")

new_columns_q40 = pd.DataFrame(new_columns_q40, index=capfacts_pred_q40.index)
capfacts_pred_q40 = pd.concat([capfacts_pred_q40, new_columns_q40], axis=1)

new_columns_q60 = pd.DataFrame(new_columns_q60, index=capfacts_pred_q60.index)
capfacts_pred_q60 = pd.concat([capfacts_pred_q60, new_columns_q60], axis=1)

# new_columns_scores = pd.DataFrame(new_columns_scores, index=df_scores.index)
# df_scores = pd.concat([df_scores, new_columns_scores], axis=1)
# Out:
# Processing " AL0 0 offwind-ac " ( 1 / 150 )
# Create Trainings data for region:  AL0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  AL0
# [iter 0] loss=-0.1584 val_loss=-0.1838 scale=1.0000 norm=0.6356
# [iter 100] loss=-1.2618 val_loss=-1.2612 scale=2.0000 norm=0.8757
# [iter 200] loss=-1.8433 val_loss=-1.8130 scale=2.0000 norm=0.8696
# [iter 300] loss=-2.1610 val_loss=-2.0969 scale=2.0000 norm=0.9099
# [iter 400] loss=-2.3196 val_loss=-2.2198 scale=2.0000 norm=0.9446
# [iter 500] loss=-2.3965 val_loss=-2.2616 scale=1.0000 norm=0.4721
# == Early stopping achieved.
# == Best iteration / VAL501 (val_loss=-2.2618)
# Iteration with best validation score:  501
# Predict capacity factors for region  AL0
# 0    0.050804
# 1    0.050804
# 2    0.030652
# 3    0.030650
# 4   -2.363303
# 5    0.014406
# 6    0.014405
# 7    0.015196
# 8    0.015195
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " AL0 0 onwind " ( 2 / 150 )
# Create Trainings data for region:  AL0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  AL0
# [iter 0] loss=-0.9390 val_loss=-0.9570 scale=1.0000 norm=0.6718
# [iter 100] loss=-2.0101 val_loss=-1.9971 scale=2.0000 norm=0.8425
# [iter 200] loss=-2.5112 val_loss=-2.4705 scale=2.0000 norm=0.8449
# [iter 300] loss=-2.7390 val_loss=-2.6831 scale=1.0000 norm=0.4337
# [iter 400] loss=-2.8178 val_loss=-2.7534 scale=1.0000 norm=0.4451
# [iter 500] loss=-2.8520 val_loss=-2.7772 scale=2.0000 norm=0.9059
# == Early stopping achieved.
# == Best iteration / VAL514 (val_loss=-2.7787)
# Iteration with best validation score:  514
# Predict capacity factors for region  AL0
# 0    0.026913
# 1    0.026913
# 2    0.016851
# 3    0.016845
# 4   -2.836191
# 5    0.007981
# 6    0.007976
# 7    0.008268
# 8    0.008267
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " AL0 0 solar " ( 3 / 150 )
# Create Trainings data for region:  AL0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  AL0
# [iter 0] loss=-0.2278 val_loss=-0.2428 scale=1.0000 norm=0.5255
# [iter 100] loss=-1.1825 val_loss=-1.1845 scale=2.0000 norm=0.8545
# [iter 200] loss=-1.8062 val_loss=-1.7967 scale=2.0000 norm=0.9133
# [iter 300] loss=-2.4698 val_loss=-2.4466 scale=2.0000 norm=0.9175
# [iter 400] loss=-2.8980 val_loss=-2.8631 scale=2.0000 norm=0.8387
# == Early stopping achieved.
# == Best iteration / VAL452 (val_loss=-2.9428)
# Iteration with best validation score:  452
# Predict capacity factors for region  AL0
# 0    0.057449
# 1    0.057426
# 2    0.032054
# 3    0.031692
# 4   -2.973177
# 5    0.015304
# 6    0.015097
# 7    0.015600
# 8    0.015458
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " AT0 0 onwind " ( 4 / 150 )
# Create Trainings data for region:  AT0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  AT0
# [iter 0] loss=-0.4285 val_loss=-0.4352 scale=1.0000 norm=0.5963
# [iter 100] loss=-1.4889 val_loss=-1.4863 scale=2.0000 norm=0.8276
# [iter 200] loss=-1.9820 val_loss=-1.9667 scale=2.0000 norm=0.8207
# [iter 300] loss=-2.1775 val_loss=-2.1452 scale=2.0000 norm=0.8724
# [iter 400] loss=-2.2346 val_loss=-2.1898 scale=1.0000 norm=0.4523
# [iter 500] loss=-2.2595 val_loss=-2.2046 scale=0.5000 norm=0.2301
# == Early stopping achieved.
# == Best iteration / VAL521 (val_loss=-2.2058)
# Iteration with best validation score:  521
# Predict capacity factors for region  AT0
# 0    0.038160
# 1    0.038157
# 2    0.026140
# 3    0.026137
# 4   -2.248328
# 5    0.012449
# 6    0.012447
# 7    0.012839
# 8    0.012838
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " AT0 0 ror " ( 5 / 150 )
# Skipped column:  AT0 0 ror
# -------------------------------------------------------------------
# Processing " AT0 0 solar " ( 6 / 150 )
# Create Trainings data for region:  AT0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  AT0
# [iter 0] loss=-0.4390 val_loss=-0.4813 scale=1.0000 norm=0.5466
# [iter 100] loss=-1.4145 val_loss=-1.4216 scale=2.0000 norm=0.8615
# [iter 200] loss=-2.0291 val_loss=-2.0202 scale=2.0000 norm=0.9167
# [iter 300] loss=-2.7349 val_loss=-2.6998 scale=2.0000 norm=0.9035
# [iter 400] loss=-3.0866 val_loss=-3.0365 scale=1.0000 norm=0.4045
# [iter 500] loss=-3.2411 val_loss=-3.1844 scale=2.0000 norm=0.7435
# == Early stopping achieved.
# == Best iteration / VAL543 (val_loss=-3.2230)
# Iteration with best validation score:  543
# Predict capacity factors for region  AT0
# 0    0.048020
# 1    0.048005
# 2    0.026922
# 3    0.026694
# 4   -3.269157
# 5    0.012867
# 6    0.012739
# 7    0.013153
# 8    0.013050
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BA0 0 onwind " ( 7 / 150 )
# Create Trainings data for region:  BA0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  BA0
# [iter 0] loss=-1.0691 val_loss=-1.1838 scale=1.0000 norm=0.7111
# [iter 100] loss=-2.2515 val_loss=-2.2427 scale=2.0000 norm=0.8991
# [iter 200] loss=-2.8635 val_loss=-2.8199 scale=2.0000 norm=0.8812
# [iter 300] loss=-3.1596 val_loss=-3.0719 scale=2.0000 norm=0.9114
# [iter 400] loss=-3.2821 val_loss=-3.1529 scale=2.0000 norm=0.9497
# == Early stopping achieved.
# == Best iteration / VAL460 (val_loss=-3.1679)
# Iteration with best validation score:  460
# Predict capacity factors for region  BA0
# 0    0.017360
# 1    0.017360
# 2    0.010407
# 3    0.010407
# 4   -3.277351
# 5    0.004741
# 6    0.004741
# 7    0.005297
# 8    0.005297
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BA0 0 solar " ( 8 / 150 )
# Create Trainings data for region:  BA0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  BA0
# [iter 0] loss=-0.3381 val_loss=-0.3538 scale=1.0000 norm=0.5527
# [iter 100] loss=-1.3179 val_loss=-1.3192 scale=2.0000 norm=0.8636
# [iter 200] loss=-1.9209 val_loss=-1.9134 scale=2.0000 norm=0.9180
# [iter 300] loss=-2.5658 val_loss=-2.5361 scale=2.0000 norm=0.8875
# [iter 400] loss=-2.9456 val_loss=-2.8865 scale=2.0000 norm=0.8129
# == Early stopping achieved.
# == Best iteration / VAL479 (val_loss=-3.0222)
# Iteration with best validation score:  479
# Predict capacity factors for region  BA0
# 0    0.051495
# 1    0.051458
# 2    0.028661
# 3    0.028202
# 4   -3.090649
# 5    0.013712
# 6    0.013462
# 7    0.013954
# 8    0.013756
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BE0 0 offwind-ac " ( 9 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  BE0
# [iter 0] loss=0.3998 val_loss=0.3810 scale=1.0000 norm=0.4992
# [iter 100] loss=-0.7195 val_loss=-0.7224 scale=2.0000 norm=0.8990
# [iter 200] loss=-1.4769 val_loss=-1.4430 scale=2.0000 norm=0.8973
# [iter 300] loss=-1.9093 val_loss=-1.7741 scale=2.0000 norm=0.9564
# == Early stopping achieved.
# == Best iteration / VAL340 (val_loss=-1.8102)
# Iteration with best validation score:  340
# Predict capacity factors for region  BE0
# 0    0.041656
# 1    0.041656
# 2    0.026586
# 3    0.026585
# 4   -1.967397
# 5    0.013059
# 6    0.013024
# 7    0.013006
# 8    0.013006
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BE0 0 offwind-dc " ( 10 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  BE0
# [iter 0] loss=0.4471 val_loss=0.4366 scale=1.0000 norm=0.4880
# [iter 100] loss=-0.6311 val_loss=-0.6262 scale=2.0000 norm=0.8898
# [iter 200] loss=-1.3255 val_loss=-1.2739 scale=2.0000 norm=0.9330
# [iter 300] loss=-1.7635 val_loss=-1.6484 scale=2.0000 norm=1.0042
# == Early stopping achieved.
# == Best iteration / VAL394 (val_loss=-1.7569)
# Iteration with best validation score:  394
# Predict capacity factors for region  BE0
# 0    0.055211
# 1    0.055211
# 2    0.032362
# 3    0.032362
# 4   -1.950351
# 5    0.015838
# 6    0.015837
# 7    0.015709
# 8    0.015709
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BE0 0 onwind " ( 11 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  BE0
# [iter 0] loss=0.1253 val_loss=0.0978 scale=1.0000 norm=0.5432
# [iter 100] loss=-0.9953 val_loss=-1.0096 scale=2.0000 norm=0.8905
# [iter 200] loss=-1.6838 val_loss=-1.6874 scale=2.0000 norm=0.8522
# [iter 300] loss=-1.9982 val_loss=-1.9682 scale=2.0000 norm=0.8954
# [iter 400] loss=-2.0924 val_loss=-2.0370 scale=2.0000 norm=0.9483
# [iter 500] loss=-2.1261 val_loss=-2.0541 scale=2.0000 norm=0.9665
# == Early stopping achieved.
# == Best iteration / VAL535 (val_loss=-2.0572)
# Iteration with best validation score:  535
# Predict capacity factors for region  BE0
# 0    0.037322
# 1    0.037322
# 2    0.026115
# 3    0.026114
# 4   -2.114738
# 5    0.012289
# 6    0.012289
# 7    0.012982
# 8    0.012981
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BE0 0 ror " ( 12 / 150 )
# Skipped column:  BE0 0 ror
# -------------------------------------------------------------------
# Processing " BE0 0 solar " ( 13 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  BE0
# [iter 0] loss=-0.4609 val_loss=-0.5196 scale=1.0000 norm=0.5866
# [iter 100] loss=-1.4141 val_loss=-1.4219 scale=2.0000 norm=0.8906
# [iter 200] loss=-2.0871 val_loss=-2.0969 scale=4.0000 norm=1.8745
# [iter 300] loss=-2.7428 val_loss=-2.7492 scale=1.0000 norm=0.4560
# [iter 400] loss=-3.0227 val_loss=-3.0292 scale=2.0000 norm=0.8326
# == Early stopping achieved.
# == Best iteration / VAL432 (val_loss=-3.0771)
# Iteration with best validation score:  432
# Predict capacity factors for region  BE0
# 0    0.053380
# 1    0.053363
# 2    0.029072
# 3    0.028894
# 4   -3.075125
# 5    0.013550
# 6    0.013451
# 7    0.014476
# 8    0.014403
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BG0 0 offwind-ac " ( 14 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  BG0
# [iter 0] loss=0.1527 val_loss=0.1034 scale=1.0000 norm=0.5867
# [iter 100] loss=-0.6903 val_loss=-0.6909 scale=2.0000 norm=0.8688
# [iter 200] loss=-1.0286 val_loss=-0.9909 scale=2.0000 norm=0.9325
# [iter 300] loss=-1.1588 val_loss=-1.0784 scale=2.0000 norm=0.9783
# == Early stopping achieved.
# == Best iteration / VAL357 (val_loss=-1.0879)
# Iteration with best validation score:  357
# Predict capacity factors for region  BG0
# 0    0.109061
# 1    0.109059
# 2    0.073357
# 3    0.073355
# 4   -1.165185
# 5    0.034442
# 6    0.034442
# 7    0.036376
# 8    0.036372
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BG0 0 offwind-dc " ( 15 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  BG0
# [iter 0] loss=0.1964 val_loss=0.1548 scale=1.0000 norm=0.6057
# [iter 100] loss=-0.6023 val_loss=-0.5938 scale=2.0000 norm=0.8843
# [iter 200] loss=-0.9043 val_loss=-0.8486 scale=2.0000 norm=0.9471
# == Early stopping achieved.
# == Best iteration / VAL295 (val_loss=-0.9040)
# Iteration with best validation score:  295
# Predict capacity factors for region  BG0
# 0    0.130032
# 1    0.130031
# 2    0.086915
# 3    0.086910
# 4   -0.989636
# 5    0.040595
# 6    0.040594
# 7    0.043190
# 8    0.043183
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BG0 0 onwind " ( 16 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  BG0
# [iter 0] loss=-0.4756 val_loss=-0.5313 scale=1.0000 norm=0.6106
# [iter 100] loss=-1.5675 val_loss=-1.5777 scale=2.0000 norm=0.8305
# [iter 200] loss=-2.0852 val_loss=-2.0718 scale=2.0000 norm=0.7954
# [iter 300] loss=-2.2859 val_loss=-2.2411 scale=1.0000 norm=0.4255
# [iter 400] loss=-2.3414 val_loss=-2.2762 scale=1.0000 norm=0.4425
# [iter 500] loss=-2.3660 val_loss=-2.2856 scale=1.0000 norm=0.4517
# == Early stopping achieved.
# == Best iteration / VAL507 (val_loss=-2.2862)
# Iteration with best validation score:  507
# Predict capacity factors for region  BG0
# 0    0.033147
# 1    0.033147
# 2    0.023061
# 3    0.023059
# 4   -2.347226
# 5    0.010931
# 6    0.010930
# 7    0.011325
# 8    0.011325
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " BG0 0 ror " ( 17 / 150 )
# Skipped column:  BG0 0 ror
# -------------------------------------------------------------------
# Processing " BG0 0 solar " ( 18 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  BG0
# [iter 0] loss=-0.2685 val_loss=-0.2822 scale=1.0000 norm=0.5291
# [iter 100] loss=-1.2675 val_loss=-1.2656 scale=2.0000 norm=0.8605
# [iter 200] loss=-1.9217 val_loss=-1.9096 scale=4.0000 norm=1.8245
# [iter 300] loss=-2.5611 val_loss=-2.5255 scale=4.0000 norm=1.8216
# [iter 400] loss=-2.9343 val_loss=-2.8786 scale=2.0000 norm=0.8533
# [iter 500] loss=-3.1480 val_loss=-3.0688 scale=0.2500 norm=0.0964
# == Early stopping achieved.
# == Best iteration / VAL539 (val_loss=-3.1160)
# Iteration with best validation score:  539
# Predict capacity factors for region  BG0
# 0    0.049001
# 1    0.048986
# 2    0.026974
# 3    0.026724
# 4   -3.179487
# 5    0.013018
# 6    0.012874
# 7    0.013022
# 8    0.012922
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " CH0 0 onwind " ( 19 / 150 )
# Create Trainings data for region:  CH0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  CH0
# [iter 0] loss=-1.1723 val_loss=-1.2758 scale=2.0000 norm=1.4018
# [iter 100] loss=-2.2086 val_loss=-2.2157 scale=2.0000 norm=0.8429
# [iter 200] loss=-2.6831 val_loss=-2.6792 scale=2.0000 norm=0.8400
# [iter 300] loss=-2.9017 val_loss=-2.8754 scale=2.0000 norm=0.8594
# [iter 400] loss=-2.9817 val_loss=-2.9331 scale=2.0000 norm=0.8696
# == Early stopping achieved.
# == Best iteration / VAL450 (val_loss=-2.9410)
# Iteration with best validation score:  450
# Predict capacity factors for region  CH0
# 0    0.027540
# 1    0.027539
# 2    0.016231
# 3    0.016220
# 4   -2.986714
# 5    0.007637
# 6    0.007626
# 7    0.008025
# 8    0.008022
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " CH0 0 ror " ( 20 / 150 )
# Skipped column:  CH0 0 ror
# -------------------------------------------------------------------
# Processing " CH0 0 solar " ( 21 / 150 )
# Create Trainings data for region:  CH0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  CH0
# [iter 0] loss=-0.4202 val_loss=-0.4511 scale=1.0000 norm=0.5508
# [iter 100] loss=-1.3786 val_loss=-1.3781 scale=2.0000 norm=0.8602
# [iter 200] loss=-1.9730 val_loss=-1.9601 scale=2.0000 norm=0.9090
# [iter 300] loss=-2.6545 val_loss=-2.6229 scale=2.0000 norm=0.8973
# [iter 400] loss=-2.9965 val_loss=-2.9470 scale=2.0000 norm=0.8019
# [iter 500] loss=-3.1606 val_loss=-3.0960 scale=0.5000 norm=0.1787
# == Early stopping achieved.
# == Best iteration / VAL517 (val_loss=-3.1130)
# Iteration with best validation score:  517
# Predict capacity factors for region  CH0
# 0    0.051655
# 1    0.051628
# 2    0.029583
# 3    0.029306
# 4   -3.162230
# 5    0.014019
# 6    0.013865
# 7    0.014429
# 8    0.014310
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " CZ0 0 onwind " ( 22 / 150 )
# Create Trainings data for region:  CZ0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  CZ0
# [iter 0] loss=-0.2673 val_loss=-0.2723 scale=1.0000 norm=0.5835
# [iter 100] loss=-1.4610 val_loss=-1.4601 scale=2.0000 norm=0.9149
# [iter 200] loss=-2.2478 val_loss=-2.2201 scale=2.0000 norm=0.8865
# [iter 300] loss=-2.6794 val_loss=-2.6004 scale=2.0000 norm=0.8896
# [iter 400] loss=-2.8434 val_loss=-2.7218 scale=1.0000 norm=0.4671
# [iter 500] loss=-2.8923 val_loss=-2.7541 scale=1.0000 norm=0.4753
# == Early stopping achieved.
# == Best iteration / VAL533 (val_loss=-2.7575)
# Iteration with best validation score:  533
# Predict capacity factors for region  CZ0
# 0    0.019098
# 1    0.019098
# 2    0.012802
# 3    0.012802
# 4   -2.864601
# 5    0.005893
# 6    0.005892
# 7    0.006492
# 8    0.006492
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " CZ0 0 ror " ( 23 / 150 )
# Skipped column:  CZ0 0 ror
# -------------------------------------------------------------------
# Processing " CZ0 0 solar " ( 24 / 150 )
# Create Trainings data for region:  CZ0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  CZ0
# [iter 0] loss=-0.4636 val_loss=-0.5093 scale=1.0000 norm=0.5926
# [iter 100] loss=-1.4681 val_loss=-1.4716 scale=2.0000 norm=0.8742
# [iter 200] loss=-2.1482 val_loss=-2.1405 scale=2.0000 norm=0.9232
# [iter 300] loss=-2.7818 val_loss=-2.7681 scale=4.0000 norm=1.7942
# [iter 400] loss=-3.1365 val_loss=-3.1102 scale=2.0000 norm=0.8201
# == Early stopping achieved.
# == Best iteration / VAL460 (val_loss=-3.1644)
# Iteration with best validation score:  460
# Predict capacity factors for region  CZ0
# 0    0.046836
# 1    0.046819
# 2    0.025838
# 3    0.025626
# 4   -3.188472
# 5    0.012189
# 6    0.012060
# 7    0.012714
# 8    0.012627
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DE0 0 offwind-ac " ( 25 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  DE0
# [iter 0] loss=0.2968 val_loss=0.2897 scale=1.0000 norm=0.4943
# [iter 100] loss=-0.3194 val_loss=-0.3076 scale=2.0000 norm=0.7964
# [iter 200] loss=-0.5414 val_loss=-0.5107 scale=2.0000 norm=0.9184
# [iter 300] loss=-0.6186 val_loss=-0.5741 scale=2.0000 norm=0.9637
# [iter 400] loss=-0.6536 val_loss=-0.5946 scale=2.0000 norm=0.9693
# == Early stopping achieved.
# == Best iteration / VAL406 (val_loss=-0.5950)
# Iteration with best validation score:  406
# Predict capacity factors for region  DE0
# 0    0.151110
# 1    0.151110
# 2    0.115547
# 3    0.115547
# 4   -0.640216
# 5    0.055207
# 6    0.055207
# 7    0.056196
# 8    0.056196
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DE0 0 offwind-dc " ( 26 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  DE0
# [iter 0] loss=0.4033 val_loss=0.3818 scale=1.0000 norm=0.4695
# [iter 100] loss=-0.4495 val_loss=-0.4494 scale=2.0000 norm=0.8152
# [iter 200] loss=-0.9631 val_loss=-0.9207 scale=2.0000 norm=0.8876
# [iter 300] loss=-1.2175 val_loss=-1.1063 scale=2.0000 norm=0.9665
# == Early stopping achieved.
# == Best iteration / VAL352 (val_loss=-1.1296)
# Iteration with best validation score:  352
# Predict capacity factors for region  DE0
# 0    0.095692
# 1    0.095692
# 2    0.065346
# 3    0.065346
# 4   -1.248408
# 5    0.032071
# 6    0.032071
# 7    0.031104
# 8    0.031103
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DE0 0 onwind " ( 27 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  DE0
# [iter 0] loss=-0.1823 val_loss=-0.1803 scale=1.0000 norm=0.5700
# [iter 100] loss=-1.2747 val_loss=-1.2746 scale=2.0000 norm=0.8457
# [iter 200] loss=-1.8206 val_loss=-1.8088 scale=2.0000 norm=0.8330
# [iter 300] loss=-2.0442 val_loss=-2.0083 scale=2.0000 norm=0.8699
# [iter 400] loss=-2.1063 val_loss=-2.0439 scale=1.0000 norm=0.4538
# == Early stopping achieved.
# == Best iteration / VAL456 (val_loss=-2.0479)
# Iteration with best validation score:  456
# Predict capacity factors for region  DE0
# 0    0.035214
# 1    0.035214
# 2    0.026040
# 3    0.026040
# 4   -2.100561
# 5    0.012033
# 6    0.012033
# 7    0.013105
# 8    0.013105
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DE0 0 ror " ( 28 / 150 )
# Skipped column:  DE0 0 ror
# -------------------------------------------------------------------
# Processing " DE0 0 solar " ( 29 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  DE0
# [iter 0] loss=-0.5275 val_loss=-0.5841 scale=1.0000 norm=0.5604
# [iter 100] loss=-1.5342 val_loss=-1.5469 scale=2.0000 norm=0.8648
# [iter 200] loss=-2.1624 val_loss=-2.1746 scale=4.0000 norm=1.8335
# [iter 300] loss=-2.8201 val_loss=-2.8291 scale=4.0000 norm=1.8162
# [iter 400] loss=-3.1044 val_loss=-3.1013 scale=1.0000 norm=0.4096
# == Early stopping achieved.
# == Best iteration / VAL438 (val_loss=-3.1355)
# Iteration with best validation score:  438
# Predict capacity factors for region  DE0
# 0    0.039891
# 1    0.039872
# 2    0.022742
# 3    0.022499
# 4   -3.139513
# 5    0.010780
# 6    0.010621
# 7    0.011221
# 8    0.011128
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK0 0 offwind-ac " ( 30 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  DK0
# [iter 0] loss=0.2918 val_loss=0.2847 scale=1.0000 norm=0.4895
# [iter 100] loss=-0.5794 val_loss=-0.5882 scale=2.0000 norm=0.8071
# [iter 200] loss=-0.9640 val_loss=-0.9711 scale=2.0000 norm=0.8880
# [iter 300] loss=-1.1154 val_loss=-1.1151 scale=2.0000 norm=0.9556
# [iter 400] loss=-1.1762 val_loss=-1.1642 scale=2.0000 norm=0.9759
# [iter 500] loss=-1.2099 val_loss=-1.1822 scale=1.0000 norm=0.4883
# == Early stopping achieved.
# == Best iteration / VAL506 (val_loss=-1.1829)
# Iteration with best validation score:  506
# Predict capacity factors for region  DK0
# 0    0.092726
# 1    0.092726
# 2    0.067256
# 3    0.067256
# 4   -1.204459
# 5    0.032764
# 6    0.032764
# 7    0.032334
# 8    0.032334
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK0 0 offwind-dc " ( 31 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  DK0
# [iter 0] loss=0.3252 val_loss=0.3033 scale=1.0000 norm=0.4723
# [iter 100] loss=-0.5031 val_loss=-0.5127 scale=2.0000 norm=0.8031
# [iter 200] loss=-1.0104 val_loss=-1.0016 scale=2.0000 norm=0.8775
# [iter 300] loss=-1.2601 val_loss=-1.2238 scale=2.0000 norm=0.9439
# [iter 400] loss=-1.3790 val_loss=-1.3032 scale=2.0000 norm=0.9794
# == Early stopping achieved.
# == Best iteration / VAL466 (val_loss=-1.3209)
# Iteration with best validation score:  466
# Predict capacity factors for region  DK0
# 0    0.085065
# 1    0.085065
# 2    0.059548
# 3    0.059548
# 4   -1.397664
# 5    0.028878
# 6    0.028878
# 7    0.028633
# 8    0.028633
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK0 0 onwind " ( 32 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  DK0
# [iter 0] loss=0.2619 val_loss=0.2526 scale=1.0000 norm=0.5103
# [iter 100] loss=-0.9120 val_loss=-0.9200 scale=2.0000 norm=0.9251
# [iter 200] loss=-1.7927 val_loss=-1.7888 scale=2.0000 norm=0.8871
# [iter 300] loss=-2.3313 val_loss=-2.2855 scale=2.0000 norm=0.8627
# [iter 400] loss=-2.5099 val_loss=-2.4094 scale=2.0000 norm=0.9418
# == Early stopping achieved.
# == Best iteration / VAL490 (val_loss=-2.4298)
# Iteration with best validation score:  490
# Predict capacity factors for region  DK0
# 0    0.021708
# 1    0.021708
# 2    0.015685
# 3    0.015685
# 4   -2.533888
# 5    0.007460
# 6    0.007460
# 7    0.007704
# 8    0.007704
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK0 0 solar " ( 33 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  DK0
# [iter 0] loss=-0.4344 val_loss=-0.5082 scale=1.0000 norm=0.5969
# [iter 100] loss=-1.4222 val_loss=-1.4366 scale=2.0000 norm=0.8708
# [iter 200] loss=-2.1007 val_loss=-2.1188 scale=4.0000 norm=1.8609
# [iter 300] loss=-2.8084 val_loss=-2.8205 scale=1.0000 norm=0.4591
# [iter 400] loss=-3.1032 val_loss=-3.1098 scale=0.0312 norm=0.0127
# == Early stopping achieved.
# == Best iteration / VAL399 (val_loss=-3.1098)
# Iteration with best validation score:  399
# Predict capacity factors for region  DK0
# 0    0.052208
# 1    0.052199
# 2    0.028963
# 3    0.028807
# 4   -3.104852
# 5    0.013576
# 6    0.013478
# 7    0.014339
# 8    0.014282
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK4 0 offwind-ac " ( 34 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  DK4
# [iter 0] loss=0.3530 val_loss=0.3461 scale=1.0000 norm=0.5002
# [iter 100] loss=-0.6433 val_loss=-0.6514 scale=2.0000 norm=0.8444
# [iter 200] loss=-1.1384 val_loss=-1.1447 scale=2.0000 norm=0.8845
# [iter 300] loss=-1.3591 val_loss=-1.3611 scale=2.0000 norm=0.9444
# [iter 400] loss=-1.4620 val_loss=-1.4545 scale=2.0000 norm=0.9674
# [iter 500] loss=-1.5099 val_loss=-1.4907 scale=1.0000 norm=0.4850
# == Early stopping achieved.
# == Best iteration / VAL594 (val_loss=-1.5015)
# Iteration with best validation score:  594
# Predict capacity factors for region  DK4
# 0    0.073776
# 1    0.073774
# 2    0.051873
# 3    0.051863
# 4   -1.524180
# 5    0.024737
# 6    0.024728
# 7    0.025300
# 8    0.025295
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK4 0 offwind-dc " ( 35 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  DK4
# [iter 0] loss=0.4133 val_loss=0.4033 scale=1.0000 norm=0.4826
# [iter 100] loss=-0.5186 val_loss=-0.5210 scale=2.0000 norm=0.8322
# [iter 200] loss=-1.0344 val_loss=-1.0166 scale=2.0000 norm=0.8953
# [iter 300] loss=-1.3008 val_loss=-1.2459 scale=2.0000 norm=0.9628
# [iter 400] loss=-1.4386 val_loss=-1.3602 scale=2.0000 norm=0.9748
# [iter 500] loss=-1.4932 val_loss=-1.3995 scale=1.0000 norm=0.4828
# [iter 600] loss=-1.5153 val_loss=-1.4107 scale=1.0000 norm=0.4800
# == Early stopping achieved.
# == Best iteration / VAL603 (val_loss=-1.4107)
# Iteration with best validation score:  603
# Predict capacity factors for region  DK4
# 0    0.085987
# 1    0.085984
# 2    0.057919
# 3    0.057909
# 4   -1.489565
# 5    0.027738
# 6    0.027731
# 7    0.028189
# 8    0.028186
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK4 0 onwind " ( 36 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  DK4
# [iter 0] loss=0.3538 val_loss=0.3354 scale=2.0000 norm=1.0065
# [iter 100] loss=-0.7912 val_loss=-0.7946 scale=2.0000 norm=0.9024
# [iter 200] loss=-1.5839 val_loss=-1.5703 scale=2.0000 norm=0.8743
# [iter 300] loss=-2.0362 val_loss=-1.9815 scale=2.0000 norm=0.9238
# [iter 400] loss=-2.2478 val_loss=-2.1619 scale=2.0000 norm=0.9867
# == Early stopping achieved.
# == Best iteration / VAL483 (val_loss=-2.2077)
# Iteration with best validation score:  483
# Predict capacity factors for region  DK4
# 0    0.032404
# 1    0.032404
# 2    0.021866
# 3    0.021865
# 4   -2.303485
# 5    0.010285
# 6    0.010280
# 7    0.010897
# 8    0.010897
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " DK4 0 solar " ( 37 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  DK4
# [iter 0] loss=-0.3840 val_loss=-0.4469 scale=1.0000 norm=0.6007
# [iter 100] loss=-1.3524 val_loss=-1.3584 scale=2.0000 norm=0.8889
# [iter 200] loss=-2.0718 val_loss=-2.0666 scale=4.0000 norm=1.8891
# [iter 300] loss=-2.6990 val_loss=-2.6816 scale=4.0000 norm=1.8296
# [iter 400] loss=-2.9722 val_loss=-2.9436 scale=0.5000 norm=0.2060
# == Early stopping achieved.
# == Best iteration / VAL453 (val_loss=-3.0012)
# Iteration with best validation score:  453
# Predict capacity factors for region  DK4
# 0    0.059186
# 1    0.059176
# 2    0.032378
# 3    0.032201
# 4   -3.024861
# 5    0.015099
# 6    0.014998
# 7    0.016080
# 8    0.016006
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " EE6 0 offwind-ac " ( 38 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  EE6
# [iter 0] loss=0.3389 val_loss=0.3175 scale=2.0000 norm=1.0127
# [iter 100] loss=-0.8177 val_loss=-0.8235 scale=2.0000 norm=0.9106
# [iter 200] loss=-1.6305 val_loss=-1.6242 scale=2.0000 norm=0.8772
# [iter 300] loss=-2.0728 val_loss=-2.0363 scale=2.0000 norm=0.9149
# [iter 400] loss=-2.2254 val_loss=-2.1537 scale=2.0000 norm=0.9930
# [iter 500] loss=-2.2782 val_loss=-2.1777 scale=2.0000 norm=1.0122
# == Early stopping achieved.
# == Best iteration / VAL504 (val_loss=-2.1783)
# Iteration with best validation score:  504
# Predict capacity factors for region  EE6
# 0    0.030582
# 1    0.030582
# 2    0.021521
# 3    0.021521
# 4   -2.254604
# 5    0.010286
# 6    0.010286
# 7    0.010582
# 8    0.010582
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " EE6 0 offwind-dc " ( 39 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  EE6
# [iter 0] loss=0.4173 val_loss=0.4042 scale=1.0000 norm=0.5017
# [iter 100] loss=-0.5340 val_loss=-0.5431 scale=2.0000 norm=0.8507
# [iter 200] loss=-1.0130 val_loss=-1.0095 scale=2.0000 norm=0.9337
# [iter 300] loss=-1.2785 val_loss=-1.2433 scale=1.0000 norm=0.4929
# [iter 400] loss=-1.4249 val_loss=-1.3363 scale=1.0000 norm=0.4986
# == Early stopping achieved.
# == Best iteration / VAL416 (val_loss=-1.3398)
# Iteration with best validation score:  416
# Predict capacity factors for region  EE6
# 0    0.089145
# 1    0.089143
# 2    0.059148
# 3    0.059140
# 4   -1.416819
# 5    0.028553
# 6    0.028548
# 7    0.028748
# 8    0.028742
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " EE6 0 onwind " ( 40 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  EE6
# [iter 0] loss=0.1453 val_loss=0.1263 scale=1.0000 norm=0.5359
# [iter 100] loss=-1.0366 val_loss=-1.0446 scale=2.0000 norm=0.9286
# [iter 200] loss=-1.9266 val_loss=-1.9285 scale=2.0000 norm=0.9115
# [iter 300] loss=-2.5075 val_loss=-2.4878 scale=2.0000 norm=0.8867
# [iter 400] loss=-2.7151 val_loss=-2.6649 scale=2.0000 norm=0.9588
# [iter 500] loss=-2.7686 val_loss=-2.6937 scale=1.0000 norm=0.5011
# == Early stopping achieved.
# == Best iteration / VAL499 (val_loss=-2.6937)
# Iteration with best validation score:  499
# Predict capacity factors for region  EE6
# 0    0.017595
# 1    0.017595
# 2    0.012554
# 3    0.012554
# 4   -2.749899
# 5    0.005736
# 6    0.005736
# 7    0.006392
# 8    0.006392
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " EE6 0 solar " ( 41 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  EE6
# [iter 0] loss=-0.4198 val_loss=-0.4716 scale=1.0000 norm=0.6036
# [iter 100] loss=-1.4149 val_loss=-1.4220 scale=2.0000 norm=0.8825
# [iter 200] loss=-2.0919 val_loss=-2.0807 scale=2.0000 norm=0.9384
# [iter 300] loss=-2.7702 val_loss=-2.7344 scale=2.0000 norm=0.9354
# [iter 400] loss=-3.1235 val_loss=-3.0731 scale=2.0000 norm=0.8390
# == Early stopping achieved.
# == Best iteration / VAL467 (val_loss=-3.1712)
# Iteration with best validation score:  467
# Predict capacity factors for region  EE6
# 0    0.050048
# 1    0.050022
# 2    0.027038
# 3    0.026839
# 4   -3.215965
# 5    0.012691
# 6    0.012582
# 7    0.013362
# 8    0.013275
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES0 0 offwind-ac " ( 42 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  ES0
# [iter 0] loss=-0.2493 val_loss=-0.2568 scale=1.0000 norm=0.4966
# [iter 100] loss=-0.5477 val_loss=-0.5354 scale=2.0000 norm=0.7810
# [iter 200] loss=-0.6327 val_loss=-0.6049 scale=2.0000 norm=0.8743
# [iter 300] loss=-0.6589 val_loss=-0.6156 scale=2.0000 norm=0.8998
# == Early stopping achieved.
# == Best iteration / VAL320 (val_loss=-0.6161)
# Iteration with best validation score:  320
# Predict capacity factors for region  ES0
# 0    0.132636
# 1    0.132636
# 2    0.108829
# 3    0.108829
# 4   -0.651112
# 5    0.050540
# 6    0.050540
# 7    0.054245
# 8    0.054245
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES0 0 offwind-dc " ( 43 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  ES0
# [iter 0] loss=0.3329 val_loss=0.3343 scale=1.0000 norm=0.5854
# [iter 100] loss=-0.0564 val_loss=-0.0575 scale=2.0000 norm=1.0150
# [iter 200] loss=-0.1572 val_loss=-0.1329 scale=2.0000 norm=1.0922
# == Early stopping achieved.
# == Best iteration / VAL297 (val_loss=-0.1465)
# Iteration with best validation score:  297
# Predict capacity factors for region  ES0
# 0    0.251254
# 1    0.251254
# 2    0.186328
# 3    0.186328
# 4   -0.179340
# 5    0.084032
# 6    0.084032
# 7    0.094509
# 8    0.094509
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES0 0 onwind " ( 44 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  ES0
# [iter 0] loss=-0.4134 val_loss=-0.4348 scale=1.0000 norm=0.5331
# [iter 100] loss=-1.5225 val_loss=-1.5292 scale=2.0000 norm=0.8310
# [iter 200] loss=-2.0811 val_loss=-2.0787 scale=2.0000 norm=0.7693
# [iter 300] loss=-2.2613 val_loss=-2.2359 scale=2.0000 norm=0.8516
# [iter 400] loss=-2.3055 val_loss=-2.2584 scale=1.0000 norm=0.4512
# == Early stopping achieved.
# == Best iteration / VAL426 (val_loss=-2.2595)
# Iteration with best validation score:  426
# Predict capacity factors for region  ES0
# 0    0.026506
# 1    0.026506
# 2    0.020751
# 3    0.020751
# 4   -2.298071
# 5    0.009867
# 6    0.009867
# 7    0.010183
# 8    0.010183
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES0 0 ror " ( 45 / 150 )
# Skipped column:  ES0 0 ror
# -------------------------------------------------------------------
# Processing " ES0 0 solar " ( 46 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  ES0
# [iter 0] loss=-0.1757 val_loss=-0.1970 scale=1.0000 norm=0.4692
# [iter 100] loss=-1.0722 val_loss=-1.0766 scale=2.0000 norm=0.8356
# [iter 200] loss=-1.7221 val_loss=-1.7161 scale=2.0000 norm=0.9035
# [iter 300] loss=-2.4015 val_loss=-2.3960 scale=4.0000 norm=1.8495
# [iter 400] loss=-2.7985 val_loss=-2.7839 scale=2.0000 norm=0.8722
# [iter 500] loss=-3.0140 val_loss=-2.9911 scale=1.0000 norm=0.4017
# [iter 600] loss=-3.1616 val_loss=-3.1184 scale=1.0000 norm=0.3844
# == Early stopping achieved.
# == Best iteration / VAL604 (val_loss=-3.1218)
# Iteration with best validation score:  604
# Predict capacity factors for region  ES0
# 0    0.051905
# 1    0.051882
# 2    0.028859
# 3    0.028472
# 4   -3.156575
# 5    0.013926
# 6    0.013703
# 7    0.013934
# 8    0.013783
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES2 0 offwind-ac " ( 47 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  ES2
# [iter 0] loss=0.1876 val_loss=0.1490 scale=1.0000 norm=0.6163
# [iter 100] loss=-0.6922 val_loss=-0.7017 scale=2.0000 norm=0.8703
# [iter 200] loss=-1.1068 val_loss=-1.1128 scale=2.0000 norm=0.8938
# [iter 300] loss=-1.2993 val_loss=-1.2880 scale=2.0000 norm=0.9277
# [iter 400] loss=-1.3673 val_loss=-1.3259 scale=2.0000 norm=0.9440
# == Early stopping achieved.
# == Best iteration / VAL406 (val_loss=-1.3262)
# Iteration with best validation score:  406
# Predict capacity factors for region  ES2
# 0    0.125622
# 1    0.125622
# 2    0.077941
# 3    0.077941
# 4   -1.359020
# 5    0.037555
# 6    0.037555
# 7    0.037622
# 8    0.037621
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES2 0 offwind-dc " ( 48 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  ES2
# [iter 0] loss=0.3153 val_loss=0.3072 scale=1.0000 norm=0.5332
# [iter 100] loss=-0.5634 val_loss=-0.5455 scale=2.0000 norm=0.8509
# [iter 200] loss=-0.9765 val_loss=-0.9268 scale=2.0000 norm=0.9094
# [iter 300] loss=-1.1730 val_loss=-1.0898 scale=2.0000 norm=0.9517
# [iter 400] loss=-1.2617 val_loss=-1.1466 scale=2.0000 norm=0.9706
# == Early stopping achieved.
# == Best iteration / VAL454 (val_loss=-1.1527)
# Iteration with best validation score:  454
# Predict capacity factors for region  ES2
# 0    0.113490
# 1    0.113490
# 2    0.075875
# 3    0.075875
# 4   -1.251161
# 5    0.036297
# 6    0.036297
# 7    0.036938
# 8    0.036938
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES2 0 onwind " ( 49 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  ES2
# [iter 0] loss=0.2110 val_loss=0.1697 scale=1.0000 norm=0.6090
# [iter 100] loss=-0.9798 val_loss=-0.9935 scale=2.0000 norm=0.9123
# [iter 200] loss=-1.7641 val_loss=-1.7679 scale=2.0000 norm=0.8928
# [iter 300] loss=-2.2329 val_loss=-2.2128 scale=2.0000 norm=0.9213
# [iter 400] loss=-2.4610 val_loss=-2.4037 scale=2.0000 norm=0.9771
# == Early stopping achieved.
# == Best iteration / VAL461 (val_loss=-2.4340)
# Iteration with best validation score:  461
# Predict capacity factors for region  ES2
# 0    0.032808
# 1    0.032807
# 2    0.020198
# 3    0.020193
# 4   -2.509060
# 5    0.009751
# 6    0.009733
# 7    0.009875
# 8    0.009873
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " ES2 0 solar " ( 50 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  ES2
# [iter 0] loss=-0.1803 val_loss=-0.1996 scale=1.0000 norm=0.4989
# [iter 100] loss=-1.0906 val_loss=-1.0972 scale=2.0000 norm=0.8497
# [iter 200] loss=-1.6977 val_loss=-1.7015 scale=2.0000 norm=0.9038
# [iter 300] loss=-2.4225 val_loss=-2.4111 scale=2.0000 norm=0.9080
# [iter 400] loss=-2.8203 val_loss=-2.7703 scale=4.0000 norm=1.6679
# == Early stopping achieved.
# == Best iteration / VAL454 (val_loss=-2.8215)
# Iteration with best validation score:  454
# Predict capacity factors for region  ES2
# 0    0.070397
# 1    0.070382
# 2    0.040547
# 3    0.040343
# 4   -2.869721
# 5    0.019289
# 6    0.019158
# 7    0.019732
# 8    0.019649
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FI4 0 offwind-ac " ( 51 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  FI4
# [iter 0] loss=0.1009 val_loss=0.1000 scale=1.0000 norm=0.5001
# [iter 100] loss=-0.3737 val_loss=-0.3540 scale=2.0000 norm=0.7927
# [iter 200] loss=-0.5286 val_loss=-0.4827 scale=2.0000 norm=0.8700
# [iter 300] loss=-0.5711 val_loss=-0.5086 scale=2.0000 norm=0.9253
# [iter 400] loss=-0.5895 val_loss=-0.5181 scale=1.0000 norm=0.4690
# == Early stopping achieved.
# == Best iteration / VAL427 (val_loss=-0.5196)
# Iteration with best validation score:  427
# Predict capacity factors for region  FI4
# 0    0.151626
# 1    0.151626
# 2    0.119237
# 3    0.119237
# 4   -0.575398
# 5    0.057251
# 6    0.057251
# 7    0.057875
# 8    0.057875
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FI4 0 offwind-dc " ( 52 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  FI4
# [iter 0] loss=0.2607 val_loss=0.2518 scale=1.0000 norm=0.4875
# [iter 100] loss=-0.1230 val_loss=-0.1097 scale=2.0000 norm=0.8303
# [iter 200] loss=-0.2573 val_loss=-0.2198 scale=2.0000 norm=0.9136
# [iter 300] loss=-0.3009 val_loss=-0.2505 scale=2.0000 norm=0.9552
# [iter 400] loss=-0.3216 val_loss=-0.2615 scale=1.0000 norm=0.4817
# [iter 500] loss=-0.3349 val_loss=-0.2673 scale=1.0000 norm=0.4819
# == Early stopping achieved.
# == Best iteration / VAL509 (val_loss=-0.2676)
# Iteration with best validation score:  509
# Predict capacity factors for region  FI4
# 0    0.199431
# 1    0.199431
# 2    0.158238
# 3    0.158238
# 4   -0.318745
# 5    0.076926
# 6    0.076926
# 7    0.075491
# 8    0.075490
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FI4 0 onwind " ( 53 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  FI4
# [iter 0] loss=-0.3828 val_loss=-0.3915 scale=1.0000 norm=0.5368
# [iter 100] loss=-1.4888 val_loss=-1.4899 scale=2.0000 norm=0.8635
# [iter 200] loss=-2.0401 val_loss=-2.0304 scale=2.0000 norm=0.8529
# [iter 300] loss=-2.2345 val_loss=-2.2057 scale=2.0000 norm=0.9112
# [iter 400] loss=-2.2840 val_loss=-2.2408 scale=2.0000 norm=0.9531
# == Early stopping achieved.
# == Best iteration / VAL484 (val_loss=-2.2483)
# Iteration with best validation score:  484
# Predict capacity factors for region  FI4
# 0    0.028896
# 1    0.028896
# 2    0.021092
# 3    0.021092
# 4   -2.288977
# 5    0.009604
# 6    0.009604
# 7    0.010746
# 8    0.010746
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FI4 0 ror " ( 54 / 150 )
# Skipped column:  FI4 0 ror
# -------------------------------------------------------------------
# Processing " FI4 0 solar " ( 55 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  FI4
# [iter 0] loss=-0.4828 val_loss=-0.5288 scale=1.0000 norm=0.5998
# [iter 100] loss=-1.4250 val_loss=-1.4127 scale=2.0000 norm=0.8950
# [iter 200] loss=-2.1334 val_loss=-2.0936 scale=2.0000 norm=0.9482
# [iter 300] loss=-2.6978 val_loss=-2.6364 scale=2.0000 norm=0.9099
# [iter 400] loss=-2.9115 val_loss=-2.8378 scale=2.0000 norm=0.8133
# == Early stopping achieved.
# == Best iteration / VAL409 (val_loss=-2.8494)
# Iteration with best validation score:  409
# Predict capacity factors for region  FI4
# 0    0.058638
# 1    0.058630
# 2    0.031629
# 3    0.031425
# 4   -2.906348
# 5    0.014594
# 6    0.014469
# 7    0.015900
# 8    0.015824
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FR0 0 offwind-ac " ( 56 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  FR0
# [iter 0] loss=0.1302 val_loss=0.1135 scale=1.0000 norm=0.4864
# [iter 100] loss=-0.3962 val_loss=-0.3861 scale=2.0000 norm=0.7866
# [iter 200] loss=-0.5237 val_loss=-0.4952 scale=2.0000 norm=0.9157
# [iter 300] loss=-0.5583 val_loss=-0.5126 scale=2.0000 norm=0.9608
# == Early stopping achieved.
# == Best iteration / VAL303 (val_loss=-0.5128)
# Iteration with best validation score:  303
# Predict capacity factors for region  FR0
# 0    0.148731
# 1    0.148731
# 2    0.118226
# 3    0.118226
# 4   -0.547542
# 5    0.056418
# 6    0.056418
# 7    0.057444
# 8    0.057444
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FR0 0 offwind-dc " ( 57 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  FR0
# [iter 0] loss=0.3686 val_loss=0.3668 scale=1.0000 norm=0.4738
# [iter 100] loss=0.1437 val_loss=0.1568 scale=2.0000 norm=0.8752
# [iter 200] loss=0.0884 val_loss=0.1132 scale=2.0000 norm=0.9753
# == Early stopping achieved.
# == Best iteration / VAL271 (val_loss=0.1061)
# Iteration with best validation score:  271
# Predict capacity factors for region  FR0
# 0    0.269796
# 1    0.269796
# 2    0.227583
# 3    0.227583
# 4    0.078314
# 5    0.108969
# 6    0.108969
# 7    0.108937
# 8    0.108934
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FR0 0 onwind " ( 58 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  FR0
# [iter 0] loss=-0.3150 val_loss=-0.3596 scale=1.0000 norm=0.5170
# [iter 100] loss=-1.4117 val_loss=-1.4215 scale=2.0000 norm=0.8430
# [iter 200] loss=-1.9813 val_loss=-1.9645 scale=2.0000 norm=0.8003
# [iter 300] loss=-2.1825 val_loss=-2.1340 scale=2.0000 norm=0.8769
# [iter 400] loss=-2.2365 val_loss=-2.1673 scale=1.0000 norm=0.4607
# [iter 500] loss=-2.2563 val_loss=-2.1768 scale=1.0000 norm=0.4675
# == Early stopping achieved.
# == Best iteration / VAL531 (val_loss=-2.1787)
# Iteration with best validation score:  531
# Predict capacity factors for region  FR0
# 0    0.029710
# 1    0.029710
# 2    0.022466
# 3    0.022466
# 4   -2.240495
# 5    0.010537
# 6    0.010537
# 7    0.011191
# 8    0.011191
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " FR0 0 ror " ( 59 / 150 )
# Skipped column:  FR0 0 ror
# -------------------------------------------------------------------
# Processing " FR0 0 solar " ( 60 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  FR0
# [iter 0] loss=-0.4299 val_loss=-0.4644 scale=1.0000 norm=0.5155
# [iter 100] loss=-1.4151 val_loss=-1.4187 scale=2.0000 norm=0.8512
# [iter 200] loss=-2.0372 val_loss=-2.0280 scale=2.0000 norm=0.9062
# [iter 300] loss=-2.7149 val_loss=-2.6976 scale=2.0000 norm=0.9102
# [iter 400] loss=-3.1580 val_loss=-3.1318 scale=2.0000 norm=0.8365
# [iter 500] loss=-3.3496 val_loss=-3.3171 scale=2.0000 norm=0.7297
# == Early stopping achieved.
# == Best iteration / VAL597 (val_loss=-3.3877)
# Iteration with best validation score:  597
# Predict capacity factors for region  FR0
# 0    0.040769
# 1    0.040750
# 2    0.023011
# 3    0.022704
# 4   -3.418205
# 5    0.011104
# 6    0.010934
# 7    0.011129
# 8    0.011001
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " GB3 0 offwind-ac " ( 61 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  GB3
# [iter 0] loss=0.1030 val_loss=0.0877 scale=1.0000 norm=0.4947
# [iter 100] loss=-0.3799 val_loss=-0.3831 scale=2.0000 norm=0.7980
# [iter 200] loss=-0.5211 val_loss=-0.5159 scale=2.0000 norm=0.8832
# [iter 300] loss=-0.5620 val_loss=-0.5456 scale=2.0000 norm=0.9231
# == Early stopping achieved.
# == Best iteration / VAL371 (val_loss=-0.5515)
# Iteration with best validation score:  371
# Predict capacity factors for region  GB3
# 0    0.148617
# 1    0.148617
# 2    0.118945
# 3    0.118945
# 4   -0.569804
# 5    0.056444
# 6    0.056444
# 7    0.058395
# 8    0.058395
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " GB3 0 offwind-dc " ( 62 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  GB3
# [iter 0] loss=0.2197 val_loss=0.2125 scale=1.0000 norm=0.4670
# [iter 100] loss=-0.1327 val_loss=-0.1301 scale=2.0000 norm=0.8015
# [iter 200] loss=-0.2445 val_loss=-0.2216 scale=2.0000 norm=0.8841
# [iter 300] loss=-0.2869 val_loss=-0.2421 scale=2.0000 norm=0.9059
# == Early stopping achieved.
# == Best iteration / VAL334 (val_loss=-0.2443)
# Iteration with best validation score:  334
# Predict capacity factors for region  GB3
# 0    0.199097
# 1    0.199097
# 2    0.163398
# 3    0.163398
# 4   -0.283362
# 5    0.078691
# 6    0.078691
# 7    0.078503
# 8    0.078503
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " GB3 0 onwind " ( 63 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  GB3
# [iter 0] loss=0.1034 val_loss=0.0660 scale=2.0000 norm=1.0183
# [iter 100] loss=-1.0306 val_loss=-1.0396 scale=2.0000 norm=0.8822
# [iter 200] loss=-1.7353 val_loss=-1.7278 scale=2.0000 norm=0.7992
# [iter 300] loss=-2.0237 val_loss=-1.9949 scale=2.0000 norm=0.8488
# [iter 400] loss=-2.0903 val_loss=-2.0472 scale=2.0000 norm=0.9154
# [iter 500] loss=-2.1102 val_loss=-2.0558 scale=2.0000 norm=0.9362
# == Early stopping achieved.
# == Best iteration / VAL530 (val_loss=-2.0574)
# Iteration with best validation score:  530
# Predict capacity factors for region  GB3
# 0    0.032693
# 1    0.032693
# 2    0.025001
# 3    0.025001
# 4   -2.100622
# 5    0.011963
# 6    0.011963
# 7    0.012191
# 8    0.012191
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " GB3 0 ror " ( 64 / 150 )
# Skipped column:  GB3 0 ror
# -------------------------------------------------------------------
# Processing " GB3 0 solar " ( 65 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  GB3
# ...
# [iter 200] loss=-0.8330 val_loss=-0.8353 scale=2.0000 norm=0.8592
# [iter 300] loss=-0.8811 val_loss=-0.8770 scale=2.0000 norm=0.9129
# [iter 400] loss=-0.9007 val_loss=-0.8849 scale=2.0000 norm=0.9286
# == Early stopping achieved.
# == Best iteration / VAL402 (val_loss=-0.8850)
# Iteration with best validation score:  402
# Predict capacity factors for region  PT0
# 0    0.114467
# 1    0.114467
# 2    0.088552
# 3    0.088552
# 4   -0.897063
# 5    0.042377
# 6    0.042377
# 7    0.043116
# 8    0.043116
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " PT0 0 onwind " ( 129 / 150 )
# Create Trainings data for region:  PT0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  PT0
# [iter 0] loss=-0.2638 val_loss=-0.3133 scale=1.0000 norm=0.5760
# [iter 100] loss=-1.4333 val_loss=-1.4402 scale=2.0000 norm=0.8883
# [iter 200] loss=-2.1317 val_loss=-2.1174 scale=2.0000 norm=0.8162
# [iter 300] loss=-2.4537 val_loss=-2.4046 scale=2.0000 norm=0.8296
# [iter 400] loss=-2.5502 val_loss=-2.4725 scale=2.0000 norm=0.8850
# == Early stopping achieved.
# == Best iteration / VAL492 (val_loss=-2.4844)
# Iteration with best validation score:  492
# Predict capacity factors for region  PT0
# 0    0.023728
# 1    0.023728
# 2    0.017343
# 3    0.017343
# 4   -2.553169
# 5    0.008170
# 6    0.008169
# 7    0.008617
# 8    0.008617
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " PT0 0 ror " ( 130 / 150 )
# Skipped column:  PT0 0 ror
# -------------------------------------------------------------------
# Processing " PT0 0 solar " ( 131 / 150 )
# Create Trainings data for region:  PT0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  PT0
# [iter 0] loss=-0.1605 val_loss=-0.1801 scale=1.0000 norm=0.5043
# [iter 100] loss=-1.1185 val_loss=-1.1149 scale=2.0000 norm=0.8470
# [iter 200] loss=-1.7654 val_loss=-1.7493 scale=2.0000 norm=0.9049
# [iter 300] loss=-2.4001 val_loss=-2.3822 scale=2.0000 norm=0.9115
# [iter 400] loss=-2.8900 val_loss=-2.8704 scale=4.0000 norm=1.7027
# [iter 500] loss=-3.2132 val_loss=-3.1809 scale=1.0000 norm=0.4002
# [iter 600] loss=-3.3331 val_loss=-3.2924 scale=0.0312 norm=0.0125
# == Early stopping achieved.
# == Best iteration / VAL680 (val_loss=-3.3097)
# Iteration with best validation score:  680
# Predict capacity factors for region  PT0
# 0    0.054071
# 1    0.054040
# 2    0.029910
# 3    0.029534
# 4   -3.341244
# 5    0.014513
# 6    0.014307
# 7    0.014407
# 8    0.014244
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " RO0 0 offwind-ac " ( 132 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  RO0
# [iter 0] loss=0.2777 val_loss=0.2398 scale=1.0000 norm=0.5435
# [iter 100] loss=-0.6821 val_loss=-0.6810 scale=2.0000 norm=0.8428
# [iter 200] loss=-1.1000 val_loss=-1.0577 scale=2.0000 norm=0.8949
# [iter 300] loss=-1.2663 val_loss=-1.1864 scale=2.0000 norm=0.9547
# [iter 400] loss=-1.3245 val_loss=-1.2272 scale=2.0000 norm=0.9813
# == Early stopping achieved.
# == Best iteration / VAL496 (val_loss=-1.2389)
# Iteration with best validation score:  496
# Predict capacity factors for region  RO0
# 0    0.088073
# 1    0.088073
# 2    0.061857
# 3    0.061857
# 4   -1.320921
# 5    0.029275
# 6    0.029275
# 7    0.030555
# 8    0.030555
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " RO0 0 offwind-dc " ( 133 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  RO0
# [iter 0] loss=0.3346 val_loss=0.2862 scale=2.0000 norm=1.0713
# [iter 100] loss=-0.6840 val_loss=-0.6870 scale=2.0000 norm=0.8558
# [iter 200] loss=-1.1899 val_loss=-1.1507 scale=2.0000 norm=0.8940
# [iter 300] loss=-1.4310 val_loss=-1.3402 scale=2.0000 norm=0.9547
# [iter 400] loss=-1.5382 val_loss=-1.3985 scale=1.0000 norm=0.4904
# == Early stopping achieved.
# == Best iteration / VAL490 (val_loss=-1.4172)
# Iteration with best validation score:  490
# Predict capacity factors for region  RO0
# 0    0.076439
# 1    0.076439
# 2    0.052069
# 3    0.052069
# 4   -1.537353
# 5    0.024867
# 6    0.024867
# 7    0.025574
# 8    0.025574
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " RO0 0 onwind " ( 134 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  RO0
# [iter 0] loss=-0.6685 val_loss=-0.7113 scale=1.0000 norm=0.5445
# [iter 100] loss=-1.6689 val_loss=-1.6649 scale=2.0000 norm=0.8398
# [iter 200] loss=-2.0992 val_loss=-2.0639 scale=2.0000 norm=0.8680
# [iter 300] loss=-2.2458 val_loss=-2.1857 scale=2.0000 norm=0.9360
# [iter 400] loss=-2.2848 val_loss=-2.2118 scale=1.0000 norm=0.4793
# [iter 500] loss=-2.3024 val_loss=-2.2217 scale=0.5000 norm=0.2416
# == Early stopping achieved.
# == Best iteration / VAL508 (val_loss=-2.2219)
# Iteration with best validation score:  508
# Predict capacity factors for region  RO0
# 0    0.032106
# 1    0.032106
# 2    0.022620
# 3    0.022620
# 4   -2.282819
# 5    0.010503
# 6    0.010503
# 7    0.011398
# 8    0.011398
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " RO0 0 ror " ( 135 / 150 )
# Skipped column:  RO0 0 ror
# -------------------------------------------------------------------
# Processing " RO0 0 solar " ( 136 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  RO0
# [iter 0] loss=-0.3415 val_loss=-0.3505 scale=1.0000 norm=0.5334
# [iter 100] loss=-1.3411 val_loss=-1.3406 scale=2.0000 norm=0.8583
# [iter 200] loss=-1.9902 val_loss=-1.9843 scale=4.0000 norm=1.8147
# [iter 300] loss=-2.6937 val_loss=-2.6732 scale=2.0000 norm=0.9098
# [iter 400] loss=-3.1096 val_loss=-3.0815 scale=2.0000 norm=0.8515
# == Early stopping achieved.
# == Best iteration / VAL450 (val_loss=-3.1739)
# Iteration with best validation score:  450
# Predict capacity factors for region  RO0
# 0    0.045627
# 1    0.045613
# 2    0.025266
# 3    0.025066
# 4   -3.199316
# 5    0.012153
# 6    0.012022
# 7    0.012258
# 8    0.012181
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " RS0 0 onwind " ( 137 / 150 )
# Create Trainings data for region:  RS0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  RS0
# [iter 0] loss=-0.5690 val_loss=-0.5465 scale=1.0000 norm=0.6353
# [iter 100] loss=-1.6755 val_loss=-1.6569 scale=2.0000 norm=0.8541
# [iter 200] loss=-2.2085 val_loss=-2.1668 scale=2.0000 norm=0.8358
# [iter 300] loss=-2.4447 val_loss=-2.3778 scale=2.0000 norm=0.8632
# [iter 400] loss=-2.5191 val_loss=-2.4353 scale=2.0000 norm=0.8850
# == Early stopping achieved.
# == Best iteration / VAL472 (val_loss=-2.4448)
# Iteration with best validation score:  472
# Predict capacity factors for region  RS0
# 0    0.030816
# 1    0.030816
# 2    0.020664
# 3    0.020664
# 4   -2.514447
# 5    0.009680
# 6    0.009679
# 7    0.010264
# 8    0.010264
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " RS0 0 solar " ( 138 / 150 )
# Create Trainings data for region:  RS0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  RS0
# [iter 0] loss=-0.3180 val_loss=-0.3371 scale=1.0000 norm=0.5461
# [iter 100] loss=-1.2956 val_loss=-1.2963 scale=2.0000 norm=0.8676
# [iter 200] loss=-1.9386 val_loss=-1.9346 scale=4.0000 norm=1.8424
# [iter 300] loss=-2.6209 val_loss=-2.5951 scale=2.0000 norm=0.9193
# [iter 400] loss=-3.0349 val_loss=-2.9932 scale=2.0000 norm=0.8627
# == Early stopping achieved.
# == Best iteration / VAL481 (val_loss=-3.1208)
# Iteration with best validation score:  481
# Predict capacity factors for region  RS0
# 0    0.050008
# 1    0.049994
# 2    0.027545
# 3    0.027288
# 4   -3.166694
# 5    0.013168
# 6    0.013015
# 7    0.013465
# 8    0.013370
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SE4 0 offwind-ac " ( 139 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  SE4
# [iter 0] loss=0.0624 val_loss=0.0617 scale=1.0000 norm=0.4985
# [iter 100] loss=-0.8813 val_loss=-0.8806 scale=2.0000 norm=0.7498
# [iter 200] loss=-1.2340 val_loss=-1.2223 scale=2.0000 norm=0.7808
# [iter 300] loss=-1.3116 val_loss=-1.2861 scale=2.0000 norm=0.8775
# [iter 400] loss=-1.3358 val_loss=-1.2951 scale=2.0000 norm=0.8988
# == Early stopping achieved.
# == Best iteration / VAL399 (val_loss=-1.2951)
# Iteration with best validation score:  399
# Predict capacity factors for region  SE4
# 0    0.067573
# 1    0.067573
# 2    0.054436
# 3    0.054436
# 4   -1.325650
# 5    0.025962
# 6    0.025962
# 7    0.026443
# 8    0.026443
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SE4 0 offwind-dc " ( 140 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  SE4
# [iter 0] loss=0.1649 val_loss=0.1572 scale=1.0000 norm=0.4821
# [iter 100] loss=-0.5349 val_loss=-0.5448 scale=2.0000 norm=0.7428
# [iter 200] loss=-0.7508 val_loss=-0.7576 scale=2.0000 norm=0.8584
# [iter 300] loss=-0.8171 val_loss=-0.8044 scale=2.0000 norm=0.9024
# == Early stopping achieved.
# == Best iteration / VAL357 (val_loss=-0.8105)
# Iteration with best validation score:  357
# Predict capacity factors for region  SE4
# 0    0.114872
# 1    0.114872
# 2    0.090988
# 3    0.090988
# 4   -0.828834
# 5    0.043403
# 6    0.043403
# 7    0.044252
# 8    0.044252
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SE4 0 onwind " ( 141 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  SE4
# [iter 0] loss=-0.3791 val_loss=-0.3754 scale=1.0000 norm=0.5315
# [iter 100] loss=-1.3743 val_loss=-1.3594 scale=2.0000 norm=0.8126
# [iter 200] loss=-1.7783 val_loss=-1.7312 scale=2.0000 norm=0.8270
# [iter 300] loss=-1.8953 val_loss=-1.8193 scale=2.0000 norm=0.9006
# == Early stopping achieved.
# == Best iteration / VAL385 (val_loss=-1.8317)
# Iteration with best validation score:  385
# Predict capacity factors for region  SE4
# 0    0.042001
# 1    0.042001
# 2    0.031449
# 3    0.031449
# 4   -1.902591
# 5    0.014484
# 6    0.014484
# 7    0.015888
# 8    0.015888
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SE4 0 ror " ( 142 / 150 )
# Skipped column:  SE4 0 ror
# -------------------------------------------------------------------
# Processing " SE4 0 solar " ( 143 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  SE4
# [iter 0] loss=-0.4481 val_loss=-0.4986 scale=1.0000 norm=0.5743
# [iter 100] loss=-1.3995 val_loss=-1.4077 scale=2.0000 norm=0.8885
# [iter 200] loss=-2.0706 val_loss=-2.0685 scale=2.0000 norm=0.9509
# [iter 300] loss=-2.5713 val_loss=-2.5620 scale=2.0000 norm=0.9280
# [iter 400] loss=-2.8695 val_loss=-2.8465 scale=2.0000 norm=0.8524
# == Early stopping achieved.
# == Best iteration / VAL434 (val_loss=-2.8845)
# Iteration with best validation score:  434
# Predict capacity factors for region  SE4
# 0    0.055080
# 1    0.055061
# 2    0.030514
# 3    0.030203
# 4   -2.906602
# 5    0.014266
# 6    0.014082
# 7    0.015192
# 8    0.015070
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SI0 0 offwind-ac " ( 144 / 150 )
# Create Trainings data for region:  SI0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  SI0
# [iter 0] loss=-0.0050 val_loss=-0.1337 scale=2.0000 norm=1.4321
# [iter 100] loss=-1.3010 val_loss=-1.3222 scale=2.0000 norm=0.9614
# [iter 200] loss=-2.4199 val_loss=-2.4430 scale=4.0000 norm=1.9233
# [iter 300] loss=-3.7860 val_loss=-3.7621 scale=4.0000 norm=1.9895
# [iter 400] loss=-4.3197 val_loss=-4.1772 scale=4.0000 norm=2.1799
# == Early stopping achieved.
# == Best iteration / VAL422 (val_loss=-4.1943)
# Iteration with best validation score:  422
# Predict capacity factors for region  SI0
# 0    0.009434
# 1    0.009434
# 2    0.004502
# 3    0.004501
# 4   -4.355512
# 5    0.002076
# 6    0.002054
# 7    0.002327
# 8    0.002327
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SI0 0 onwind " ( 145 / 150 )
# Create Trainings data for region:  SI0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  SI0
# [iter 0] loss=-0.9167 val_loss=-1.0529 scale=1.0000 norm=0.6980
# [iter 100] loss=-2.1281 val_loss=-2.1502 scale=2.0000 norm=0.8905
# [iter 200] loss=-2.7778 val_loss=-2.7963 scale=2.0000 norm=0.8596
# [iter 300] loss=-3.0978 val_loss=-3.0940 scale=2.0000 norm=0.8988
# [iter 400] loss=-3.2309 val_loss=-3.1964 scale=2.0000 norm=0.9353
# [iter 500] loss=-3.2835 val_loss=-3.2265 scale=2.0000 norm=0.9496
# == Early stopping achieved.
# == Best iteration / VAL526 (val_loss=-3.2292)
# Iteration with best validation score:  526
# Predict capacity factors for region  SI0
# 0    0.014584
# 1    0.014584
# 2    0.009528
# 3    0.009523
# 4   -3.276324
# 5    0.004420
# 6    0.004411
# 7    0.004804
# 8    0.004804
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SI0 0 ror " ( 146 / 150 )
# Skipped column:  SI0 0 ror
# -------------------------------------------------------------------
# Processing " SI0 0 solar " ( 147 / 150 )
# Create Trainings data for region:  SI0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  SI0
# [iter 0] loss=-0.3589 val_loss=-0.4027 scale=1.0000 norm=0.5720
# [iter 100] loss=-1.3300 val_loss=-1.3361 scale=2.0000 norm=0.8768
# [iter 200] loss=-1.9657 val_loss=-1.9544 scale=2.0000 norm=0.9192
# [iter 300] loss=-2.6208 val_loss=-2.5949 scale=2.0000 norm=0.9068
# [iter 400] loss=-2.9348 val_loss=-2.9006 scale=2.0000 norm=0.7971
# == Early stopping achieved.
# == Best iteration / VAL405 (val_loss=-2.9101)
# Iteration with best validation score:  405
# Predict capacity factors for region  SI0
# 0    0.055730
# 1    0.055714
# 2    0.030861
# 3    0.030563
# 4   -2.937682
# 5    0.014622
# 6    0.014447
# 7    0.015126
# 8    0.015004
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SK0 0 onwind " ( 148 / 150 )
# Create Trainings data for region:  SK0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  SK0
# [iter 0] loss=-0.3442 val_loss=-0.3699 scale=1.0000 norm=0.6054
# [iter 100] loss=-1.3392 val_loss=-1.3287 scale=2.0000 norm=0.8611
# [iter 200] loss=-1.7745 val_loss=-1.7518 scale=2.0000 norm=0.9004
# [iter 300] loss=-1.9733 val_loss=-1.9321 scale=1.0000 norm=0.4724
# [iter 400] loss=-2.0420 val_loss=-1.9885 scale=1.0000 norm=0.4811
# [iter 500] loss=-2.0671 val_loss=-2.0067 scale=2.0000 norm=0.9671
# == Early stopping achieved.
# == Best iteration / VAL523 (val_loss=-2.0091)
# Iteration with best validation score:  523
# Predict capacity factors for region  SK0
# 0    0.049193
# 1    0.049190
# 2    0.032823
# 3    0.032795
# 4   -2.055791
# 5    0.014856
# 6    0.014837
# 7    0.016825
# 8    0.016814
# dtype: float64
# -------------------------------------------------------------------
#
# Processing " SK0 0 ror " ( 149 / 150 )
# Skipped column:  SK0 0 ror
# -------------------------------------------------------------------
# Processing " SK0 0 solar " ( 150 / 150 )
# Create Trainings data for region:  SK0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  SK0
# [iter 0] loss=-0.3864 val_loss=-0.4254 scale=1.0000 norm=0.5680
# [iter 100] loss=-1.3675 val_loss=-1.3708 scale=2.0000 norm=0.8745
# [iter 200] loss=-1.9874 val_loss=-1.9707 scale=4.0000 norm=1.8376
# [iter 300] loss=-2.6854 val_loss=-2.6372 scale=2.0000 norm=0.8998
# [iter 400] loss=-3.0101 val_loss=-2.9449 scale=0.1250 norm=0.0506
# == Early stopping achieved.
# == Best iteration / VAL462 (val_loss=-2.9724)
# Iteration with best validation score:  462
# Predict capacity factors for region  SK0
# 0    0.049849
# 1    0.049829
# 2    0.027714
# 3    0.027454
# 4   -3.022824
# 5    0.013077
# 6    0.012933
# 7    0.013616
# 8    0.013510
# dtype: float64
# -------------------------------------------------------------------

# %%
capfacts_pred_q40.to_csv('results/capfacts_pred_q40.csv')
capfacts_pred_q60.to_csv('results/capfacts_pred_q60.csv')
capfacts_pred_q40
# Out:
#                  snapshot  AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  \
# 0     2013-01-01 00:00:00          0.000935      0.018007     0.000974
# 1     2013-01-01 01:00:00          0.000935      0.010318     0.000974
# 2     2013-01-01 02:00:00          0.000935      0.004316     0.001258
# 3     2013-01-01 03:00:00          0.000935      0.002376     0.002605
# 4     2013-01-01 04:00:00         -0.000095     -0.000965     0.002605
# ...                   ...               ...           ...          ...
# 8755  2013-12-31 19:00:00          0.029159      0.052332     0.000953
# 8756  2013-12-31 20:00:00          0.029166      0.065333     0.000953
# 8757  2013-12-31 21:00:00          0.029159      0.070563     0.001167
# 8758  2013-12-31 22:00:00          0.029550      0.052332     0.001167
# 8759  2013-12-31 23:00:00          0.016483      0.047250     0.001167
#
#       AT0 0 onwind  AT0 0 solar  BA0 0 onwind  BA0 0 solar  BE0 0 offwind-ac  \
# 0         0.175266      0.00209      0.007819     0.002153          0.982549
# 1         0.175266      0.00209      0.009555     0.001069          0.968969
# 2         0.152724      0.00209      0.009555     0.001069          0.935869
# 3         0.137218      0.00209      0.009555     0.001069          0.831915
# 4         0.130751      0.00209      0.010373     0.001069          0.647624
# ...            ...          ...           ...          ...               ...
# 8755      0.111254      0.00209      0.001783     0.000915          0.918328
# 8756      0.129625      0.00209      0.001783     0.000915          0.774481
# 8757      0.129625      0.00209      0.001793     0.000915          0.706745
# 8758      0.161576      0.00209      0.001991     0.000915          0.771093
# 8759      0.151439      0.00209      0.001783     0.000915          0.871274
#
#       BE0 0 offwind-dc  ...  RS0 0 solar  SE4 0 offwind-ac  SE4 0 offwind-dc  \
# 0             0.994409  ...     0.001178          0.882340          0.925296
# 1             0.994409  ...     0.001178          0.863526          0.925686
# 2             0.994381  ...     0.001178          0.863526          0.925686
# 3             0.935168  ...     0.001178          0.863526          0.925686
# 4             0.760954  ...     0.001178          0.863526          0.925686
# ...                ...  ...          ...               ...               ...
# 8755          0.988046  ...     0.000879          0.774291          0.856786
# 8756          0.907568  ...     0.002752          0.740592          0.850961
# 8757          0.846384  ...     0.009836          0.692528          0.791599
# 8758          0.915945  ...     0.000094          0.672201          0.783148
# 8759          0.987468  ...     0.000094          0.610672          0.689264
#
#       SE4 0 onwind  SE4 0 solar  SI0 0 offwind-ac  SI0 0 onwind  SI0 0 solar  \
# 0         0.384801     0.000987         -0.000109      0.014418     0.001826
# 1         0.384801     0.000987         -0.000109      0.019600     0.001826
# 2         0.385571     0.000987         -0.000135      0.025477     0.001826
# 3         0.385571     0.000987         -0.000130      0.036631     0.001826
# 4         0.384801     0.000987         -0.000130      0.041897     0.001826
# ...            ...          ...               ...           ...          ...
# 8755      0.308273     0.000987          0.025981      0.003609     0.001372
# 8756      0.284335     0.000987          0.021932      0.004997     0.001372
# 8757      0.250199     0.000987         -0.000072      0.005047     0.001372
# 8758      0.204543     0.000987         -0.000270      0.008052     0.001372
# 8759      0.198399     0.000987         -0.000231      0.008059     0.001372
#
#       SK0 0 onwind  SK0 0 solar
# 0         0.236736     0.000889
# 1         0.236736     0.000889
# 2         0.262676     0.000889
# 3         0.262676     0.000889
# 4         0.264466     0.000889
# ...            ...          ...
# 8755      0.074543     0.000955
# 8756      0.082564     0.000955
# 8757      0.083678     0.000955
# 8758      0.090550     0.000955
# 8759      0.096323     0.000955
#
# [8760 rows x 126 columns]

# %%
cols_num = capfacts_pred_q40.select_dtypes(np.number).columns
print(cols_num)

capfacts_pred_q40[cols_num] = capfacts_pred_q40[cols_num].clip(lower=0, upper=1.02)
capfacts_pred_q60[cols_num] = capfacts_pred_q60[cols_num].clip(lower=0, upper=1.02)

# capfacts_pred_q40.iloc[:, 1:].clip(lower=0, upper=1.02)
# capfacts_pred_q60.iloc[:, 1:].clip(lower=0, upper=1.02)

capfacts_pred_q40.to_csv('results/capfacts_pred_q40_clipped.csv')
capfacts_pred_q60.to_csv('results/capfacts_pred_q60_clipped.csv')

# Alles klar, danke euch. Dann werde ich das auf [0, 1.02] beschränken
capfacts_pred_q40
# Out:
# Index(['AL0 0 offwind-ac', 'AL0 0 onwind', 'AL0 0 solar', 'AT0 0 onwind',
#        'AT0 0 solar', 'BA0 0 onwind', 'BA0 0 solar', 'BE0 0 offwind-ac',
#        'BE0 0 offwind-dc', 'BE0 0 onwind',
#        ...
#        'RS0 0 solar', 'SE4 0 offwind-ac', 'SE4 0 offwind-dc', 'SE4 0 onwind',
#        'SE4 0 solar', 'SI0 0 offwind-ac', 'SI0 0 onwind', 'SI0 0 solar',
#        'SK0 0 onwind', 'SK0 0 solar'],
#       dtype='object', length=125)
#                  snapshot  AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  \
# 0     2013-01-01 00:00:00          0.000935      0.018007     0.000974
# 1     2013-01-01 01:00:00          0.000935      0.010318     0.000974
# 2     2013-01-01 02:00:00          0.000935      0.004316     0.001258
# 3     2013-01-01 03:00:00          0.000935      0.002376     0.002605
# 4     2013-01-01 04:00:00          0.000000      0.000000     0.002605
# ...                   ...               ...           ...          ...
# 8755  2013-12-31 19:00:00          0.029159      0.052332     0.000953
# 8756  2013-12-31 20:00:00          0.029166      0.065333     0.000953
# 8757  2013-12-31 21:00:00          0.029159      0.070563     0.001167
# 8758  2013-12-31 22:00:00          0.029550      0.052332     0.001167
# 8759  2013-12-31 23:00:00          0.016483      0.047250     0.001167
#
#       AT0 0 onwind  AT0 0 solar  BA0 0 onwind  BA0 0 solar  BE0 0 offwind-ac  \
# 0         0.175266      0.00209      0.007819     0.002153          0.982549
# 1         0.175266      0.00209      0.009555     0.001069          0.968969
# 2         0.152724      0.00209      0.009555     0.001069          0.935869
# 3         0.137218      0.00209      0.009555     0.001069          0.831915
# 4         0.130751      0.00209      0.010373     0.001069          0.647624
# ...            ...          ...           ...          ...               ...
# 8755      0.111254      0.00209      0.001783     0.000915          0.918328
# 8756      0.129625      0.00209      0.001783     0.000915          0.774481
# 8757      0.129625      0.00209      0.001793     0.000915          0.706745
# 8758      0.161576      0.00209      0.001991     0.000915          0.771093
# 8759      0.151439      0.00209      0.001783     0.000915          0.871274
#
#       BE0 0 offwind-dc  ...  RS0 0 solar  SE4 0 offwind-ac  SE4 0 offwind-dc  \
# 0             0.994409  ...     0.001178          0.882340          0.925296
# 1             0.994409  ...     0.001178          0.863526          0.925686
# 2             0.994381  ...     0.001178          0.863526          0.925686
# 3             0.935168  ...     0.001178          0.863526          0.925686
# 4             0.760954  ...     0.001178          0.863526          0.925686
# ...                ...  ...          ...               ...               ...
# 8755          0.988046  ...     0.000879          0.774291          0.856786
# 8756          0.907568  ...     0.002752          0.740592          0.850961
# 8757          0.846384  ...     0.009836          0.692528          0.791599
# 8758          0.915945  ...     0.000094          0.672201          0.783148
# 8759          0.987468  ...     0.000094          0.610672          0.689264
#
#       SE4 0 onwind  SE4 0 solar  SI0 0 offwind-ac  SI0 0 onwind  SI0 0 solar  \
# 0         0.384801     0.000987          0.000000      0.014418     0.001826
# 1         0.384801     0.000987          0.000000      0.019600     0.001826
# 2         0.385571     0.000987          0.000000      0.025477     0.001826
# 3         0.385571     0.000987          0.000000      0.036631     0.001826
# 4         0.384801     0.000987          0.000000      0.041897     0.001826
# ...            ...          ...               ...           ...          ...
# 8755      0.308273     0.000987          0.025981      0.003609     0.001372
# 8756      0.284335     0.000987          0.021932      0.004997     0.001372
# 8757      0.250199     0.000987          0.000000      0.005047     0.001372
# 8758      0.204543     0.000987          0.000000      0.008052     0.001372
# 8759      0.198399     0.000987          0.000000      0.008059     0.001372
#
#       SK0 0 onwind  SK0 0 solar
# 0         0.236736     0.000889
# 1         0.236736     0.000889
# 2         0.262676     0.000889
# 3         0.262676     0.000889
# 4         0.264466     0.000889
# ...            ...          ...
# 8755      0.074543     0.000955
# 8756      0.082564     0.000955
# 8757      0.083678     0.000955
# 8758      0.090550     0.000955
# 8759      0.096323     0.000955
#
# [8760 rows x 126 columns]

# %%
capfacts_pred_q40.dtypes
# Out:
# snapshot             object
# AL0 0 offwind-ac    float64
# AL0 0 onwind        float64
# AL0 0 solar         float64
# AT0 0 onwind        float64
#                      ...
# SI0 0 offwind-ac    float64
# SI0 0 onwind        float64
# SI0 0 solar         float64
# SK0 0 onwind        float64
# SK0 0 solar         float64
# Length: 126, dtype: object

# %%
ngb.feature_importances_
# Out:
# array([[0.18371644, 0.46947752, 0.15859219, 0.18821385],
#        [0.17012062, 0.53181351, 0.25267393, 0.04539195]])

# %%
new_columns_scores
# Out:
# {'AL0 0 offwind-ac': 0    0.050804
#  1    0.050804
#  2    0.030652
#  3    0.030650
#  4   -2.363303
#  5    0.014406
#  6    0.014405
#  7    0.015196
#  8    0.015195
#  dtype: float64,
#  'AL0 0 onwind': 0    0.026913
#  1    0.026913
#  2    0.016851
#  3    0.016845
#  4   -2.836191
#  5    0.007981
#  6    0.007976
#  7    0.008268
#  8    0.008267
#  dtype: float64,
#  'AL0 0 solar': 0    0.057449
#  1    0.057426
#  2    0.032054
#  3    0.031692
#  4   -2.973177
#  5    0.015304
#  6    0.015097
#  7    0.015600
#  8    0.015458
#  dtype: float64,
#  'AT0 0 onwind': 0    0.038160
#  1    0.038157
#  2    0.026140
#  3    0.026137
#  4   -2.248328
#  5    0.012449
#  6    0.012447
#  7    0.012839
#  8    0.012838
#  dtype: float64,
#  'AT0 0 solar': 0    0.048020
#  1    0.048005
#  2    0.026922
#  3    0.026694
#  4   -3.269157
#  5    0.012867
#  6    0.012739
#  7    0.013153
#  8    0.013050
#  dtype: float64,
#  'BA0 0 onwind': 0    0.017360
#  1    0.017360
#  2    0.010407
#  3    0.010407
#  4   -3.277351
#  5    0.004741
#  6    0.004741
#  7    0.005297
#  8    0.005297
#  dtype: float64,
#  'BA0 0 solar': 0    0.051495
#  1    0.051458
#  2    0.028661
#  3    0.028202
#  4   -3.090649
#  5    0.013712
#  6    0.013462
#  7    0.013954
#  8    0.013756
#  dtype: float64,
#  'BE0 0 offwind-ac': 0    0.041656
#  1    0.041656
#  2    0.026586
#  3    0.026585
#  4   -1.967397
#  5    0.013059
#  6    0.013024
#  7    0.013006
#  8    0.013006
#  dtype: float64,
#  'BE0 0 offwind-dc': 0    0.055211
#  1    0.055211
#  2    0.032362
#  3    0.032362
#  4   -1.950351
#  5    0.015838
#  6    0.015837
#  7    0.015709
#  8    0.015709
#  dtype: float64,
#  'BE0 0 onwind': 0    0.037322
#  1    0.037322
#  2    0.026115
#  3    0.026114
#  4   -2.114738
#  5    0.012289
#  6    0.012289
#  7    0.012982
#  8    0.012981
#  dtype: float64,
#  'BE0 0 solar': 0    0.053380
#  1    0.053363
#  2    0.029072
#  3    0.028894
#  4   -3.075125
#  5    0.013550
#  6    0.013451
#  7    0.014476
#  8    0.014403
#  dtype: float64,
#  'BG0 0 offwind-ac': 0    0.109061
#  1    0.109059
#  2    0.073357
#  3    0.073355
#  4   -1.165185
#  5    0.034442
#  6    0.034442
#  7    0.036376
#  8    0.036372
#  dtype: float64,
#  'BG0 0 offwind-dc': 0    0.130032
#  1    0.130031
#  2    0.086915
#  3    0.086910
#  4   -0.989636
#  5    0.040595
#  6    0.040594
#  7    0.043190
#  8    0.043183
#  dtype: float64,
#  'BG0 0 onwind': 0    0.033147
#  1    0.033147
#  2    0.023061
#  3    0.023059
#  4   -2.347226
#  5    0.010931
#  6    0.010930
#  7    0.011325
#  8    0.011325
#  dtype: float64,
#  'BG0 0 solar': 0    0.049001
#  1    0.048986
#  2    0.026974
#  3    0.026724
#  4   -3.179487
#  5    0.013018
#  6    0.012874
#  7    0.013022
#  8    0.012922
#  dtype: float64,
#  'CH0 0 onwind': 0    0.027540
#  1    0.027539
#  2    0.016231
#  3    0.016220
#  4   -2.986714
#  5    0.007637
#  6    0.007626
#  7    0.008025
#  8    0.008022
#  dtype: float64,
#  'CH0 0 solar': 0    0.051655
#  1    0.051628
#  2    0.029583
#  3    0.029306
#  4   -3.162230
#  5    0.014019
#  6    0.013865
#  7    0.014429
#  8    0.014310
#  dtype: float64,
#  'CZ0 0 onwind': 0    0.019098
#  1    0.019098
#  2    0.012802
#  3    0.012802
#  4   -2.864601
#  5    0.005893
#  6    0.005892
#  7    0.006492
#  8    0.006492
#  dtype: float64,
#  'CZ0 0 solar': 0    0.046836
#  1    0.046819
#  2    0.025838
#  3    0.025626
#  4   -3.188472
#  5    0.012189
#  6    0.012060
#  7    0.012714
#  8    0.012627
#  dtype: float64,
#  'DE0 0 offwind-ac': 0    0.151110
#  1    0.151110
#  2    0.115547
#  3    0.115547
#  4   -0.640216
#  5    0.055207
#  6    0.055207
#  7    0.056196
#  8    0.056196
#  dtype: float64,
#  'DE0 0 offwind-dc': 0    0.095692
#  1    0.095692
#  2    0.065346
#  3    0.065346
#  4   -1.248408
#  5    0.032071
#  6    0.032071
#  7    0.031104
#  8    0.031103
#  dtype: float64,
#  'DE0 0 onwind': 0    0.035214
#  1    0.035214
#  2    0.026040
#  3    0.026040
#  4   -2.100561
#  5    0.012033
#  6    0.012033
#  7    0.013105
#  8    0.013105
#  dtype: float64,
#  'DE0 0 solar': 0    0.039891
#  1    0.039872
#  2    0.022742
#  3    0.022499
#  4   -3.139513
#  5    0.010780
#  6    0.010621
#  7    0.011221
#  8    0.011128
#  dtype: float64,
#  'DK0 0 offwind-ac': 0    0.092726
#  1    0.092726
#  2    0.067256
#  3    0.067256
#  4   -1.204459
#  5    0.032764
#  6    0.032764
#  7    0.032334
#  8    0.032334
#  dtype: float64,
#  'DK0 0 offwind-dc': 0    0.085065
#  1    0.085065
#  2    0.059548
#  3    0.059548
#  4   -1.397664
#  5    0.028878
#  6    0.028878
#  7    0.028633
#  8    0.028633
#  dtype: float64,
#  'DK0 0 onwind': 0    0.021708
#  1    0.021708
#  2    0.015685
#  3    0.015685
#  4   -2.533888
#  5    0.007460
#  6    0.007460
#  7    0.007704
#  8    0.007704
#  dtype: float64,
#  'DK0 0 solar': 0    0.052208
#  1    0.052199
#  2    0.028963
#  3    0.028807
#  4   -3.104852
#  5    0.013576
#  6    0.013478
#  7    0.014339
#  8    0.014282
#  dtype: float64,
#  'DK4 0 offwind-ac': 0    0.073776
#  1    0.073774
#  2    0.051873
#  3    0.051863
#  4   -1.524180
#  5    0.024737
#  6    0.024728
#  7    0.025300
#  8    0.025295
#  dtype: float64,
#  'DK4 0 offwind-dc': 0    0.085987
#  1    0.085984
#  2    0.057919
#  3    0.057909
#  4   -1.489565
#  5    0.027738
#  6    0.027731
#  7    0.028189
#  8    0.028186
#  dtype: float64,
#  'DK4 0 onwind': 0    0.032404
#  1    0.032404
#  2    0.021866
#  3    0.021865
#  4   -2.303485
#  5    0.010285
#  6    0.010280
#  7    0.010897
#  8    0.010897
#  dtype: float64,
#  'DK4 0 solar': 0    0.059186
#  1    0.059176
#  2    0.032378
#  3    0.032201
#  4   -3.024861
#  5    0.015099
#  6    0.014998
#  7    0.016080
#  8    0.016006
#  dtype: float64,
#  'EE6 0 offwind-ac': 0    0.030582
#  1    0.030582
#  2    0.021521
#  3    0.021521
#  4   -2.254604
#  5    0.010286
#  6    0.010286
#  7    0.010582
#  8    0.010582
#  dtype: float64,
#  'EE6 0 offwind-dc': 0    0.089145
#  1    0.089143
#  2    0.059148
#  3    0.059140
#  4   -1.416819
#  5    0.028553
#  6    0.028548
#  7    0.028748
#  8    0.028742
#  dtype: float64,
#  'EE6 0 onwind': 0    0.017595
#  1    0.017595
#  2    0.012554
#  3    0.012554
#  4   -2.749899
#  5    0.005736
#  6    0.005736
#  7    0.006392
#  8    0.006392
#  dtype: float64,
#  'EE6 0 solar': 0    0.050048
#  1    0.050022
#  2    0.027038
#  3    0.026839
#  4   -3.215965
#  5    0.012691
#  6    0.012582
#  7    0.013362
#  8    0.013275
#  dtype: float64,
#  'ES0 0 offwind-ac': 0    0.132636
#  1    0.132636
#  2    0.108829
#  3    0.108829
#  4   -0.651112
#  5    0.050540
#  6    0.050540
#  7    0.054245
#  8    0.054245
#  dtype: float64,
#  'ES0 0 offwind-dc': 0    0.251254
#  1    0.251254
#  2    0.186328
#  3    0.186328
#  4   -0.179340
#  5    0.084032
#  6    0.084032
#  7    0.094509
#  8    0.094509
#  dtype: float64,
#  'ES0 0 onwind': 0    0.026506
#  1    0.026506
#  2    0.020751
#  3    0.020751
#  4   -2.298071
#  5    0.009867
#  6    0.009867
#  7    0.010183
#  8    0.010183
#  dtype: float64,
#  'ES0 0 solar': 0    0.051905
#  1    0.051882
#  2    0.028859
#  3    0.028472
#  4   -3.156575
#  5    0.013926
#  6    0.013703
#  7    0.013934
#  8    0.013783
#  dtype: float64,
#  'ES2 0 offwind-ac': 0    0.125622
#  1    0.125622
#  2    0.077941
#  3    0.077941
#  4   -1.359020
#  5    0.037555
#  6    0.037555
#  7    0.037622
#  8    0.037621
#  dtype: float64,
#  'ES2 0 offwind-dc': 0    0.113490
#  1    0.113490
#  2    0.075875
#  3    0.075875
#  4   -1.251161
#  5    0.036297
#  6    0.036297
#  7    0.036938
#  8    0.036938
#  dtype: float64,
#  'ES2 0 onwind': 0    0.032808
#  1    0.032807
#  2    0.020198
#  3    0.020193
#  4   -2.509060
#  5    0.009751
#  6    0.009733
#  7    0.009875
#  8    0.009873
#  dtype: float64,
#  'ES2 0 solar': 0    0.070397
#  1    0.070382
#  2    0.040547
#  3    0.040343
#  4   -2.869721
#  5    0.019289
#  6    0.019158
#  7    0.019732
#  8    0.019649
#  dtype: float64,
#  'FI4 0 offwind-ac': 0    0.151626
#  1    0.151626
#  2    0.119237
#  3    0.119237
#  4   -0.575398
#  5    0.057251
#  6    0.057251
#  7    0.057875
#  8    0.057875
#  dtype: float64,
#  'FI4 0 offwind-dc': 0    0.199431
#  1    0.199431
#  2    0.158238
#  3    0.158238
#  4   -0.318745
#  5    0.076926
#  6    0.076926
#  7    0.075491
#  8    0.075490
#  dtype: float64,
#  'FI4 0 onwind': 0    0.028896
#  1    0.028896
#  2    0.021092
#  3    0.021092
#  4   -2.288977
#  5    0.009604
#  6    0.009604
#  7    0.010746
#  8    0.010746
#  dtype: float64,
#  'FI4 0 solar': 0    0.058638
#  1    0.058630
#  2    0.031629
#  3    0.031425
#  4   -2.906348
#  5    0.014594
#  6    0.014469
#  7    0.015900
#  8    0.015824
#  dtype: float64,
#  'FR0 0 offwind-ac': 0    0.148731
#  1    0.148731
#  2    0.118226
#  3    0.118226
#  4   -0.547542
#  5    0.056418
#  6    0.056418
#  7    0.057444
#  8    0.057444
#  dtype: float64,
#  'FR0 0 offwind-dc': 0    0.269796
#  1    0.269796
#  2    0.227583
#  3    0.227583
#  4    0.078314
#  5    0.108969
#  6    0.108969
#  7    0.108937
#  8    0.108934
#  dtype: float64,
#  'FR0 0 onwind': 0    0.029710
#  1    0.029710
#  2    0.022466
#  3    0.022466
#  4   -2.240495
#  5    0.010537
#  6    0.010537
#  7    0.011191
#  8    0.011191
#  dtype: float64,
#  'FR0 0 solar': 0    0.040769
#  1    0.040750
#  2    0.023011
#  3    0.022704
#  4   -3.418205
#  5    0.011104
#  6    0.010934
#  7    0.011129
#  8    0.011001
#  dtype: float64,
#  'GB3 0 offwind-ac': 0    0.148617
#  1    0.148617
#  2    0.118945
#  3    0.118945
#  4   -0.569804
#  5    0.056444
#  6    0.056444
#  7    0.058395
#  8    0.058395
#  dtype: float64,
#  'GB3 0 offwind-dc': 0    0.199097
#  1    0.199097
#  2    0.163398
#  3    0.163398
#  4   -0.283362
#  5    0.078691
#  6    0.078691
#  7    0.078503
#  8    0.078503
#  dtype: float64,
#  'GB3 0 onwind': 0    0.032693
#  1    0.032693
#  2    0.025001
#  3    0.025001
#  4   -2.100622
#  5    0.011963
#  6    0.011963
#  7    0.012191
#  8    0.012191
#  dtype: float64,
#  'GB3 0 solar': 0    0.044834
#  1    0.044818
#  2    0.025602
#  3    0.025446
#  4   -3.274597
#  5    0.012167
#  6    0.012072
#  7    0.012550
#  8    0.012496
#  dtype: float64,
#  'GB5 0 offwind-ac': 0    0.243418
#  1    0.243418
#  2    0.195126
#  3    0.195126
#  4   -0.126647
#  5    0.093886
#  6    0.093886
#  7    0.093752
#  8    0.093752
#  dtype: float64,
#  'GB5 0 offwind-dc': 0    0.192135
#  1    0.192135
#  2    0.139216
#  3    0.139216
#  4   -0.529990
#  5    0.067906
#  6    0.067906
#  7    0.066050
#  8    0.066050
#  dtype: float64,
#  'GB5 0 onwind': 0    0.018728
#  1    0.018728
#  2    0.012123
#  3    0.012123
#  4   -2.894253
#  5    0.005828
#  6    0.005828
#  7    0.005942
#  8    0.005942
#  dtype: float64,
#  'GB5 0 solar': 0    0.050054
#  1    0.050043
#  2    0.027212
#  3    0.027139
#  4   -3.295203
#  5    0.012718
#  6    0.012659
#  7    0.013548
#  8    0.013523
#  dtype: float64,
#  'GR0 0 offwind-ac': 0    0.090544
#  1    0.090544
#  2    0.067325
#  3    0.067325
#  4   -1.176893
#  5    0.030856
#  6    0.030856
#  7    0.034076
#  8    0.034076
#  dtype: float64,
#  'GR0 0 offwind-dc': 0    0.173194
#  1    0.173194
#  2    0.140478
#  3    0.140478
#  4   -0.462899
#  5    0.068901
#  6    0.068901
#  7    0.066097
#  8    0.066097
#  dtype: float64,
#  'GR0 0 onwind': 0    0.060341
#  1    0.060341
#  2    0.049645
#  3    0.049645
#  4   -1.461339
#  5    0.023656
#  6    0.023656
#  7    0.024092
#  8    0.024092
#  dtype: float64,
#  'GR0 0 solar': 0    0.051984
#  1    0.051960
#  2    0.029121
#  3    0.028777
#  4   -3.125375
#  5    0.014093
#  6    0.013901
#  7    0.013947
#  8    0.013799
#  dtype: float64,
#  'HR0 0 offwind-ac': 0    0.123857
#  1    0.123857
#  2    0.082563
#  3    0.082563
#  4   -1.132122
#  5    0.037217
#  6    0.037216
#  7    0.042250
#  8    0.042250
#  dtype: float64,
#  'HR0 0 offwind-dc': 0    0.143555
#  1    0.143555
#  2    0.095318
#  3    0.095318
#  4   -0.939533
#  5    0.042884
#  6    0.042883
#  7    0.048771
#  8    0.048771
#  dtype: float64,
#  'HR0 0 onwind': 0    0.021189
#  1    0.021189
#  2    0.014012
#  3    0.014012
#  4   -2.755889
#  5    0.006462
#  6    0.006462
#  7    0.007124
#  8    0.007124
#  dtype: float64,
#  'HR0 0 solar': 0    0.050450
#  1    0.050433
#  2    0.028206
#  3    0.027848
#  4   -3.061911
#  5    0.013460
#  6    0.013272
#  7    0.013731
#  8    0.013583
#  dtype: float64,
#  'HU0 0 onwind': 0    0.024271
#  1    0.024271
#  2    0.016183
#  3    0.016182
#  4   -2.629090
#  5    0.007360
#  6    0.007359
#  7    0.008267
#  8    0.008267
#  dtype: float64,
#  'HU0 0 solar': 0    0.047402
#  1    0.047385
#  2    0.026136
#  3    0.025865
#  4   -2.996949
#  5    0.012473
#  6    0.012316
#  7    0.012745
#  8    0.012640
#  dtype: float64,
#  'IE5 0 offwind-ac': 0    0.123060
#  1    0.123060
#  2    0.092516
#  3    0.092516
#  4   -0.848452
#  5    0.045502
#  6    0.045502
#  7    0.043936
#  8    0.043936
#  dtype: float64,
#  'IE5 0 offwind-dc': 0    0.272690
#  1    0.272690
#  2    0.214897
#  3    0.214897
#  4   -0.032735
#  5    0.106602
#  6    0.106602
#  7    0.098960
#  8    0.098960
#  dtype: float64,
#  'IE5 0 onwind': 0    0.016592
#  1    0.016592
#  2    0.011644
#  3    0.011644
#  4   -2.867440
#  5    0.005496
#  6    0.005496
#  7    0.005745
#  8    0.005745
#  dtype: float64,
#  'IE5 0 solar': 0    0.046004
#  1    0.045998
#  2    0.025691
#  3    0.025643
#  4   -3.469928
#  5    0.012102
#  6    0.012073
#  7    0.012664
#  8    0.012646
#  dtype: float64,
#  'IT0 0 offwind-ac': 0    0.071487
#  1    0.071487
#  2    0.049720
#  3    0.049720
#  4   -1.456760
#  5    0.022656
#  6    0.022656
#  7    0.025458
#  8    0.025458
#  dtype: float64,
#  'IT0 0 offwind-dc': 0    0.167611
#  1    0.167611
#  2    0.116178
#  3    0.116178
#  4   -0.537185
#  5    0.050232
#  6    0.050230
#  7    0.061583
#  8    0.061583
#  dtype: float64,
#  'IT0 0 onwind': 0    0.039261
#  1    0.039261
#  2    0.029184
#  3    0.029184
#  4   -2.023996
#  5    0.013574
#  6    0.013574
#  7    0.014571
#  8    0.014571
#  dtype: float64,
#  'IT0 0 solar': 0    0.048342
#  1    0.048327
#  2    0.027613
#  3    0.027236
#  4   -3.070306
#  5    0.013419
#  6    0.013203
#  7    0.013203
#  8    0.013061
#  dtype: float64,
#  'IT1 0 offwind-ac': 0    0.076849
#  1    0.076849
#  2    0.051410
#  3    0.051410
#  4   -1.596191
#  5    0.024595
#  6    0.024595
#  7    0.025091
#  8    0.025091
#  dtype: float64,
#  'IT1 0 onwind': 0    0.020595
#  1    0.020595
#  2    0.013955
#  3    0.013955
#  4   -2.893047
#  5    0.006662
#  6    0.006662
#  7    0.006851
#  8    0.006850
#  dtype: float64,
#  'IT1 0 solar': 0    0.063398
#  1    0.063378
#  2    0.036004
#  3    0.035859
#  4   -3.063383
#  5    0.017235
#  6    0.017132
#  7    0.017473
#  8    0.017411
#  dtype: float64,
#  'LT6 0 offwind-ac': 0    0.046039
#  1    0.046039
#  2    0.029417
#  3    0.029410
#  4   -2.085705
#  5    0.014017
#  6    0.014012
#  7    0.014513
#  8    0.014511
#  dtype: float64,
#  'LT6 0 offwind-dc': 0    0.025949
#  1    0.025948
#  2    0.015918
#  3    0.015917
#  4   -2.696922
#  5    0.007695
#  6    0.007684
#  7    0.007823
#  8    0.007823
#  dtype: float64,
#  'LT6 0 onwind': 0    0.012428
#  1    0.012428
#  2    0.008466
#  3    0.008466
#  4   -3.116662
#  5    0.003835
#  6    0.003835
#  7    0.004354
#  8    0.004354
#  dtype: float64,
#  'LT6 0 solar': 0    0.047871
#  1    0.047844
#  2    0.026163
#  3    0.025921
#  4   -3.199863
#  5    0.012295
#  6    0.012164
#  7    0.012897
#  8    0.012793
#  dtype: float64,
#  'LU0 0 onwind': 0    0.009935
#  1    0.009935
#  2    0.006537
#  3    0.006535
#  4   -3.478376
#  5    0.003110
#  6    0.003105
#  7    0.003253
#  8    0.003253
#  dtype: float64,
#  'LU0 0 solar': 0    0.058593
#  1    0.058582
#  2    0.031333
#  3    0.031175
#  4   -3.059024
#  5    0.014596
#  6    0.014509
#  7    0.015618
#  8    0.015553
#  dtype: float64,
#  'LV6 0 offwind-ac': 0    0.066231
#  1    0.066231
#  2    0.045617
#  3    0.045617
#  4   -1.469580
#  5    0.021553
#  6    0.021552
#  7    0.022596
#  8    0.022596
#  dtype: float64,
#  'LV6 0 offwind-dc': 0    0.035418
#  1    0.035418
#  2    0.024711
#  3    0.024711
#  4   -2.036818
#  5    0.011898
#  6    0.011898
#  7    0.011997
#  8    0.011997
#  dtype: float64,
#  'LV6 0 onwind': 0    0.018002
#  1    0.018002
#  2    0.012926
#  3    0.012926
#  4   -2.696658
#  5    0.005921
#  6    0.005921
#  7    0.006567
#  8    0.006567
#  dtype: float64,
#  'LV6 0 solar': 0    0.047738
#  1    0.047711
#  2    0.026075
#  3    0.025880
#  4   -3.249645
#  5    0.012252
#  6    0.012146
#  7    0.012876
#  8    0.012794
#  dtype: float64,
#  'ME0 0 offwind-ac': 0    0.079571
#  1    0.079568
#  2    0.046275
#  3    0.046272
#  4   -2.174519
#  5    0.021732
#  6    0.021732
#  7    0.022803
#  8    0.022802
#  dtype: float64,
#  'ME0 0 onwind': 0    0.008791
#  1    0.008791
#  2    0.005079
#  3    0.005075
#  4   -4.028892
#  5    0.002315
#  6    0.002308
#  7    0.002591
#  8    0.002590
#  dtype: float64,
#  'ME0 0 solar': 0    0.059460
#  1    0.059430
#  2    0.033458
#  3    0.033110
#  4   -2.820405
#  5    0.015880
#  6    0.015667
#  7    0.016368
#  8    0.016244
#  dtype: float64,
#  'MK0 0 onwind': 0    0.012717
#  1    0.012717
#  2    0.006443
#  3    0.006441
#  4   -3.859686
#  5    0.002951
#  6    0.002933
#  7    0.003303
#  8    0.003303
#  dtype: float64,
#  'MK0 0 solar': 0    0.057161
#  1    0.057136
#  2    0.031435
#  3    0.031077
#  4   -3.175764
#  5    0.015214
#  6    0.015031
#  7    0.015159
#  8    0.015002
#  dtype: float64,
#  'NL0 0 offwind-ac': 0    0.134834
#  1    0.134834
#  2    0.098151
#  3    0.098151
#  4   -0.802135
#  5    0.047111
#  6    0.047111
#  7    0.047544
#  8    0.047544
#  dtype: float64,
#  'NL0 0 offwind-dc': 0    0.040436
#  1    0.040436
#  2    0.026618
#  3    0.026618
#  4   -1.931140
#  5    0.013256
#  6    0.013256
#  7    0.012490
#  8    0.012490
#  dtype: float64,
#  'NL0 0 onwind': 0    0.026706
#  1    0.026706
#  2    0.018372
#  3    0.018372
#  4   -2.396451
#  5    0.008570
#  6    0.008570
#  7    0.009208
#  8    0.009208
#  dtype: float64,
#  'NL0 0 solar': 0    0.049626
#  1    0.049617
#  2    0.027437
#  3    0.027340
#  4   -3.242016
#  5    0.012804
#  6    0.012742
#  7    0.013654
#  8    0.013615
#  dtype: float64,
#  'NO4 0 offwind-ac': 0    0.095729
#  1    0.095729
#  2    0.074499
#  3    0.074499
#  4   -1.017938
#  5    0.035774
#  6    0.035774
#  7    0.036345
#  8    0.036345
#  dtype: float64,
#  'NO4 0 offwind-dc': 0    0.147385
#  1    0.147385
#  2    0.116998
#  3    0.116998
#  4   -0.548305
#  5    0.056445
#  6    0.056445
#  7    0.056585
#  8    0.056585
#  dtype: float64,
#  'NO4 0 onwind': 0    0.024776
#  1    0.024776
#  2    0.019123
#  3    0.019123
#  4   -2.376871
#  5    0.009090
#  6    0.009090
#  7    0.009411
#  8    0.009411
#  dtype: float64,
#  'NO4 0 solar': 0    0.044022
#  1    0.044017
#  2    0.023653
#  3    0.023544
#  4   -3.171133
#  5    0.010916
#  6    0.010850
#  7    0.011872
#  8    0.011827
#  dtype: float64,
#  'PL0 0 offwind-ac': 0    0.047734
#  1    0.047733
#  2    0.033016
#  3    0.033014
#  4   -1.909585
#  5    0.015668
#  6    0.015666
#  7    0.016327
#  8    0.016326
#  dtype: float64,
#  'PL0 0 offwind-dc': 0    0.059202
#  1    0.059202
#  2    0.040095
#  3    0.040094
#  4   -1.808817
#  5    0.019457
#  6    0.019454
#  7    0.019348
#  8    0.019348
#  dtype: float64,
#  'PL0 0 onwind': 0    0.023018
#  1    0.023018
#  2    0.016872
#  3    0.016872
#  4   -2.522324
#  5    0.007889
#  6    0.007889
#  7    0.008456
#  8    0.008456
#  dtype: float64,
#  'PL0 0 solar': 0    0.041308
#  1    0.041285
#  2    0.022908
#  3    0.022668
#  4   -3.142155
#  5    0.010829
#  6    0.010678
#  7    0.011268
#  8    0.011177
#  dtype: float64,
#  'PT0 0 offwind-ac': 0    0.114467
#  1    0.114467
#  2    0.088552
#  3    0.088552
#  4   -0.897063
#  5    0.042377
#  6    0.042377
#  7    0.043116
#  8    0.043116
#  dtype: float64,
#  'PT0 0 onwind': 0    0.023728
#  1    0.023728
#  2    0.017343
#  3    0.017343
#  4   -2.553169
#  5    0.008170
#  6    0.008169
#  7    0.008617
#  8    0.008617
#  dtype: float64,
#  'PT0 0 solar': 0    0.054071
#  1    0.054040
#  2    0.029910
#  3    0.029534
#  4   -3.341244
#  5    0.014513
#  6    0.014307
#  7    0.014407
#  8    0.014244
#  dtype: float64,
#  'RO0 0 offwind-ac': 0    0.088073
#  1    0.088073
#  2    0.061857
#  3    0.061857
#  4   -1.320921
#  5    0.029275
#  6    0.029275
#  7    0.030555
#  8    0.030555
#  dtype: float64,
#  'RO0 0 offwind-dc': 0    0.076439
#  1    0.076439
#  2    0.052069
#  3    0.052069
#  4   -1.537353
#  5    0.024867
#  6    0.024867
#  7    0.025574
#  8    0.025574
#  dtype: float64,
#  'RO0 0 onwind': 0    0.032106
#  1    0.032106
#  2    0.022620
#  3    0.022620
#  4   -2.282819
#  5    0.010503
#  6    0.010503
#  7    0.011398
#  8    0.011398
#  dtype: float64,
#  'RO0 0 solar': 0    0.045627
#  1    0.045613
#  2    0.025266
#  3    0.025066
#  4   -3.199316
#  5    0.012153
#  6    0.012022
#  7    0.012258
#  8    0.012181
#  dtype: float64,
#  'RS0 0 onwind': 0    0.030816
#  1    0.030816
#  2    0.020664
#  3    0.020664
#  4   -2.514447
#  5    0.009680
#  6    0.009679
#  7    0.010264
#  8    0.010264
#  dtype: float64,
#  'RS0 0 solar': 0    0.050008
#  1    0.049994
#  2    0.027545
#  3    0.027288
#  4   -3.166694
#  5    0.013168
#  6    0.013015
#  7    0.013465
#  8    0.013370
#  dtype: float64,
#  'SE4 0 offwind-ac': 0    0.067573
#  1    0.067573
#  2    0.054436
#  3    0.054436
#  4   -1.325650
#  5    0.025962
#  6    0.025962
#  7    0.026443
#  8    0.026443
#  dtype: float64,
#  'SE4 0 offwind-dc': 0    0.114872
#  1    0.114872
#  2    0.090988
#  3    0.090988
#  4   -0.828834
#  5    0.043403
#  6    0.043403
#  7    0.044252
#  8    0.044252
#  dtype: float64,
#  'SE4 0 onwind': 0    0.042001
#  1    0.042001
#  2    0.031449
#  3    0.031449
#  4   -1.902591
#  5    0.014484
#  6    0.014484
#  7    0.015888
#  8    0.015888
#  dtype: float64,
#  'SE4 0 solar': 0    0.055080
#  1    0.055061
#  2    0.030514
#  3    0.030203
#  4   -2.906602
#  5    0.014266
#  6    0.014082
#  7    0.015192
#  8    0.015070
#  dtype: float64,
#  'SI0 0 offwind-ac': 0    0.009434
#  1    0.009434
#  2    0.004502
#  3    0.004501
#  4   -4.355512
#  5    0.002076
#  6    0.002054
#  7    0.002327
#  8    0.002327
#  dtype: float64,
#  'SI0 0 onwind': 0    0.014584
#  1    0.014584
#  2    0.009528
#  3    0.009523
#  4   -3.276324
#  5    0.004420
#  6    0.004411
#  7    0.004804
#  8    0.004804
#  dtype: float64,
#  'SI0 0 solar': 0    0.055730
#  1    0.055714
#  2    0.030861
#  3    0.030563
#  4   -2.937682
#  5    0.014622
#  6    0.014447
#  7    0.015126
#  8    0.015004
#  dtype: float64,
#  'SK0 0 onwind': 0    0.049193
#  1    0.049190
#  2    0.032823
#  3    0.032795
#  4   -2.055791
#  5    0.014856
#  6    0.014837
#  7    0.016825
#  8    0.016814
#  dtype: float64,
#  'SK0 0 solar': 0    0.049849
#  1    0.049829
#  2    0.027714
#  3    0.027454
#  4   -3.022824
#  5    0.013077
#  6    0.012933
#  7    0.013616
#  8    0.013510
#  dtype: float64}

# %%
df_scores = pd.DataFrame(new_columns_scores)
df_scores.set_index([["RMSE", "RMSE_clipped", "MAE", "MAE_clipped", "NLL", "PL 0.4", "PL 0.4_clipped", "PL 0.6", "PL 0.6_clipped"]], inplace=True)
df_scores.index.name = "Metric"
df_scores.to_csv("results/scores_default.csv")
df_scores
# Out:
#                 AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  AT0 0 onwind  \
# Metric
# RMSE                    0.050804      0.026913     0.057449      0.038160
# RMSE_clipped            0.050804      0.026913     0.057426      0.038157
# MAE                     0.030652      0.016851     0.032054      0.026140
# MAE_clipped             0.030650      0.016845     0.031692      0.026137
# NLL                    -2.363303     -2.836191    -2.973177     -2.248328
# PL 0.4                  0.014406      0.007981     0.015304      0.012449
# PL 0.4_clipped          0.014405      0.007976     0.015097      0.012447
# PL 0.6                  0.015196      0.008268     0.015600      0.012839
# PL 0.6_clipped          0.015195      0.008267     0.015458      0.012838
#
#                 AT0 0 solar  BA0 0 onwind  BA0 0 solar  BE0 0 offwind-ac  \
# Metric
# RMSE               0.048020      0.017360     0.051495          0.041656
# RMSE_clipped       0.048005      0.017360     0.051458          0.041656
# MAE                0.026922      0.010407     0.028661          0.026586
# MAE_clipped        0.026694      0.010407     0.028202          0.026585
# NLL               -3.269157     -3.277351    -3.090649         -1.967397
# PL 0.4             0.012867      0.004741     0.013712          0.013059
# PL 0.4_clipped     0.012739      0.004741     0.013462          0.013024
# PL 0.6             0.013153      0.005297     0.013954          0.013006
# PL 0.6_clipped     0.013050      0.005297     0.013756          0.013006
#
#                 BE0 0 offwind-dc  BE0 0 onwind  ...  RS0 0 solar  \
# Metric                                          ...
# RMSE                    0.055211      0.037322  ...     0.050008
# RMSE_clipped            0.055211      0.037322  ...     0.049994
# MAE                     0.032362      0.026115  ...     0.027545
# MAE_clipped             0.032362      0.026114  ...     0.027288
# NLL                    -1.950351     -2.114738  ...    -3.166694
# PL 0.4                  0.015838      0.012289  ...     0.013168
# PL 0.4_clipped          0.015837      0.012289  ...     0.013015
# PL 0.6                  0.015709      0.012982  ...     0.013465
# PL 0.6_clipped          0.015709      0.012981  ...     0.013370
#
#                 SE4 0 offwind-ac  SE4 0 offwind-dc  SE4 0 onwind  SE4 0 solar  \
# Metric
# RMSE                    0.067573          0.114872      0.042001     0.055080
# RMSE_clipped            0.067573          0.114872      0.042001     0.055061
# MAE                     0.054436          0.090988      0.031449     0.030514
# MAE_clipped             0.054436          0.090988      0.031449     0.030203
# NLL                    -1.325650         -0.828834     -1.902591    -2.906602
# PL 0.4                  0.025962          0.043403      0.014484     0.014266
# PL 0.4_clipped          0.025962          0.043403      0.014484     0.014082
# PL 0.6                  0.026443          0.044252      0.015888     0.015192
# PL 0.6_clipped          0.026443          0.044252      0.015888     0.015070
#
#                 SI0 0 offwind-ac  SI0 0 onwind  SI0 0 solar  SK0 0 onwind  \
# Metric
# RMSE                    0.009434      0.014584     0.055730      0.049193
# RMSE_clipped            0.009434      0.014584     0.055714      0.049190
# MAE                     0.004502      0.009528     0.030861      0.032823
# MAE_clipped             0.004501      0.009523     0.030563      0.032795
# NLL                    -4.355512     -3.276324    -2.937682     -2.055791
# PL 0.4                  0.002076      0.004420     0.014622      0.014856
# PL 0.4_clipped          0.002054      0.004411     0.014447      0.014837
# PL 0.6                  0.002327      0.004804     0.015126      0.016825
# PL 0.6_clipped          0.002327      0.004804     0.015004      0.016814
#
#                 SK0 0 solar
# Metric
# RMSE               0.049849
# RMSE_clipped       0.049829
# MAE                0.027714
# MAE_clipped        0.027454
# NLL               -3.022824
# PL 0.4             0.013077
# PL 0.4_clipped     0.012933
# PL 0.6             0.013616
# PL 0.6_clipped     0.013510
#
# [9 rows x 125 columns]

# %%
df_scores
# Out:
# Empty DataFrame
# Columns: []
# Index: [RMSE, RMSE_clipped, MAE, MAE_clipped, NLL, PL 0.4, PL 0.4_clipped, PL 0.6, PL 0.6_clipped]

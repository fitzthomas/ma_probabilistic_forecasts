# %% [markdown]
# # Capacity Factors Forecast with Regression

# %%
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
from enum import Enum

from ngboost.scores import LogScore
from shapely.geometry import Point
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

from ngboost import NGBRegressor
from sklearn.model_selection import train_test_split
from ngboost.distns import Exponential, Normal, LogNormal

from sklearn.metrics import mean_pinball_loss
from sklearn.metrics import mean_squared_error

from scipy.stats import norm
import ephem
from datetime import datetime
import pickle
from pathlib import Path

paths = {"era5_eu_2013": "resources/europe-2013-era5.nc",
         "era5_tutorial": "resources/europe-2013-era5-tutorial.nc",
         "offshore_shape": "resources/regions_offshore_elec_s_37.geojson",
         "onshore_shape": "resources/regions_onshore_elec_s_37.geojson",
         "capfacs": "resources/capfacs_37.csv",
         "era5_regions": "resources/europe-2013-era5-regions.nc"}

# %%
ds = xr.open_dataset(filename_or_obj=paths["era5_regions"], engine="netcdf4")
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (region: 65, time: 8760)
# Coordinates:
#   * region            (region) object 'AL0 0 on' 'AT0 0 on' ... 'SI0 0 off'
#   * time              (time) datetime64[ns] 2013-01-01 ... 2013-12-31T23:00:00
# Data variables:
#     height            (region, time) float64 ...
#     wnd100m           (region, time) float64 ...
#     roughness         (region, time) float64 ...
#     influx_toa        (region, time) float64 ...
#     influx_direct     (region, time) float64 ...
#     influx_diffuse    (region, time) float64 ...
#     albedo            (region, time) float64 ...
#     temperature       (region, time) float64 ...
#     soil_temperature  (region, time) float64 ...
#     runoff            (region, time) float64 ...
# Attributes:
#     description:  Era5 data with mean value of the coordinates within a region

# %%
capfacts = pd.read_csv(paths["capfacs"])
capfacts
# Out:
#                  snapshot  AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  \
# 0     2013-01-01 00:00:00          0.003291      0.001469          0.0
# 1     2013-01-01 01:00:00          0.002103      0.000000          0.0
# 2     2013-01-01 02:00:00          0.000000      0.000000          0.0
# 3     2013-01-01 03:00:00          0.000000      0.000000          0.0
# 4     2013-01-01 04:00:00          0.000000      0.000000          0.0
# ...                   ...               ...           ...          ...
# 8755  2013-12-31 19:00:00          0.029235      0.024321          0.0
# 8756  2013-12-31 20:00:00          0.034024      0.031357          0.0
# 8757  2013-12-31 21:00:00          0.037104      0.034522          0.0
# 8758  2013-12-31 22:00:00          0.029730      0.027419          0.0
# 8759  2013-12-31 23:00:00          0.017742      0.020761          0.0
#
#       AT0 0 onwind  AT0 0 ror  AT0 0 solar  BA0 0 onwind  BA0 0 solar  \
# 0         0.163262   0.224456          0.0      0.007340          0.0
# 1         0.171340   0.224369          0.0      0.007939          0.0
# 2         0.171035   0.224300          0.0      0.007829          0.0
# 3         0.169685   0.224249          0.0      0.005766          0.0
# 4         0.159757   0.224213          0.0      0.004262          0.0
# ...            ...        ...          ...           ...          ...
# 8755      0.109127   0.275353          0.0      0.001076          0.0
# 8756      0.120485   0.275159          0.0      0.001090          0.0
# 8757      0.128186   0.274975          0.0      0.001062          0.0
# 8758      0.124740   0.274784          0.0      0.001351          0.0
# 8759      0.126570   0.274592          0.0      0.001109          0.0
#
#       BE0 0 offwind-ac  ...  SE4 0 onwind  SE4 0 ror  SE4 0 solar  \
# 0             1.000000  ...      0.459609   0.626955          0.0
# 1             0.999998  ...      0.463265   0.625502          0.0
# 2             0.993941  ...      0.463777   0.624810          0.0
# 3             0.916094  ...      0.463041   0.623794          0.0
# 4             0.704786  ...      0.457253   0.623085          0.0
# ...                ...  ...           ...        ...          ...
# 8755          0.998922  ...      0.358191   0.469586          0.0
# 8756          0.965757  ...      0.324709   0.469395          0.0
# 8757          0.852484  ...      0.288415   0.469208          0.0
# 8758          0.776442  ...      0.268695   0.469028          0.0
# 8759          0.880753  ...      0.245296   0.468856          0.0
#
#       SI0 0 offwind-ac  SI0 0 onwind  SI0 0 ror  SI0 0 solar  SK0 0 onwind  \
# 0             0.000000      0.055146   0.344668          0.0      0.361009
# 1             0.000000      0.052605   0.344657          0.0      0.368912
# 2             0.000000      0.052222   0.344593          0.0      0.382949
# 3             0.000000      0.050762   0.344626          0.0      0.388344
# 4             0.000000      0.047285   0.344607          0.0      0.409303
# ...                ...           ...        ...          ...           ...
# 8755          0.027877      0.001708   0.696975          0.0      0.125735
# 8756          0.023567      0.000000   0.696262          0.0      0.142431
# 8757          0.000000      0.004891   0.695524          0.0      0.153930
# 8758          0.000000      0.009091   0.694665          0.0      0.163442
# 8759          0.000000      0.013554   0.693632          0.0      0.183295
#
#       SK0 0 ror  SK0 0 solar
# 0      0.106197          0.0
# 1      0.106012          0.0
# 2      0.105968          0.0
# 3      0.106215          0.0
# 4      0.106364          0.0
# ...         ...          ...
# 8755   0.157729          0.0
# 8756   0.157817          0.0
# 8757   0.157899          0.0
# 8758   0.157945          0.0
# 8759   0.157963          0.0
#
# [8760 rows x 151 columns]

# %%
class EnergyType(Enum):
    """
    Represents the different type of renewable energy sources in pypsa-eur
    """
    OFFWIND_AC = "offwind-ac"
    OFFWIND_DC = "offwind-dc"
    ONWIND = "onwind-dc"
    SOLAR = "solar"
    ROR = "ror"
    NOT_DEFINED = "not_defined"

class Feature(Enum):
    """
    Represents the features, that can be extracted from the era-5 weather data set
    """
    HEIGHT = "height"
    WND100M = "wnd100m"
    ROUGHNESS = "roughness"
    INFLUX_TOA = "influx_toa"
    INFLUX_DIRECT = "influx_direct"
    INFLUX_DIFFUSE = "influx_diffuse"
    ALBEDO = "albedo"
    TEMPERATURE = "temperature"
    SOIL_TEMPERATURE = "soil_temperature"
    RUNOFF = "runoff"

"""
Determines which features are selected to calculate the capacity factor of a certain energy type.
"""
feature_set = {
    EnergyType.OFFWIND_AC: [Feature.HEIGHT, Feature.WND100M, Feature.ROUGHNESS],
    EnergyType.OFFWIND_DC: [Feature.HEIGHT, Feature.WND100M, Feature.ROUGHNESS],
    EnergyType.ONWIND: [Feature.HEIGHT, Feature.WND100M, Feature.ROUGHNESS],
    EnergyType.SOLAR: [Feature.INFLUX_TOA, Feature.INFLUX_DIRECT, Feature.INFLUX_DIFFUSE, Feature.TEMPERATURE],
    EnergyType.ROR: []
}

def find_countries_in_capfacts(country_name="") -> list:
    """
    Returns the full region names and energy types of the given name abbreviation that can be found in the .csv file with capacity factors.
    :param country_name: Two character abbreviation of the searched country
    :return: list of all regions and energy types to the given country name
    """
    countries = []
    for column in capfacts:
        if column.find(country_name) >= 0:
            countries.append(column)
    return countries


def get_energy_type(name: str) -> EnergyType:
    """
    Returns the energy type for a given string
    :param name: energy type as string
    :return: energy type for the given string
    """
    match name:
        case "offwind-ac":
            return EnergyType.OFFWIND_AC
        case "offwind-dc":
            return EnergyType.OFFWIND_DC
        case "onwind":
            return EnergyType.ONWIND
        case "solar":
            return EnergyType.SOLAR
        case "ror":
            return EnergyType.ROR
        case _:
            return EnergyType.NOT_DEFINED

def get_ds_region_name(region_name: str, energy_type: EnergyType) -> str:
    """
    Returns the name or string that addresses the given region and energy type which can be used to address the data in the feature data set
    :param region_name: name of the region
    :param energy_type: the uses energy type in that region
    :return: string that can be used to fetch data from the feature data set
    """
    ds_region_name = region_name + " 0"
    if energy_type == EnergyType.ONWIND or energy_type == EnergyType.SOLAR or energy_type == EnergyType.ROR:
        ds_region_name += " on"
    elif energy_type == EnergyType.OFFWIND_AC or energy_type == EnergyType.OFFWIND_DC:
        ds_region_name += " off"
    else:
        ds_region_name += ""
    return ds_region_name

def parse_capfac_col(column_name: str) -> (str, EnergyType):
    """
    Returns a tuple of the region name and energy type for a given column name of the capfacts .csv file
    :param column_name: column name of the capfacts .csv file
    :return: Tuple of a region name and energy type, None if no region is found
    """
    col_args = column_name.split(" ")
    if len(col_args) == 3:
        region_name = col_args[0]
        energy_type = get_energy_type(col_args[2])
        return region_name, energy_type
    return None, None

def create_training_data_for_col(column_name: str) -> (np.ndarray, dict):
    """
    Creates and returns the the training data set with the relevant data for a given column name from the capfacts .csv file.
    The training data set is a tuple of a numpy array of capacity factors (target values) and a dictionary of the era5 data (feature data),
    :param column_name: column name of the capfacts .csv file
    :return: Tuple of capacity factor (Y) and trainings data (X)
            X                       : DataFrame object or List or numpy array of predictors (n x p) in Numeric format
            Y                       : DataFrame object or List or numpy array of outcomes (n) in Numeric format.
    """
    region_name, energy_type = parse_capfac_col(column_name)
    # print(region_name)
    # print(energy_type)
    ds_region_name = get_ds_region_name(region_name, energy_type)
    # print(ds_region_name)
    features = feature_set.get(energy_type)
    # print(features)

    Y_capfac = capfacts[column_name].values
    X = {}
    for feature in features:
        X[feature] = ds.sel(region=ds_region_name)[feature.value].values

    return Y_capfac, X


def shape_multi_feature_data(training_data: dict):
    """
    Reshapes the trainingsdata in an array of shape (n_samples, n_features)
    (8760, 2) ---> [[x_f1_1, x_f2_1], [x_f1_2, x_f2_2], ... , [x_f1_8760, x_f2_8760]]
    :param training_data as a dictinary of multiple 1-d arrays:
    :return: trainingsdata in array of shape (n_samples, n_features)
    """
    # tup = tuple(list(training_data.values()))
    # multi_feature_train_data = np.column_stack(tup)
    arrays = list(training_data.values())
    return np.stack(arrays, axis=-1)

# %%
def get_date_time_obj(date_time_str: str):
    # 2013-01-01 21:00:00
    return datetime.strptime(date_time_str, "%Y-%m-%d %H:%M:%S")

# %%
capfacts_columns = capfacts.columns.values


# capfacts_pred_q40 = pd.DataFrame(columns=capfacts_columns)
capfacts_pred_q40 = pd.DataFrame()
capfacts_pred_q40["snapshot"] = capfacts["snapshot"]

# capfacts_pred_q60 = pd.DataFrame(columns=capfacts_columns)
capfacts_pred_q60 = pd.DataFrame()
capfacts_pred_q60["snapshot"] = capfacts["snapshot"]

capfacts_pred_q40
# Out:
#                  snapshot
# 0     2013-01-01 00:00:00
# 1     2013-01-01 01:00:00
# 2     2013-01-01 02:00:00
# 3     2013-01-01 03:00:00
# 4     2013-01-01 04:00:00
# ...                   ...
# 8755  2013-12-31 19:00:00
# 8756  2013-12-31 20:00:00
# 8757  2013-12-31 21:00:00
# 8758  2013-12-31 22:00:00
# 8759  2013-12-31 23:00:00
#
# [8760 rows x 1 columns]

# %%
col_names = capfacts_columns[1:]

new_columns_q40 = {}
new_columns_q60 = {}

i = 1
for col in col_names:
    print("Processing \"", col, "\" (", i, "/", len(col_names), ")")
    i += 1
    region_name, energy_type = parse_capfac_col(col)

    if(energy_type == EnergyType.NOT_DEFINED):
        print("Skipped column: ", col)
        print("-------------------------------------------------------------------")
    elif(energy_type == EnergyType.ROR):
        print("Skipped column: ", col)
        print("-------------------------------------------------------------------")
    else:
        print("Create Trainings data for region: ", region_name, " with energy type: ", energy_type)

        Y, X = create_training_data_for_col(col)
        X_pred = shape_multi_feature_data(X)
        X_train, X_test, Y_train, Y_test = train_test_split(shape_multi_feature_data(X), Y, test_size=0.25, random_state=42)

        print("Fit Regression Model for region ", region_name)
        ngb = NGBRegressor(random_state=42, verbose=False).fit(X_train, Y_train)

        print("Predict capacity factors for region ", region_name)
        # Y_preds = ngb.predict(X_pred)
        Y_dists = ngb.pred_dist(X_pred)

        Y_preds_q40 = Y_dists.ppf(0.4)
        new_columns_q40[col] = pd.Series(Y_preds_q40)
        # capfacts_pred_q40[col] = Y_preds_q40

        Y_preds_q60 = Y_dists.ppf(0.6)
        new_columns_q60[col] = pd.Series(Y_preds_q60)
        # capfacts_pred_q60[col] = Y_preds_q60

        # print(capfacts_pred.head())
        print(col, " with q = 0.4")
        # print("Smallest value: ", capfacts_pred_q40[col].min())
        # print("Biggest value: ", capfacts_pred_q40[col].max())
        # print("#Negative Values: ", (capfacts_pred_q40[col] < 0).sum())
        # print("#Values > 1: ", (capfacts_pred_q40[col] > 1).sum())
        print("Smallest value: ", new_columns_q40[col].min())
        print("Biggest value: ", new_columns_q40[col].max())
        print("#Negative Values: ", (new_columns_q40[col] < 0).sum())
        print("#Values > 1: ", (new_columns_q40[col] > 1).sum())

        print("")
        print(col, " with q = 0.6")
        # print("Smallest value: ", capfacts_pred_q40[col].min())
        # print("Biggest value: ", capfacts_pred_q40[col].max())
        # print("#Negative Values: ", (capfacts_pred_q40[col] < 0).sum())
        # print("#Values > 1: ", (capfacts_pred_q40[col] > 1).sum())
        print("Smallest value: ", new_columns_q60[col].min())
        print("Biggest value: ", new_columns_q60[col].max())
        print("#Negative Values: ", (new_columns_q60[col] < 0).sum())
        print("#Values > 1: ", (new_columns_q60[col] > 1).sum())

        print("-------------------------------------------------------------------")

        print("")

new_columns_q40 = pd.DataFrame(new_columns_q40, index=capfacts_pred_q40.index)
capfacts_pred_q40 = pd.concat([capfacts_pred_q40, new_columns_q40], axis=1)
new_columns_q60 = pd.DataFrame(new_columns_q60, index=capfacts_pred_q60.index)
capfacts_pred_q60 = pd.concat([capfacts_pred_q60, new_columns_q60], axis=1)
# Out:
# Processing " AL0 0 offwind-ac " ( 1 / 150 )
# Create Trainings data for region:  AL0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  AL0
# Predict capacity factors for region  AL0
# AL0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.012624098012820785
# Biggest value:  0.9714872040522765
# #Negative Values:  97
# #Values > 1:  0
#
# AL0 0 offwind-ac  with q = 0.6
# Smallest value:  -0.006444241201678533
# Biggest value:  1.0119108318100547
# #Negative Values:  1
# #Values > 1:  7
# -------------------------------------------------------------------
#
# Processing " AL0 0 onwind " ( 2 / 150 )
# Create Trainings data for region:  AL0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  AL0
# Predict capacity factors for region  AL0
# AL0 0 onwind  with q = 0.4
# Smallest value:  -0.006681087674393571
# Biggest value:  0.6197746490529304
# #Negative Values:  96
# #Values > 1:  0
#
# AL0 0 onwind  with q = 0.6
# Smallest value:  -0.0028088120090494773
# Biggest value:  0.6419837990087166
# #Negative Values:  13
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " AL0 0 solar " ( 3 / 150 )
# Create Trainings data for region:  AL0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  AL0
# Predict capacity factors for region  AL0
# AL0 0 solar  with q = 0.4
# Smallest value:  -0.03156655949069945
# Biggest value:  0.6295162171159138
# #Negative Values:  1688
# #Values > 1:  0
#
# AL0 0 solar  with q = 0.6
# Smallest value:  -0.021836978030475587
# Biggest value:  0.6567156877662664
# #Negative Values:  987
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " AT0 0 onwind " ( 4 / 150 )
# Create Trainings data for region:  AT0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  AT0
# Predict capacity factors for region  AT0
# AT0 0 onwind  with q = 0.4
# Smallest value:  -0.029932785335628695
# Biggest value:  0.8497984697255514
# #Negative Values:  53
# #Values > 1:  0
#
# AT0 0 onwind  with q = 0.6
# Smallest value:  -0.02190526717664959
# Biggest value:  0.8741192585650601
# #Negative Values:  1
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " AT0 0 ror " ( 5 / 150 )
# Skipped column:  AT0 0 ror
# -------------------------------------------------------------------
# Processing " AT0 0 solar " ( 6 / 150 )
# Create Trainings data for region:  AT0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  AT0
# Predict capacity factors for region  AT0
# AT0 0 solar  with q = 0.4
# Smallest value:  -0.03032895258813045
# Biggest value:  0.6046970518136906
# #Negative Values:  2003
# #Values > 1:  0
#
# AT0 0 solar  with q = 0.6
# Smallest value:  -0.025798275642147536
# Biggest value:  0.6469478133598404
# #Negative Values:  643
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " BA0 0 onwind " ( 7 / 150 )
# Create Trainings data for region:  BA0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  BA0
# Predict capacity factors for region  BA0
# BA0 0 onwind  with q = 0.4
# Smallest value:  -0.0013713383011579009
# Biggest value:  0.8377249621238443
# #Negative Values:  19
# #Values > 1:  0
#
# BA0 0 onwind  with q = 0.6
# Smallest value:  0.0004301898843354796
# Biggest value:  0.8619759685376924
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " BA0 0 solar " ( 8 / 150 )
# Create Trainings data for region:  BA0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  BA0
# Predict capacity factors for region  BA0
# BA0 0 solar  with q = 0.4
# Smallest value:  -0.028300146326892924
# Biggest value:  0.6466163715346719
# #Negative Values:  1699
# #Values > 1:  0
#
# BA0 0 solar  with q = 0.6
# Smallest value:  -0.019647041749009015
# Biggest value:  0.6667262449630437
# #Negative Values:  840
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " BE0 0 offwind-ac " ( 9 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  BE0
# Predict capacity factors for region  BE0
# BE0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.009273282821792055
# Biggest value:  1.002736648173118
# #Negative Values:  24
# #Values > 1:  2
#
# BE0 0 offwind-ac  with q = 0.6
# Smallest value:  -0.006421967830779483
# Biggest value:  1.006056112502943
# #Negative Values:  3
# #Values > 1:  276
# -------------------------------------------------------------------
#
# Processing " BE0 0 offwind-dc " ( 10 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  BE0
# Predict capacity factors for region  BE0
# BE0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.004294022651220461
# Biggest value:  1.0042916654726768
# #Negative Values:  24
# #Values > 1:  27
#
# BE0 0 offwind-dc  with q = 0.6
# Smallest value:  -0.00013787571960402608
# Biggest value:  1.0256251392774651
# #Negative Values:  1
# #Values > 1:  508
# -------------------------------------------------------------------
#
# Processing " BE0 0 onwind " ( 11 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  BE0
# Predict capacity factors for region  BE0
# BE0 0 onwind  with q = 0.4
# Smallest value:  -0.002819939979502998
# Biggest value:  1.0141910165839136
# #Negative Values:  6
# #Values > 1:  1
#
# BE0 0 onwind  with q = 0.6
# Smallest value:  0.0012056167977773503
# Biggest value:  1.0204802985241135
# #Negative Values:  0
# #Values > 1:  14
# -------------------------------------------------------------------
#
# Processing " BE0 0 ror " ( 12 / 150 )
# Skipped column:  BE0 0 ror
# -------------------------------------------------------------------
# Processing " BE0 0 solar " ( 13 / 150 )
# Create Trainings data for region:  BE0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  BE0
# Predict capacity factors for region  BE0
# BE0 0 solar  with q = 0.4
# Smallest value:  -0.03901025233949703
# Biggest value:  0.623162000395186
# #Negative Values:  364
# #Values > 1:  0
#
# BE0 0 solar  with q = 0.6
# Smallest value:  -0.03227185638278147
# Biggest value:  0.6502134965423052
# #Negative Values:  301
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " BG0 0 offwind-ac " ( 14 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  BG0
# Predict capacity factors for region  BG0
# BG0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.003736289625963264
# Biggest value:  1.0079244892774593
# #Negative Values:  2
# #Values > 1:  2
#
# BG0 0 offwind-ac  with q = 0.6
# Smallest value:  0.00603094802013019
# Biggest value:  1.0742585811161314
# #Negative Values:  0
# #Values > 1:  4
# -------------------------------------------------------------------
#
# Processing " BG0 0 offwind-dc " ( 15 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  BG0
# Predict capacity factors for region  BG0
# BG0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.012460009823752952
# Biggest value:  1.059667023241108
# #Negative Values:  4
# #Values > 1:  3
#
# BG0 0 offwind-dc  with q = 0.6
# Smallest value:  0.006773509762856263
# Biggest value:  1.140111322178955
# #Negative Values:  0
# #Values > 1:  43
# -------------------------------------------------------------------
#
# Processing " BG0 0 onwind " ( 16 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  BG0
# Predict capacity factors for region  BG0
# BG0 0 onwind  with q = 0.4
# Smallest value:  -0.005398099118649554
# Biggest value:  0.8408534804891805
# #Negative Values:  33
# #Values > 1:  0
#
# BG0 0 onwind  with q = 0.6
# Smallest value:  -0.002271909680098586
# Biggest value:  0.8645680311067097
# #Negative Values:  3
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " BG0 0 ror " ( 17 / 150 )
# Skipped column:  BG0 0 ror
# -------------------------------------------------------------------
# Processing " BG0 0 solar " ( 18 / 150 )
# Create Trainings data for region:  BG0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  BG0
# Predict capacity factors for region  BG0
# BG0 0 solar  with q = 0.4
# Smallest value:  -0.018980355228176735
# Biggest value:  0.6264457692955757
# #Negative Values:  1957
# #Values > 1:  0
#
# BG0 0 solar  with q = 0.6
# Smallest value:  -0.012695378334894784
# Biggest value:  0.6634847446030093
# #Negative Values:  999
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " CH0 0 onwind " ( 19 / 150 )
# Create Trainings data for region:  CH0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  CH0
# Predict capacity factors for region  CH0
# CH0 0 onwind  with q = 0.4
# Smallest value:  -0.0037990941120942777
# Biggest value:  0.551776289481948
# #Negative Values:  218
# #Values > 1:  0
#
# CH0 0 onwind  with q = 0.6
# Smallest value:  -0.002414916567070813
# Biggest value:  0.5894689091726371
# #Negative Values:  44
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " CH0 0 ror " ( 20 / 150 )
# Skipped column:  CH0 0 ror
# -------------------------------------------------------------------
# Processing " CH0 0 solar " ( 21 / 150 )
# Create Trainings data for region:  CH0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  CH0
# Predict capacity factors for region  CH0
# CH0 0 solar  with q = 0.4
# Smallest value:  -0.04662062099146823
# Biggest value:  0.6330246371500365
# #Negative Values:  978
# #Values > 1:  0
#
# CH0 0 solar  with q = 0.6
# Smallest value:  -0.03746627207590632
# Biggest value:  0.6548147702396505
# #Negative Values:  684
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " CZ0 0 onwind " ( 22 / 150 )
# Create Trainings data for region:  CZ0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  CZ0
# Predict capacity factors for region  CZ0
# CZ0 0 onwind  with q = 0.4
# Smallest value:  -0.0003871790721332347
# Biggest value:  1.0008497264167775
# #Negative Values:  33
# #Values > 1:  1
#
# CZ0 0 onwind  with q = 0.6
# Smallest value:  0.0012861746757786368
# Biggest value:  1.0146312995404183
# #Negative Values:  0
# #Values > 1:  7
# -------------------------------------------------------------------
#
# Processing " CZ0 0 ror " ( 23 / 150 )
# Skipped column:  CZ0 0 ror
# -------------------------------------------------------------------
# Processing " CZ0 0 solar " ( 24 / 150 )
# Create Trainings data for region:  CZ0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  CZ0
# Predict capacity factors for region  CZ0
# CZ0 0 solar  with q = 0.4
# Smallest value:  -0.03531540832991644
# Biggest value:  0.6383641736691447
# #Negative Values:  1562
# #Values > 1:  0
#
# CZ0 0 solar  with q = 0.6
# Smallest value:  -0.030762452455879313
# Biggest value:  0.6664330516333855
# #Negative Values:  613
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " DE0 0 offwind-ac " ( 25 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  DE0
# Predict capacity factors for region  DE0
# DE0 0 offwind-ac  with q = 0.4
# Smallest value:  0.020570816177553797
# Biggest value:  0.982876500221267
# #Negative Values:  0
# #Values > 1:  0
#
# DE0 0 offwind-ac  with q = 0.6
# Smallest value:  0.035592900226043715
# Biggest value:  1.0030224992697148
# #Negative Values:  0
# #Values > 1:  3
# -------------------------------------------------------------------
#
# Processing " DE0 0 offwind-dc " ( 26 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  DE0
# Predict capacity factors for region  DE0
# DE0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.012154695345449378
# Biggest value:  1.0173647480682948
# #Negative Values:  2
# #Values > 1:  14
#
# DE0 0 offwind-dc  with q = 0.6
# Smallest value:  0.015278724282798927
# Biggest value:  1.034816664097354
# #Negative Values:  0
# #Values > 1:  185
# -------------------------------------------------------------------
#
# Processing " DE0 0 onwind " ( 27 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  DE0
# Predict capacity factors for region  DE0
# DE0 0 onwind  with q = 0.4
# Smallest value:  0.002933616148881195
# Biggest value:  0.9699165715047913
# #Negative Values:  0
# #Values > 1:  0
#
# DE0 0 onwind  with q = 0.6
# Smallest value:  0.007537603298981272
# Biggest value:  0.9878826309123732
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " DE0 0 ror " ( 28 / 150 )
# Skipped column:  DE0 0 ror
# -------------------------------------------------------------------
# Processing " DE0 0 solar " ( 29 / 150 )
# Create Trainings data for region:  DE0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  DE0
# Predict capacity factors for region  DE0
# DE0 0 solar  with q = 0.4
# Smallest value:  -0.028295008048580164
# Biggest value:  0.5876250714449356
# #Negative Values:  1741
# #Values > 1:  0
#
# DE0 0 solar  with q = 0.6
# Smallest value:  -0.02154606714288669
# Biggest value:  0.6069733295221181
# #Negative Values:  755
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " DK0 0 offwind-ac " ( 30 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  DK0
# Predict capacity factors for region  DK0
# DK0 0 offwind-ac  with q = 0.4
# Smallest value:  0.008226870796061254
# Biggest value:  0.9972181333510267
# #Negative Values:  0
# #Values > 1:  0
#
# DK0 0 offwind-ac  with q = 0.6
# Smallest value:  0.016424342545487518
# Biggest value:  1.010505055220412
# #Negative Values:  0
# #Values > 1:  25
# -------------------------------------------------------------------
#
# Processing " DK0 0 offwind-dc " ( 31 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  DK0
# Predict capacity factors for region  DK0
# DK0 0 offwind-dc  with q = 0.4
# Smallest value:  0.00044292048550013865
# Biggest value:  1.0106218393612727
# #Negative Values:  0
# #Values > 1:  5
#
# DK0 0 offwind-dc  with q = 0.6
# Smallest value:  0.008315201114252404
# Biggest value:  1.0152439318983448
# #Negative Values:  0
# #Values > 1:  30
# -------------------------------------------------------------------
#
# Processing " DK0 0 onwind " ( 32 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  DK0
# Predict capacity factors for region  DK0
# DK0 0 onwind  with q = 0.4
# Smallest value:  -0.0009369691493198481
# Biggest value:  0.997659661833895
# #Negative Values:  6
# #Values > 1:  0
#
# DK0 0 onwind  with q = 0.6
# Smallest value:  0.002050041585424753
# Biggest value:  1.0061341137663977
# #Negative Values:  0
# #Values > 1:  46
# -------------------------------------------------------------------
#
# Processing " DK0 0 solar " ( 33 / 150 )
# Create Trainings data for region:  DK0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  DK0
# Predict capacity factors for region  DK0
# DK0 0 solar  with q = 0.4
# Smallest value:  -0.021323100156091394
# Biggest value:  0.6276550739622917
# #Negative Values:  1145
# #Values > 1:  0
#
# DK0 0 solar  with q = 0.6
# Smallest value:  -0.016036725916011938
# Biggest value:  0.65212221883499
# #Negative Values:  655
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " DK4 0 offwind-ac " ( 34 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  DK4
# Predict capacity factors for region  DK4
# DK4 0 offwind-ac  with q = 0.4
# Smallest value:  -0.016136298520272086
# Biggest value:  1.0013220003313965
# #Negative Values:  40
# #Values > 1:  12
#
# DK4 0 offwind-ac  with q = 0.6
# Smallest value:  -0.007836538916282023
# Biggest value:  1.0237390443671592
# #Negative Values:  7
# #Values > 1:  26
# -------------------------------------------------------------------
#
# Processing " DK4 0 offwind-dc " ( 35 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  DK4
# Predict capacity factors for region  DK4
# DK4 0 offwind-dc  with q = 0.4
# Smallest value:  -0.012507666362252614
# Biggest value:  1.0389172291087856
# #Negative Values:  9
# #Values > 1:  75
#
# DK4 0 offwind-dc  with q = 0.6
# Smallest value:  -0.0027401630500584638
# Biggest value:  1.050513157656376
# #Negative Values:  2
# #Values > 1:  216
# -------------------------------------------------------------------
#
# Processing " DK4 0 onwind " ( 36 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  DK4
# Predict capacity factors for region  DK4
# DK4 0 onwind  with q = 0.4
# Smallest value:  -0.006670534208053324
# Biggest value:  1.0064254820525658
# #Negative Values:  86
# #Values > 1:  18
#
# DK4 0 onwind  with q = 0.6
# Smallest value:  -0.000847836506434602
# Biggest value:  1.0097270965201377
# #Negative Values:  1
# #Values > 1:  135
# -------------------------------------------------------------------
#
# Processing " DK4 0 solar " ( 37 / 150 )
# Create Trainings data for region:  DK4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  DK4
# Predict capacity factors for region  DK4
# DK4 0 solar  with q = 0.4
# Smallest value:  -0.027946259383702203
# Biggest value:  0.632616327023525
# #Negative Values:  596
# #Values > 1:  0
#
# DK4 0 solar  with q = 0.6
# Smallest value:  -0.01892878382023623
# Biggest value:  0.6587250264033606
# #Negative Values:  427
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " EE6 0 offwind-ac " ( 38 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  EE6
# Predict capacity factors for region  EE6
# EE6 0 offwind-ac  with q = 0.4
# Smallest value:  0.00044888508142817756
# Biggest value:  1.0044296355238589
# #Negative Values:  0
# #Values > 1:  1
#
# EE6 0 offwind-ac  with q = 0.6
# Smallest value:  0.004181627750341761
# Biggest value:  1.0102590588823817
# #Negative Values:  0
# #Values > 1:  27
# -------------------------------------------------------------------
#
# Processing " EE6 0 offwind-dc " ( 39 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  EE6
# Predict capacity factors for region  EE6
# EE6 0 offwind-dc  with q = 0.4
# Smallest value:  -0.019773140331432338
# Biggest value:  1.0368475949226643
# #Negative Values:  29
# #Values > 1:  22
#
# EE6 0 offwind-dc  with q = 0.6
# Smallest value:  -0.010154605837995753
# Biggest value:  1.0496686954157362
# #Negative Values:  8
# #Values > 1:  165
# -------------------------------------------------------------------
#
# Processing " EE6 0 onwind " ( 40 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  EE6
# Predict capacity factors for region  EE6
# EE6 0 onwind  with q = 0.4
# Smallest value:  -0.004091149717565591
# Biggest value:  0.9972660992785416
# #Negative Values:  2
# #Values > 1:  0
#
# EE6 0 onwind  with q = 0.6
# Smallest value:  -0.00015273767106958056
# Biggest value:  1.0020170387006904
# #Negative Values:  1
# #Values > 1:  3
# -------------------------------------------------------------------
#
# Processing " EE6 0 solar " ( 41 / 150 )
# Create Trainings data for region:  EE6  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  EE6
# Predict capacity factors for region  EE6
# EE6 0 solar  with q = 0.4
# Smallest value:  -0.04279409632449102
# Biggest value:  0.6014280408467605
# #Negative Values:  563
# #Values > 1:  0
#
# EE6 0 solar  with q = 0.6
# Smallest value:  -0.03213317170356232
# Biggest value:  0.6730667619631994
# #Negative Values:  217
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " ES0 0 offwind-ac " ( 42 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  ES0
# Predict capacity factors for region  ES0
# ES0 0 offwind-ac  with q = 0.4
# Smallest value:  0.023189034919314223
# Biggest value:  0.9029850657711136
# #Negative Values:  0
# #Values > 1:  0
#
# ES0 0 offwind-ac  with q = 0.6
# Smallest value:  0.03815980257354651
# Biggest value:  0.944027236286093
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " ES0 0 offwind-dc " ( 43 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  ES0
# Predict capacity factors for region  ES0
# ES0 0 offwind-dc  with q = 0.4
# Smallest value:  0.00852821435714414
# Biggest value:  1.0024782590460173
# #Negative Values:  0
# #Values > 1:  2
#
# ES0 0 offwind-dc  with q = 0.6
# Smallest value:  0.0669005490348152
# Biggest value:  1.0323496316035476
# #Negative Values:  0
# #Values > 1:  26
# -------------------------------------------------------------------
#
# Processing " ES0 0 onwind " ( 44 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  ES0
# Predict capacity factors for region  ES0
# ES0 0 onwind  with q = 0.4
# Smallest value:  0.002328829545822908
# Biggest value:  0.8147330892751927
# #Negative Values:  0
# #Values > 1:  0
#
# ES0 0 onwind  with q = 0.6
# Smallest value:  0.005519031215865216
# Biggest value:  0.8341315861060601
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " ES0 0 ror " ( 45 / 150 )
# Skipped column:  ES0 0 ror
# -------------------------------------------------------------------
# Processing " ES0 0 solar " ( 46 / 150 )
# Create Trainings data for region:  ES0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  ES0
# Predict capacity factors for region  ES0
# ES0 0 solar  with q = 0.4
# Smallest value:  -0.029171866029213983
# Biggest value:  0.6378782976136619
# #Negative Values:  2302
# #Values > 1:  0
#
# ES0 0 solar  with q = 0.6
# Smallest value:  -0.02310852481732073
# Biggest value:  0.6589483847723621
# #Negative Values:  917
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " ES2 0 offwind-ac " ( 47 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  ES2
# Predict capacity factors for region  ES2
# ES2 0 offwind-ac  with q = 0.4
# Smallest value:  -0.0036209951513770343
# Biggest value:  0.9850443558598153
# #Negative Values:  1
# #Values > 1:  0
#
# ES2 0 offwind-ac  with q = 0.6
# Smallest value:  0.007509923604429557
# Biggest value:  1.0271210751916307
# #Negative Values:  0
# #Values > 1:  24
# -------------------------------------------------------------------
#
# Processing " ES2 0 offwind-dc " ( 48 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  ES2
# Predict capacity factors for region  ES2
# ES2 0 offwind-dc  with q = 0.4
# Smallest value:  0.0017358564226240664
# Biggest value:  0.9969944729123058
# #Negative Values:  0
# #Values > 1:  0
#
# ES2 0 offwind-dc  with q = 0.6
# Smallest value:  0.006803219140293169
# Biggest value:  1.0178431779466004
# #Negative Values:  0
# #Values > 1:  19
# -------------------------------------------------------------------
#
# Processing " ES2 0 onwind " ( 49 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  ES2
# Predict capacity factors for region  ES2
# ES2 0 onwind  with q = 0.4
# Smallest value:  -0.008941379555031577
# Biggest value:  0.9983764491703867
# #Negative Values:  447
# #Values > 1:  0
#
# ES2 0 onwind  with q = 0.6
# Smallest value:  -0.0061975394247015675
# Biggest value:  1.0061858786387643
# #Negative Values:  10
# #Values > 1:  118
# -------------------------------------------------------------------
#
# Processing " ES2 0 solar " ( 50 / 150 )
# Create Trainings data for region:  ES2  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  ES2
# Predict capacity factors for region  ES2
# ES2 0 solar  with q = 0.4
# Smallest value:  -0.04601129796578608
# Biggest value:  0.6214825047808291
# #Negative Values:  2113
# #Values > 1:  0
#
# ES2 0 solar  with q = 0.6
# Smallest value:  -0.03339470638131467
# Biggest value:  0.6447102950071407
# #Negative Values:  221
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " FI4 0 offwind-ac " ( 51 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  FI4
# Predict capacity factors for region  FI4
# FI4 0 offwind-ac  with q = 0.4
# Smallest value:  0.020521806500745057
# Biggest value:  0.9767516658006322
# #Negative Values:  0
# #Values > 1:  0
#
# FI4 0 offwind-ac  with q = 0.6
# Smallest value:  0.037559307797469785
# Biggest value:  1.0240684031026863
# #Negative Values:  0
# #Values > 1:  2
# -------------------------------------------------------------------
#
# Processing " FI4 0 offwind-dc " ( 52 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  FI4
# Predict capacity factors for region  FI4
# FI4 0 offwind-dc  with q = 0.4
# Smallest value:  0.012574958980407079
# Biggest value:  1.0040157258413132
# #Negative Values:  0
# #Values > 1:  7
#
# FI4 0 offwind-dc  with q = 0.6
# Smallest value:  0.03150048721421523
# Biggest value:  1.023109543450751
# #Negative Values:  0
# #Values > 1:  16
# -------------------------------------------------------------------
#
# Processing " FI4 0 onwind " ( 53 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  FI4
# Predict capacity factors for region  FI4
# FI4 0 onwind  with q = 0.4
# Smallest value:  0.009787924556770694
# Biggest value:  0.8987733862263487
# #Negative Values:  0
# #Values > 1:  0
#
# FI4 0 onwind  with q = 0.6
# Smallest value:  0.014342783549658086
# Biggest value:  0.9220748689429472
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " FI4 0 ror " ( 54 / 150 )
# Skipped column:  FI4 0 ror
# -------------------------------------------------------------------
# Processing " FI4 0 solar " ( 55 / 150 )
# Create Trainings data for region:  FI4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  FI4
# Predict capacity factors for region  FI4
# FI4 0 solar  with q = 0.4
# Smallest value:  -0.02405648492473295
# Biggest value:  0.5097052260605964
# #Negative Values:  793
# #Values > 1:  0
#
# FI4 0 solar  with q = 0.6
# Smallest value:  -0.015126798976868264
# Biggest value:  0.587307914448944
# #Negative Values:  503
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " FR0 0 offwind-ac " ( 56 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  FR0
# Predict capacity factors for region  FR0
# FR0 0 offwind-ac  with q = 0.4
# Smallest value:  0.01997980576442771
# Biggest value:  0.9419453931056746
# #Negative Values:  0
# #Values > 1:  0
#
# FR0 0 offwind-ac  with q = 0.6
# Smallest value:  0.03703908952852254
# Biggest value:  0.9704998454693804
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " FR0 0 offwind-dc " ( 57 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  FR0
# Predict capacity factors for region  FR0
# FR0 0 offwind-dc  with q = 0.4
# Smallest value:  0.015466602000880045
# Biggest value:  0.9551364072160259
# #Negative Values:  0
# #Values > 1:  0
#
# FR0 0 offwind-dc  with q = 0.6
# Smallest value:  0.05653871390591067
# Biggest value:  1.0760803281939086
# #Negative Values:  0
# #Values > 1:  9
# -------------------------------------------------------------------
#
# Processing " FR0 0 onwind " ( 58 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  FR0
# Predict capacity factors for region  FR0
# FR0 0 onwind  with q = 0.4
# Smallest value:  0.004447755630228254
# Biggest value:  0.8916768283672275
# #Negative Values:  0
# #Values > 1:  0
#
# FR0 0 onwind  with q = 0.6
# Smallest value:  0.008930687870048836
# Biggest value:  0.9084614335927191
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " FR0 0 ror " ( 59 / 150 )
# Skipped column:  FR0 0 ror
# -------------------------------------------------------------------
# Processing " FR0 0 solar " ( 60 / 150 )
# Create Trainings data for region:  FR0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  FR0
# Predict capacity factors for region  FR0
# FR0 0 solar  with q = 0.4
# Smallest value:  -0.02678625798187984
# Biggest value:  0.6396853394468786
# #Negative Values:  1878
# #Values > 1:  0
#
# FR0 0 solar  with q = 0.6
# Smallest value:  -0.02099944030714625
# Biggest value:  0.6584833439630161
# #Negative Values:  864
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GB3 0 offwind-ac " ( 61 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  GB3
# Predict capacity factors for region  GB3
# GB3 0 offwind-ac  with q = 0.4
# Smallest value:  0.050000732522613396
# Biggest value:  0.9524830948858516
# #Negative Values:  0
# #Values > 1:  0
#
# GB3 0 offwind-ac  with q = 0.6
# Smallest value:  0.07287933988763667
# Biggest value:  0.9750598198895795
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GB3 0 offwind-dc " ( 62 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  GB3
# Predict capacity factors for region  GB3
# GB3 0 offwind-dc  with q = 0.4
# Smallest value:  0.06767340368385993
# Biggest value:  0.9637221461645317
# #Negative Values:  0
# #Values > 1:  0
#
# GB3 0 offwind-dc  with q = 0.6
# Smallest value:  0.09307633948478483
# Biggest value:  0.9851804921739462
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GB3 0 onwind " ( 63 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  GB3
# Predict capacity factors for region  GB3
# GB3 0 onwind  with q = 0.4
# Smallest value:  0.010550702748479277
# Biggest value:  0.9845084071478515
# #Negative Values:  0
# #Values > 1:  0
#
# GB3 0 onwind  with q = 0.6
# Smallest value:  0.01661909409808176
# Biggest value:  0.9975744532037268
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GB3 0 ror " ( 64 / 150 )
# Skipped column:  GB3 0 ror
# -------------------------------------------------------------------
# Processing " GB3 0 solar " ( 65 / 150 )
# Create Trainings data for region:  GB3  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  GB3
# Predict capacity factors for region  GB3
# GB3 0 solar  with q = 0.4
# Smallest value:  -0.041610744443882304
# Biggest value:  0.5868243750978464
# #Negative Values:  1365
# #Values > 1:  0
#
# GB3 0 solar  with q = 0.6
# Smallest value:  -0.025248217619619158
# Biggest value:  0.6115282295469195
# #Negative Values:  1034
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GB5 0 offwind-ac " ( 66 / 150 )
# Create Trainings data for region:  GB5  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  GB5
# Predict capacity factors for region  GB5
# GB5 0 offwind-ac  with q = 0.4
# Smallest value:  0.03828840163217309
# Biggest value:  0.9669363879498615
# #Negative Values:  0
# #Values > 1:  0
#
# GB5 0 offwind-ac  with q = 0.6
# Smallest value:  0.060264483310565706
# Biggest value:  0.9965134905050886
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GB5 0 offwind-dc " ( 67 / 150 )
# Create Trainings data for region:  GB5  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  GB5
# Predict capacity factors for region  GB5
# GB5 0 offwind-dc  with q = 0.4
# Smallest value:  0.01902308348036833
# Biggest value:  1.0030261117102488
# #Negative Values:  0
# #Values > 1:  1
#
# GB5 0 offwind-dc  with q = 0.6
# Smallest value:  0.036781771223491064
# Biggest value:  1.012351566175235
# #Negative Values:  0
# #Values > 1:  33
# -------------------------------------------------------------------
#
# Processing " GB5 0 onwind " ( 68 / 150 )
# Create Trainings data for region:  GB5  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  GB5
# Predict capacity factors for region  GB5
# GB5 0 onwind  with q = 0.4
# Smallest value:  0.0006939587614537151
# Biggest value:  1.0002175092192844
# #Negative Values:  0
# #Values > 1:  1
#
# GB5 0 onwind  with q = 0.6
# Smallest value:  0.0030563194039865808
# Biggest value:  1.0069020344313462
# #Negative Values:  0
# #Values > 1:  101
# -------------------------------------------------------------------
#
# Processing " GB5 0 solar " ( 69 / 150 )
# Create Trainings data for region:  GB5  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  GB5
# Predict capacity factors for region  GB5
# GB5 0 solar  with q = 0.4
# Smallest value:  -0.053710708162623265
# Biggest value:  0.6299698247887436
# #Negative Values:  1232
# #Values > 1:  0
#
# GB5 0 solar  with q = 0.6
# Smallest value:  -0.025156940842190577
# Biggest value:  0.6485002441771163
# #Negative Values:  81
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GR0 0 offwind-ac " ( 70 / 150 )
# Create Trainings data for region:  GR0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  GR0
# Predict capacity factors for region  GR0
# GR0 0 offwind-ac  with q = 0.4
# Smallest value:  0.009412573541643177
# Biggest value:  0.8138906553525466
# #Negative Values:  0
# #Values > 1:  0
#
# GR0 0 offwind-ac  with q = 0.6
# Smallest value:  0.01661274924983008
# Biggest value:  0.8649660746111075
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GR0 0 offwind-dc " ( 71 / 150 )
# Create Trainings data for region:  GR0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  GR0
# Predict capacity factors for region  GR0
# GR0 0 offwind-dc  with q = 0.4
# Smallest value:  0.024257860778961117
# Biggest value:  0.9283968350423897
# #Negative Values:  0
# #Values > 1:  0
#
# GR0 0 offwind-dc  with q = 0.6
# Smallest value:  0.04257489366079253
# Biggest value:  0.9690316836266991
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GR0 0 onwind " ( 72 / 150 )
# Create Trainings data for region:  GR0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  GR0
# Predict capacity factors for region  GR0
# GR0 0 onwind  with q = 0.4
# Smallest value:  0.008329612329065286
# Biggest value:  0.6654329382053272
# #Negative Values:  0
# #Values > 1:  0
#
# GR0 0 onwind  with q = 0.6
# Smallest value:  0.018026296762598443
# Biggest value:  0.6952884312505787
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " GR0 0 ror " ( 73 / 150 )
# Skipped column:  GR0 0 ror
# -------------------------------------------------------------------
# Processing " GR0 0 solar " ( 74 / 150 )
# Create Trainings data for region:  GR0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  GR0
# Predict capacity factors for region  GR0
# GR0 0 solar  with q = 0.4
# Smallest value:  -0.025051249283601466
# Biggest value:  0.6425771668655959
# #Negative Values:  1931
# #Values > 1:  0
#
# GR0 0 solar  with q = 0.6
# Smallest value:  -0.016910168003709383
# Biggest value:  0.6662841080808021
# #Negative Values:  952
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " HR0 0 offwind-ac " ( 75 / 150 )
# Create Trainings data for region:  HR0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  HR0
# Predict capacity factors for region  HR0
# HR0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.0055421550555188265
# Biggest value:  0.9662660286971336
# #Negative Values:  4
# #Values > 1:  0
#
# HR0 0 offwind-ac  with q = 0.6
# Smallest value:  0.005300000937495749
# Biggest value:  0.9861389195172947
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " HR0 0 offwind-dc " ( 76 / 150 )
# Create Trainings data for region:  HR0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  HR0
# Predict capacity factors for region  HR0
# HR0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.009988209821535577
# Biggest value:  0.9680181840299651
# #Negative Values:  2
# #Values > 1:  0
#
# HR0 0 offwind-dc  with q = 0.6
# Smallest value:  0.009257957507422686
# Biggest value:  1.010989684986923
# #Negative Values:  0
# #Values > 1:  2
# -------------------------------------------------------------------
#
# Processing " HR0 0 onwind " ( 77 / 150 )
# Create Trainings data for region:  HR0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  HR0
# Predict capacity factors for region  HR0
# HR0 0 onwind  with q = 0.4
# Smallest value:  0.0004246714761094576
# Biggest value:  0.873510228781049
# #Negative Values:  0
# #Values > 1:  0
#
# HR0 0 onwind  with q = 0.6
# Smallest value:  0.0022107992438782594
# Biggest value:  0.8906198798088464
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " HR0 0 ror " ( 78 / 150 )
# Skipped column:  HR0 0 ror
# -------------------------------------------------------------------
# Processing " HR0 0 solar " ( 79 / 150 )
# Create Trainings data for region:  HR0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  HR0
# Predict capacity factors for region  HR0
# HR0 0 solar  with q = 0.4
# Smallest value:  -0.026143256300115485
# Biggest value:  0.6376655015550535
# #Negative Values:  961
# #Values > 1:  0
#
# HR0 0 solar  with q = 0.6
# Smallest value:  -0.01797895865040091
# Biggest value:  0.6743034256646788
# #Negative Values:  918
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " HU0 0 onwind " ( 80 / 150 )
# Create Trainings data for region:  HU0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  HU0
# Predict capacity factors for region  HU0
# HU0 0 onwind  with q = 0.4
# Smallest value:  -0.002921504474740455
# Biggest value:  0.9361657792216411
# #Negative Values:  9
# #Values > 1:  0
#
# HU0 0 onwind  with q = 0.6
# Smallest value:  -0.0009748938980152061
# Biggest value:  0.9517909012755612
# #Negative Values:  5
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " HU0 0 ror " ( 81 / 150 )
# Skipped column:  HU0 0 ror
# -------------------------------------------------------------------
# Processing " HU0 0 solar " ( 82 / 150 )
# Create Trainings data for region:  HU0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  HU0
# Predict capacity factors for region  HU0
# HU0 0 solar  with q = 0.4
# Smallest value:  -0.026205587719623342
# Biggest value:  0.6106252619097537
# #Negative Values:  1152
# #Values > 1:  0
#
# HU0 0 solar  with q = 0.6
# Smallest value:  -0.020765497254066262
# Biggest value:  0.6509562458815753
# #Negative Values:  613
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IE5 0 offwind-ac " ( 83 / 150 )
# Create Trainings data for region:  IE5  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  IE5
# Predict capacity factors for region  IE5
# IE5 0 offwind-ac  with q = 0.4
# Smallest value:  0.018145258521897804
# Biggest value:  0.982126951063173
# #Negative Values:  0
# #Values > 1:  0
#
# IE5 0 offwind-ac  with q = 0.6
# Smallest value:  0.03551340258839617
# Biggest value:  0.9942855435060703
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IE5 0 offwind-dc " ( 84 / 150 )
# Create Trainings data for region:  IE5  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  IE5
# Predict capacity factors for region  IE5
# IE5 0 offwind-dc  with q = 0.4
# Smallest value:  0.013113267229614565
# Biggest value:  0.9714511510489632
# #Negative Values:  0
# #Values > 1:  0
#
# IE5 0 offwind-dc  with q = 0.6
# Smallest value:  0.0292857709003134
# Biggest value:  1.0295750227689182
# #Negative Values:  0
# #Values > 1:  76
# -------------------------------------------------------------------
#
# Processing " IE5 0 onwind " ( 85 / 150 )
# Create Trainings data for region:  IE5  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  IE5
# Predict capacity factors for region  IE5
# IE5 0 onwind  with q = 0.4
# Smallest value:  0.0018342535464076978
# Biggest value:  0.9943863724468492
# #Negative Values:  0
# #Values > 1:  0
#
# IE5 0 onwind  with q = 0.6
# Smallest value:  0.0046553864847950505
# Biggest value:  1.0005516980355655
# #Negative Values:  0
# #Values > 1:  2
# -------------------------------------------------------------------
#
# Processing " IE5 0 ror " ( 86 / 150 )
# Skipped column:  IE5 0 ror
# -------------------------------------------------------------------
# Processing " IE5 0 solar " ( 87 / 150 )
# Create Trainings data for region:  IE5  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  IE5
# Predict capacity factors for region  IE5
# IE5 0 solar  with q = 0.4
# Smallest value:  -0.0357294598061831
# Biggest value:  0.6177384013921671
# #Negative Values:  1183
# #Values > 1:  0
#
# IE5 0 solar  with q = 0.6
# Smallest value:  -0.023788934513472963
# Biggest value:  0.642886138844743
# #Negative Values:  74
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT0 0 offwind-ac " ( 88 / 150 )
# Create Trainings data for region:  IT0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  IT0
# Predict capacity factors for region  IT0
# IT0 0 offwind-ac  with q = 0.4
# Smallest value:  0.0047763837060379385
# Biggest value:  0.8746373490732459
# #Negative Values:  0
# #Values > 1:  0
#
# IT0 0 offwind-ac  with q = 0.6
# Smallest value:  0.009155876614027841
# Biggest value:  0.930002952225902
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT0 0 offwind-dc " ( 89 / 150 )
# Create Trainings data for region:  IT0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  IT0
# Predict capacity factors for region  IT0
# IT0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.01732797149849799
# Biggest value:  0.922240199233098
# #Negative Values:  2
# #Values > 1:  0
#
# IT0 0 offwind-dc  with q = 0.6
# Smallest value:  0.02092540994153632
# Biggest value:  0.988424389902803
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT0 0 onwind " ( 90 / 150 )
# Create Trainings data for region:  IT0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  IT0
# Predict capacity factors for region  IT0
# IT0 0 onwind  with q = 0.4
# Smallest value:  0.004979070696417011
# Biggest value:  0.7553589204403046
# #Negative Values:  0
# #Values > 1:  0
#
# IT0 0 onwind  with q = 0.6
# Smallest value:  0.010270230669032291
# Biggest value:  0.7787377336140575
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT0 0 ror " ( 91 / 150 )
# Skipped column:  IT0 0 ror
# -------------------------------------------------------------------
# Processing " IT0 0 solar " ( 92 / 150 )
# Create Trainings data for region:  IT0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  IT0
# Predict capacity factors for region  IT0
# IT0 0 solar  with q = 0.4
# Smallest value:  -0.027015608687149077
# Biggest value:  0.62963059827925
# #Negative Values:  1875
# #Values > 1:  0
#
# IT0 0 solar  with q = 0.6
# Smallest value:  -0.022471532307601308
# Biggest value:  0.6568015731199961
# #Negative Values:  1098
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT1 0 offwind-ac " ( 93 / 150 )
# Create Trainings data for region:  IT1  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  IT1
# Predict capacity factors for region  IT1
# IT1 0 offwind-ac  with q = 0.4
# Smallest value:  0.002307938292766153
# Biggest value:  0.965255522653248
# #Negative Values:  0
# #Values > 1:  0
#
# IT1 0 offwind-ac  with q = 0.6
# Smallest value:  0.005578141307522608
# Biggest value:  0.9845698621156871
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT1 0 onwind " ( 94 / 150 )
# Create Trainings data for region:  IT1  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  IT1
# Predict capacity factors for region  IT1
# IT1 0 onwind  with q = 0.4
# Smallest value:  -0.0031766753992500812
# Biggest value:  0.9722754688461394
# #Negative Values:  26
# #Values > 1:  0
#
# IT1 0 onwind  with q = 0.6
# Smallest value:  -0.0013874455817396531
# Biggest value:  0.9801019326174795
# #Negative Values:  1
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " IT1 0 ror " ( 95 / 150 )
# Skipped column:  IT1 0 ror
# -------------------------------------------------------------------
# Processing " IT1 0 solar " ( 96 / 150 )
# Create Trainings data for region:  IT1  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  IT1
# Predict capacity factors for region  IT1
# IT1 0 solar  with q = 0.4
# Smallest value:  -0.06496120495214623
# Biggest value:  0.6262843152808434
# #Negative Values:  1652
# #Values > 1:  0
#
# IT1 0 solar  with q = 0.6
# Smallest value:  -0.04912605654765523
# Biggest value:  0.6500278307325372
# #Negative Values:  154
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " LT6 0 offwind-ac " ( 97 / 150 )
# Create Trainings data for region:  LT6  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  LT6
# Predict capacity factors for region  LT6
# LT6 0 offwind-ac  with q = 0.4
# Smallest value:  -0.00598327524406707
# Biggest value:  1.0035460035682762
# #Negative Values:  81
# #Values > 1:  9
#
# LT6 0 offwind-ac  with q = 0.6
# Smallest value:  -0.0027816282032197383
# Biggest value:  1.0093474875599682
# #Negative Values:  14
# #Values > 1:  196
# -------------------------------------------------------------------
#
# Processing " LT6 0 offwind-dc " ( 98 / 150 )
# Create Trainings data for region:  LT6  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  LT6
# Predict capacity factors for region  LT6
# LT6 0 offwind-dc  with q = 0.4
# Smallest value:  -0.006283045856314239
# Biggest value:  1.0046230569059782
# #Negative Values:  394
# #Values > 1:  3
#
# LT6 0 offwind-dc  with q = 0.6
# Smallest value:  -0.0015673150165139526
# Biggest value:  1.0072571489501811
# #Negative Values:  2
# #Values > 1:  987
# -------------------------------------------------------------------
#
# Processing " LT6 0 onwind " ( 99 / 150 )
# Create Trainings data for region:  LT6  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  LT6
# Predict capacity factors for region  LT6
# LT6 0 onwind  with q = 0.4
# Smallest value:  -0.0014396768318472807
# Biggest value:  0.9919466640594713
# #Negative Values:  45
# #Values > 1:  0
#
# LT6 0 onwind  with q = 0.6
# Smallest value:  0.0007784399885404999
# Biggest value:  1.0002857163821022
# #Negative Values:  0
# #Values > 1:  2
# -------------------------------------------------------------------
#
# Processing " LT6 0 solar " ( 100 / 150 )
# Create Trainings data for region:  LT6  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  LT6
# Predict capacity factors for region  LT6
# LT6 0 solar  with q = 0.4
# Smallest value:  -0.04487492278368086
# Biggest value:  0.6497792709156446
# #Negative Values:  773
# #Values > 1:  0
#
# ...
# Predict capacity factors for region  NL0
# NL0 0 onwind  with q = 0.4
# Smallest value:  0.0007853090720952955
# Biggest value:  0.9950085574273354
# #Negative Values:  0
# #Values > 1:  0
#
# NL0 0 onwind  with q = 0.6
# Smallest value:  0.0035178245647896943
# Biggest value:  1.001507738477837
# #Negative Values:  0
# #Values > 1:  19
# -------------------------------------------------------------------
#
# Processing " NL0 0 solar " ( 118 / 150 )
# Create Trainings data for region:  NL0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  NL0
# Predict capacity factors for region  NL0
# NL0 0 solar  with q = 0.4
# Smallest value:  -0.03111447971800653
# Biggest value:  0.6312910927663195
# #Negative Values:  1069
# #Values > 1:  0
#
# NL0 0 solar  with q = 0.6
# Smallest value:  -0.0222778261114754
# Biggest value:  0.6854750292014861
# #Negative Values:  149
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " NO4 0 offwind-ac " ( 119 / 150 )
# Create Trainings data for region:  NO4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  NO4
# Predict capacity factors for region  NO4
# NO4 0 offwind-ac  with q = 0.4
# Smallest value:  0.04734135998884052
# Biggest value:  0.9081150168469282
# #Negative Values:  0
# #Values > 1:  0
#
# NO4 0 offwind-ac  with q = 0.6
# Smallest value:  0.05950910026912152
# Biggest value:  0.9374048449090621
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " NO4 0 offwind-dc " ( 120 / 150 )
# Create Trainings data for region:  NO4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  NO4
# Predict capacity factors for region  NO4
# NO4 0 offwind-dc  with q = 0.4
# Smallest value:  0.0592280429594906
# Biggest value:  0.9775636400778858
# #Negative Values:  0
# #Values > 1:  0
#
# NO4 0 offwind-dc  with q = 0.6
# Smallest value:  0.09848297340510782
# Biggest value:  0.9929996859025839
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " NO4 0 onwind " ( 121 / 150 )
# Create Trainings data for region:  NO4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  NO4
# Predict capacity factors for region  NO4
# NO4 0 onwind  with q = 0.4
# Smallest value:  0.008411610929494145
# Biggest value:  0.8051072812089561
# #Negative Values:  0
# #Values > 1:  0
#
# NO4 0 onwind  with q = 0.6
# Smallest value:  0.01244000158625491
# Biggest value:  0.8198796187722306
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " NO4 0 solar " ( 122 / 150 )
# Create Trainings data for region:  NO4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  NO4
# Predict capacity factors for region  NO4
# NO4 0 solar  with q = 0.4
# Smallest value:  -0.014400189188612831
# Biggest value:  0.5553673162583795
# #Negative Values:  701
# #Values > 1:  0
#
# NO4 0 solar  with q = 0.6
# Smallest value:  -0.01219763264248255
# Biggest value:  0.5978705418046047
# #Negative Values:  315
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " PL0 0 offwind-ac " ( 123 / 150 )
# Create Trainings data for region:  PL0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  PL0
# Predict capacity factors for region  PL0
# PL0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.005435139521776162
# Biggest value:  1.0263441159573348
# #Negative Values:  8
# #Values > 1:  6
#
# PL0 0 offwind-ac  with q = 0.6
# Smallest value:  0.0006349381053500879
# Biggest value:  1.0312472938737538
# #Negative Values:  0
# #Values > 1:  25
# -------------------------------------------------------------------
#
# Processing " PL0 0 offwind-dc " ( 124 / 150 )
# Create Trainings data for region:  PL0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  PL0
# Predict capacity factors for region  PL0
# PL0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.0030410271284083273
# Biggest value:  1.004534145204703
# #Negative Values:  30
# #Values > 1:  21
#
# PL0 0 offwind-dc  with q = 0.6
# Smallest value:  0.0026185735398024396
# Biggest value:  1.0139623824030304
# #Negative Values:  0
# #Values > 1:  218
# -------------------------------------------------------------------
#
# Processing " PL0 0 onwind " ( 125 / 150 )
# Create Trainings data for region:  PL0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  PL0
# Predict capacity factors for region  PL0
# PL0 0 onwind  with q = 0.4
# Smallest value:  0.000972582526173026
# Biggest value:  0.9912306680246248
# #Negative Values:  0
# #Values > 1:  0
#
# PL0 0 onwind  with q = 0.6
# Smallest value:  0.004414191019007151
# Biggest value:  0.998125099219314
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " PL0 0 ror " ( 126 / 150 )
# Skipped column:  PL0 0 ror
# -------------------------------------------------------------------
# Processing " PL0 0 solar " ( 127 / 150 )
# Create Trainings data for region:  PL0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  PL0
# Predict capacity factors for region  PL0
# PL0 0 solar  with q = 0.4
# Smallest value:  -0.03778348426664637
# Biggest value:  0.6019664185364552
# #Negative Values:  1427
# #Values > 1:  0
#
# PL0 0 solar  with q = 0.6
# Smallest value:  -0.032627694651268406
# Biggest value:  0.6349392337710617
# #Negative Values:  719
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " PT0 0 offwind-ac " ( 128 / 150 )
# Create Trainings data for region:  PT0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  PT0
# Predict capacity factors for region  PT0
# PT0 0 offwind-ac  with q = 0.4
# Smallest value:  0.005620168941467468
# Biggest value:  0.9708410489854142
# #Negative Values:  0
# #Values > 1:  0
#
# PT0 0 offwind-ac  with q = 0.6
# Smallest value:  0.01280438337331195
# Biggest value:  0.996752623755994
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " PT0 0 onwind " ( 129 / 150 )
# Create Trainings data for region:  PT0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  PT0
# Predict capacity factors for region  PT0
# PT0 0 onwind  with q = 0.4
# Smallest value:  -0.0020832663036401394
# Biggest value:  0.9680317981971027
# #Negative Values:  27
# #Values > 1:  0
#
# PT0 0 onwind  with q = 0.6
# Smallest value:  0.000485210056947366
# Biggest value:  0.9830014134528733
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " PT0 0 ror " ( 130 / 150 )
# Skipped column:  PT0 0 ror
# -------------------------------------------------------------------
# Processing " PT0 0 solar " ( 131 / 150 )
# Create Trainings data for region:  PT0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  PT0
# Predict capacity factors for region  PT0
# PT0 0 solar  with q = 0.4
# Smallest value:  -0.03650539079911892
# Biggest value:  0.6450439777921396
# #Negative Values:  2189
# #Values > 1:  0
#
# PT0 0 solar  with q = 0.6
# Smallest value:  -0.028031679299941662
# Biggest value:  0.6808261750268032
# #Negative Values:  500
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " RO0 0 offwind-ac " ( 132 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  RO0
# Predict capacity factors for region  RO0
# RO0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.0026466984344308596
# Biggest value:  1.0002740683273195
# #Negative Values:  8
# #Values > 1:  3
#
# RO0 0 offwind-ac  with q = 0.6
# Smallest value:  0.0019163904675139258
# Biggest value:  1.0107033837523964
# #Negative Values:  0
# #Values > 1:  17
# -------------------------------------------------------------------
#
# Processing " RO0 0 offwind-dc " ( 133 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  RO0
# Predict capacity factors for region  RO0
# RO0 0 offwind-dc  with q = 0.4
# Smallest value:  -0.003851451376068361
# Biggest value:  1.0086054032527938
# #Negative Values:  2
# #Values > 1:  14
#
# RO0 0 offwind-dc  with q = 0.6
# Smallest value:  0.001767001597671355
# Biggest value:  1.0140919143019211
# #Negative Values:  0
# #Values > 1:  121
# -------------------------------------------------------------------
#
# Processing " RO0 0 onwind " ( 134 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  RO0
# Predict capacity factors for region  RO0
# RO0 0 onwind  with q = 0.4
# Smallest value:  -0.0004968302427202434
# Biggest value:  0.697212161124834
# #Negative Values:  1
# #Values > 1:  0
#
# RO0 0 onwind  with q = 0.6
# Smallest value:  0.0033562889667102013
# Biggest value:  0.7129688549742229
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " RO0 0 ror " ( 135 / 150 )
# Skipped column:  RO0 0 ror
# -------------------------------------------------------------------
# Processing " RO0 0 solar " ( 136 / 150 )
# Create Trainings data for region:  RO0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  RO0
# Predict capacity factors for region  RO0
# RO0 0 solar  with q = 0.4
# Smallest value:  -0.021578561470088384
# Biggest value:  0.6395684908328653
# #Negative Values:  1644
# #Values > 1:  0
#
# RO0 0 solar  with q = 0.6
# Smallest value:  -0.015347792285498998
# Biggest value:  0.6677341806772042
# #Negative Values:  502
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " RS0 0 onwind " ( 137 / 150 )
# Create Trainings data for region:  RS0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  RS0
# Predict capacity factors for region  RS0
# RS0 0 onwind  with q = 0.4
# Smallest value:  -0.0015732622020330632
# Biggest value:  0.9452597870758676
# #Negative Values:  47
# #Values > 1:  0
#
# RS0 0 onwind  with q = 0.6
# Smallest value:  0.0002778706643333718
# Biggest value:  0.9641835216159446
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " RS0 0 solar " ( 138 / 150 )
# Create Trainings data for region:  RS0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  RS0
# Predict capacity factors for region  RS0
# RS0 0 solar  with q = 0.4
# Smallest value:  -0.02846054357064404
# Biggest value:  0.6041373060629726
# #Negative Values:  1996
# #Values > 1:  0
#
# RS0 0 solar  with q = 0.6
# Smallest value:  -0.01956493336681069
# Biggest value:  0.639583276589872
# #Negative Values:  1175
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " SE4 0 offwind-ac " ( 139 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  SE4
# Predict capacity factors for region  SE4
# SE4 0 offwind-ac  with q = 0.4
# Smallest value:  0.011814586967299198
# Biggest value:  0.9763921117663908
# #Negative Values:  0
# #Values > 1:  0
#
# SE4 0 offwind-ac  with q = 0.6
# Smallest value:  0.019240422104645126
# Biggest value:  1.0018882202524901
# #Negative Values:  0
# #Values > 1:  3
# -------------------------------------------------------------------
#
# Processing " SE4 0 offwind-dc " ( 140 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.OFFWIND_DC
# Fit Regression Model for region  SE4
# Predict capacity factors for region  SE4
# SE4 0 offwind-dc  with q = 0.4
# Smallest value:  -0.00996211582853413
# Biggest value:  0.9820201159594903
# #Negative Values:  1
# #Values > 1:  0
#
# SE4 0 offwind-dc  with q = 0.6
# Smallest value:  0.0007044816439059666
# Biggest value:  1.0002460601467917
# #Negative Values:  0
# #Values > 1:  1
# -------------------------------------------------------------------
#
# Processing " SE4 0 onwind " ( 141 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  SE4
# Predict capacity factors for region  SE4
# SE4 0 onwind  with q = 0.4
# Smallest value:  0.006433086462912
# Biggest value:  0.896958829045537
# #Negative Values:  0
# #Values > 1:  0
#
# SE4 0 onwind  with q = 0.6
# Smallest value:  0.01204828677500234
# Biggest value:  0.9128255132125371
# #Negative Values:  0
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " SE4 0 ror " ( 142 / 150 )
# Skipped column:  SE4 0 ror
# -------------------------------------------------------------------
# Processing " SE4 0 solar " ( 143 / 150 )
# Create Trainings data for region:  SE4  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  SE4
# Predict capacity factors for region  SE4
# SE4 0 solar  with q = 0.4
# Smallest value:  -0.02583913030241898
# Biggest value:  0.5641577170339768
# #Negative Values:  1110
# #Values > 1:  0
#
# SE4 0 solar  with q = 0.6
# Smallest value:  -0.01962789806177228
# Biggest value:  0.6098923731683094
# #Negative Values:  750
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " SI0 0 offwind-ac " ( 144 / 150 )
# Create Trainings data for region:  SI0  with energy type:  EnergyType.OFFWIND_AC
# Fit Regression Model for region  SI0
# Predict capacity factors for region  SI0
# SI0 0 offwind-ac  with q = 0.4
# Smallest value:  -0.0028783579281497556
# Biggest value:  1.0027075381974995
# #Negative Values:  2405
# #Values > 1:  2
#
# SI0 0 offwind-ac  with q = 0.6
# Smallest value:  -0.002111760643691958
# Biggest value:  1.0045714644106765
# #Negative Values:  1
# #Values > 1:  63
# -------------------------------------------------------------------
#
# Processing " SI0 0 onwind " ( 145 / 150 )
# Create Trainings data for region:  SI0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  SI0
# Predict capacity factors for region  SI0
# SI0 0 onwind  with q = 0.4
# Smallest value:  -0.0015938696328800907
# Biggest value:  0.9114794067727364
# #Negative Values:  363
# #Values > 1:  0
#
# SI0 0 onwind  with q = 0.6
# Smallest value:  -0.0006177521326204686
# Biggest value:  0.9235082159098359
# #Negative Values:  6
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " SI0 0 ror " ( 146 / 150 )
# Skipped column:  SI0 0 ror
# -------------------------------------------------------------------
# Processing " SI0 0 solar " ( 147 / 150 )
# Create Trainings data for region:  SI0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  SI0
# Predict capacity factors for region  SI0
# SI0 0 solar  with q = 0.4
# Smallest value:  -0.028413822573024074
# Biggest value:  0.6202136497604375
# #Negative Values:  1383
# #Values > 1:  0
#
# SI0 0 solar  with q = 0.6
# Smallest value:  -0.023262968186233624
# Biggest value:  0.6510596950424611
# #Negative Values:  637
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " SK0 0 onwind " ( 148 / 150 )
# Create Trainings data for region:  SK0  with energy type:  EnergyType.ONWIND
# Fit Regression Model for region  SK0
# Predict capacity factors for region  SK0
# SK0 0 onwind  with q = 0.4
# Smallest value:  -0.015641637722661222
# Biggest value:  0.9566198437578423
# #Negative Values:  116
# #Values > 1:  0
#
# SK0 0 onwind  with q = 0.6
# Smallest value:  -0.01082006914644242
# Biggest value:  0.9697850321087512
# #Negative Values:  35
# #Values > 1:  0
# -------------------------------------------------------------------
#
# Processing " SK0 0 ror " ( 149 / 150 )
# Skipped column:  SK0 0 ror
# -------------------------------------------------------------------
# Processing " SK0 0 solar " ( 150 / 150 )
# Create Trainings data for region:  SK0  with energy type:  EnergyType.SOLAR
# Fit Regression Model for region  SK0
# Predict capacity factors for region  SK0
# SK0 0 solar  with q = 0.4
# Smallest value:  -0.04237500281322799
# Biggest value:  0.6321041330717111
# #Negative Values:  648
# #Values > 1:  0
#
# SK0 0 solar  with q = 0.6
# Smallest value:  -0.02959797940338669
# Biggest value:  0.6748729941585508
# #Negative Values:  504
# #Values > 1:  0
# -------------------------------------------------------------------

# %%
capfacts_pred_q40.to_csv('results/capfacts_pred_q40.csv')
capfacts_pred_q60.to_csv('results/capfacts_pred_q60.csv')
capfacts_pred_q40
# Out:
#                  snapshot  AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  \
# 0     2013-01-01 00:00:00          0.000928      0.018104     0.000975
# 1     2013-01-01 01:00:00          0.000928      0.010446     0.000975
# 2     2013-01-01 02:00:00          0.000928      0.004443     0.001260
# 3     2013-01-01 03:00:00          0.000928      0.002503     0.002607
# 4     2013-01-01 04:00:00         -0.000102     -0.000837     0.002607
# ...                   ...               ...           ...          ...
# 8755  2013-12-31 19:00:00          0.029153      0.052263     0.000961
# 8756  2013-12-31 20:00:00          0.029161      0.065263     0.000961
# 8757  2013-12-31 21:00:00          0.029153      0.070495     0.001175
# 8758  2013-12-31 22:00:00          0.029545      0.052263     0.001175
# 8759  2013-12-31 23:00:00          0.016479      0.047181     0.001175
#
#       AT0 0 onwind  AT0 0 solar  BA0 0 onwind  BA0 0 solar  BE0 0 offwind-ac  \
# 0         0.175273     0.002074      0.007821     0.002178          0.985324
# 1         0.175273     0.002074      0.009557     0.001121          0.971108
# 2         0.152732     0.002074      0.009557     0.001121          0.937728
# 3         0.137212     0.002074      0.009557     0.001121          0.831023
# 4         0.130745     0.002074      0.010375     0.001121          0.645404
# ...            ...          ...           ...          ...               ...
# 8755      0.111495     0.002074      0.001800     0.000976          0.919508
# 8756      0.129865     0.002074      0.001800     0.000976          0.778407
# 8757      0.129865     0.002074      0.001812     0.000976          0.707040
# 8758      0.161829     0.002074      0.002011     0.000976          0.766593
# 8759      0.151693     0.002074      0.001800     0.000976          0.873038
#
#       BE0 0 offwind-dc  ...  RS0 0 solar  SE4 0 offwind-ac  SE4 0 offwind-dc  \
# 0             0.996833  ...     0.001190          0.883585          0.929599
# 1             0.996833  ...     0.001190          0.864818          0.929391
# 2             0.996629  ...     0.001190          0.864818          0.929391
# 3             0.938460  ...     0.001190          0.864818          0.927961
# 4             0.759356  ...     0.001190          0.864818          0.929391
# ...                ...  ...          ...               ...               ...
# 8755          0.989035  ...     0.000900          0.774638          0.858609
# 8756          0.910707  ...     0.002864          0.737556          0.855220
# 8757          0.847579  ...     0.010672          0.692466          0.791745
# 8758          0.919846  ...     0.000017          0.672129          0.785177
# 8759          0.988350  ...     0.000017          0.610597          0.691225
#
#       SE4 0 onwind  SE4 0 solar  SI0 0 offwind-ac  SI0 0 onwind  SI0 0 solar  \
# 0         0.385410     0.001006         -0.000013      0.014425     0.001833
# 1         0.385410     0.001006         -0.000013      0.019608     0.001833
# 2         0.386180     0.001006         -0.000028      0.025489     0.001833
# 3         0.386180     0.001006         -0.000023      0.036644     0.001833
# 4         0.385410     0.001006         -0.000023      0.041910     0.001833
# ...            ...          ...               ...           ...          ...
# 8755      0.307886     0.001006          0.025999      0.003614     0.001377
# 8756      0.283948     0.001006          0.021950      0.005001     0.001377
# 8757      0.247635     0.001006          0.000050      0.005051     0.001377
# 8758      0.204160     0.001006         -0.000171      0.008033     0.001377
# 8759      0.198137     0.001006         -0.000151      0.008039     0.001377
#
#       SK0 0 onwind  SK0 0 solar
# 0         0.236722     0.000873
# 1         0.236722     0.000873
# 2         0.262663     0.000873
# 3         0.262663     0.000873
# 4         0.264453     0.000873
# ...            ...          ...
# 8755      0.074752     0.000940
# 8756      0.082766     0.000940
# 8757      0.083883     0.000940
# 8758      0.090750     0.000940
# 8759      0.096459     0.000940
#
# [8760 rows x 126 columns]

# %%
cols_num = capfacts_pred_q40.select_dtypes(np.number).columns
print(cols_num)

capfacts_pred_q40[cols_num] = capfacts_pred_q40[cols_num].clip(lower=0, upper=1.02)
capfacts_pred_q60[cols_num] = capfacts_pred_q60[cols_num].clip(lower=0, upper=1.02)

# capfacts_pred_q40.iloc[:, 1:].clip(lower=0, upper=1.02)
# capfacts_pred_q60.iloc[:, 1:].clip(lower=0, upper=1.02)

capfacts_pred_q40.to_csv('results/capfacts_pred_q40_clipped.csv')
capfacts_pred_q60.to_csv('results/capfacts_pred_q60_clipped.csv')

# Alles klar, danke euch. Dann werde ich das auf [0, 1.02] beschränken
capfacts_pred_q40
# Out:
# Index(['AL0 0 offwind-ac', 'AL0 0 onwind', 'AL0 0 solar', 'AT0 0 onwind',
#        'AT0 0 solar', 'BA0 0 onwind', 'BA0 0 solar', 'BE0 0 offwind-ac',
#        'BE0 0 offwind-dc', 'BE0 0 onwind',
#        ...
#        'RS0 0 solar', 'SE4 0 offwind-ac', 'SE4 0 offwind-dc', 'SE4 0 onwind',
#        'SE4 0 solar', 'SI0 0 offwind-ac', 'SI0 0 onwind', 'SI0 0 solar',
#        'SK0 0 onwind', 'SK0 0 solar'],
#       dtype='object', length=125)
#                  snapshot  AL0 0 offwind-ac  AL0 0 onwind  AL0 0 solar  \
# 0     2013-01-01 00:00:00          0.000928      0.018104     0.000975
# 1     2013-01-01 01:00:00          0.000928      0.010446     0.000975
# 2     2013-01-01 02:00:00          0.000928      0.004443     0.001260
# 3     2013-01-01 03:00:00          0.000928      0.002503     0.002607
# 4     2013-01-01 04:00:00          0.000000      0.000000     0.002607
# ...                   ...               ...           ...          ...
# 8755  2013-12-31 19:00:00          0.029153      0.052263     0.000961
# 8756  2013-12-31 20:00:00          0.029161      0.065263     0.000961
# 8757  2013-12-31 21:00:00          0.029153      0.070495     0.001175
# 8758  2013-12-31 22:00:00          0.029545      0.052263     0.001175
# 8759  2013-12-31 23:00:00          0.016479      0.047181     0.001175
#
#       AT0 0 onwind  AT0 0 solar  BA0 0 onwind  BA0 0 solar  BE0 0 offwind-ac  \
# 0         0.175273     0.002074      0.007821     0.002178          0.985324
# 1         0.175273     0.002074      0.009557     0.001121          0.971108
# 2         0.152732     0.002074      0.009557     0.001121          0.937728
# 3         0.137212     0.002074      0.009557     0.001121          0.831023
# 4         0.130745     0.002074      0.010375     0.001121          0.645404
# ...            ...          ...           ...          ...               ...
# 8755      0.111495     0.002074      0.001800     0.000976          0.919508
# 8756      0.129865     0.002074      0.001800     0.000976          0.778407
# 8757      0.129865     0.002074      0.001812     0.000976          0.707040
# 8758      0.161829     0.002074      0.002011     0.000976          0.766593
# 8759      0.151693     0.002074      0.001800     0.000976          0.873038
#
#       BE0 0 offwind-dc  ...  RS0 0 solar  SE4 0 offwind-ac  SE4 0 offwind-dc  \
# 0             0.996833  ...     0.001190          0.883585          0.929599
# 1             0.996833  ...     0.001190          0.864818          0.929391
# 2             0.996629  ...     0.001190          0.864818          0.929391
# 3             0.938460  ...     0.001190          0.864818          0.927961
# 4             0.759356  ...     0.001190          0.864818          0.929391
# ...                ...  ...          ...               ...               ...
# 8755          0.989035  ...     0.000900          0.774638          0.858609
# 8756          0.910707  ...     0.002864          0.737556          0.855220
# 8757          0.847579  ...     0.010672          0.692466          0.791745
# 8758          0.919846  ...     0.000017          0.672129          0.785177
# 8759          0.988350  ...     0.000017          0.610597          0.691225
#
#       SE4 0 onwind  SE4 0 solar  SI0 0 offwind-ac  SI0 0 onwind  SI0 0 solar  \
# 0         0.385410     0.001006          0.000000      0.014425     0.001833
# 1         0.385410     0.001006          0.000000      0.019608     0.001833
# 2         0.386180     0.001006          0.000000      0.025489     0.001833
# 3         0.386180     0.001006          0.000000      0.036644     0.001833
# 4         0.385410     0.001006          0.000000      0.041910     0.001833
# ...            ...          ...               ...           ...          ...
# 8755      0.307886     0.001006          0.025999      0.003614     0.001377
# 8756      0.283948     0.001006          0.021950      0.005001     0.001377
# 8757      0.247635     0.001006          0.000050      0.005051     0.001377
# 8758      0.204160     0.001006          0.000000      0.008033     0.001377
# 8759      0.198137     0.001006          0.000000      0.008039     0.001377
#
#       SK0 0 onwind  SK0 0 solar
# 0         0.236722     0.000873
# 1         0.236722     0.000873
# 2         0.262663     0.000873
# 3         0.262663     0.000873
# 4         0.264453     0.000873
# ...            ...          ...
# 8755      0.074752     0.000940
# 8756      0.082766     0.000940
# 8757      0.083883     0.000940
# 8758      0.090750     0.000940
# 8759      0.096459     0.000940
#
# [8760 rows x 126 columns]

# %%
capfacts_pred_q40.dtypes
# Out:
# snapshot             object
# AL0 0 offwind-ac    float64
# AL0 0 onwind        float64
# AL0 0 solar         float64
# AT0 0 onwind        float64
#                      ...
# SI0 0 offwind-ac    float64
# SI0 0 onwind        float64
# SI0 0 solar         float64
# SK0 0 onwind        float64
# SK0 0 solar         float64
# Length: 126, dtype: object
